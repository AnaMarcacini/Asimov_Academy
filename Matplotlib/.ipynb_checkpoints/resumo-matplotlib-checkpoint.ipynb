# %% [markdown]
# # Resumo - Matplotlib

# %% [markdown]
# ## Introdução

# %% [markdown]
# Matplotlib é a biblioteca "avô" de visualização de dados com o Python. Foi criado por John Hunter. Ele criou-a para tentar replicar os recursos de visualização de dados do MatLab (outra linguagem de programação) no Python. Então, se você estiver familiarizado com matlab, aprender matplotlib será natural para você.
#
# É uma excelente biblioteca de gráficos 2D e 3D para gerar figuras científicas.
#
# Algumas das vantagens do Matplotlib são:
#
# * Geralmente fácil de começar para plotagens simples
# * Suporte para rótulos e textos personalizados
# * Saída de alta qualidade em muitos formatos
# * Muito personalizável em geral
#
# Matplotlib permite que você crie figuras reprodutíveis de forma programática. Vamos aprender a usá-lo! Antes de continuar esta palestra, sugiro que você dê uma olhada  na página oficial do Matplotlib: http://matplotlib.org/
#
# ## Instalação
#
# Você precisará primeiro instalar Matplotlib com:
#
#     conda install matplotlib
# ou
#     pip install matplotlib
#
# ## Importação

# %%
import numpy as np
x = np.linspace(0, 5, 11) #cria 11 valores no intervalo de 0-5
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# #dentro do jupyter --> não em nova janela

# %% [markdown]
# ## Comandos básicos do Matplotlib

# %%
plt.plot(x, y, 'r') # 'r' é a cor vermelha (red)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Título')
plt.show()

# %% [markdown]
# ## Criando Multiplots na mesma tela

# %%
# plt.subplot(nlinhas, ncols, numeroplot)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # Mais nas seções de cores abaixo
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
# Cria uma figura vazia
fig = plt.figure()

# Adiciona eixos à figura
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # esquerda, inferior, largura, altura (faixa de 0 a 1) padding (valor porcentual de 0-1)

# Plota nos eixos especificados
axes.plot(x, y, 'b')#ploat do objeto que eu criei -- utilizando o objeto axes (fazendo tudo na mão o plt (plt.plot(x, y, 'r--') ) seria um objeto pronto ou seja não personalizariamos o pading 
#axes.plot(x, y, 'blue')
axes.set_xlabel('Define o Label X') # Perceba o uso de "set_" para começar métodos
axes.set_ylabel('Define o Label Y')
axes.set_title('Define o Título')
# Out:
# Text(0.5, 1.0, 'Define o Título')

# %% [markdown]
# O código é um pouco mais complicado, mas a vantagem é que agora temos o controle total de onde os eixos da parcela são colocados, e podemos facilmente adicionar mais de um eixo à figura:

# %%
# Cria uma figura vazia
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # Eixo principal
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # Eixos inseridos

# Trabalhando no eixo maior
axes1.plot(x, y, 'blue')
axes1.set_xlabel('Eixo X1')
axes1.set_ylabel('Eixo Y1')
axes1.set_title('Título 1')

# Trabalhando no eixo menor
axes2.plot(y, x, 'red')
axes2.set_xlabel('Eixo X2')
axes2.set_ylabel('Eixo Y2')
axes2.set_title('Título 2')
# grafico gerado apenas pelo fato de utilizarmos objetos
# Out:
# Text(0.5, 1.0, 'Título 2')

# %% [markdown]
# ## subplots()

# %%
(1,2)#posição importa
# Out:
# (1, 2)

# %%
type((1,2))
# Out:
# tuple

# %%
a, b = (1,2)
print(f'{a} e {b}')
# Out:
# 1 e 2

# %%
# Use semelhante a plt.figure (), exceto usar o desempacotamento da tupla para agarrar as figuras e os eixos
fig, axes = plt.subplots()#uma tupla (figura e eixo)

# Agora use o objeto dos eixos para adicionar coisas ao gráfico
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Título');

# %%
#Tela vazia de 2 por 2 subplots
fig, axes = plt.subplots(nrows=2, ncols=2)

# %%
# Eixos é uma matriz de eixos
axes#lista com os dois elementos
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
#Tela vazia de 1 por 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
# Eixos é uma matriz de eixos
axes#lista com os dois elementos
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('Título')

# Mostra o objeto fig
fig

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,"red")
axes[1].plot(x,y,"green")

# %% [markdown]
# Um problema comum com matplolib é sobreposição de subplots ou figuras. Nós podemos usar o método ** fig.tight_layout () ** ou ** plt.tight_layout () **, que ajusta automaticamente as posições dos eixos na tela de figuras para que não haja conteúdo sobreposto:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('título')

fig    
plt.tight_layout()#Ajusta o grafico -- não fica comprimido no canto --> ajusta a tela

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (30,8))

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('título')

fig    
plt.tight_layout()#Ajusta o grafico -- não fica comprimido no canto --> ajusta a tela

# %%
fig, ax = plt.subplots(nrows =2, ncols=2)

# %%
ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
ax[1]
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
ax[1][1]
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Tamanho da figura, relação de aspecto e DPI

# %% [markdown]
# Matplotlib permite que a relação de aspecto, DPI e o tamanho da figura sejam especificados quando o objeto Figura é criado. Você pode usar os argumentos de palavras-chave `figsize` e` dpi`.
# * `figsize` é uma tupla da largura e altura da figura em polegadas
# * `dpi` é o ponto por polegada (pixel por polegada).

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('título');

# %% [markdown]
# ## Salvando figuras

# %%
fig.savefig("filename.png")#PNG, JPG, EPS, SVG, PGF e PDF # método savefig da classe Figure

# %%
fig.savefig("filename.png", dpi=200)#especificar o DPI e escolher entre diferentes formatos de saída:

# %% [markdown]
# # Legends, rótulos e títulos

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2)
ax2.plot(x,x**3)

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2, label = "x^2")
ax2.plot(x,x**3, label = "x^3")

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");
ax2.legend()# ele acha o lugar mais vazio do grafico

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2, label = "x^2")
ax2.plot(x,x**3, label = "x^3")

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");
ax2.legend( loc = 6)# colocar no canto

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2, label = "x^2")
ax2.plot(x,x**3, label = "x^3")

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");
ax2.legend( loc = 'center left')# colocar no canto

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2,"b--", label = "x^2")
ax2.plot(x,x**3, 'g*-',label = "x^3")

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");
ax2.legend( loc = 8)

# %%
fig = plt.figure()
ax2 = fig.add_axes([0,0,1,1])
ax2.plot(x,x**2, label = "x^2",color = "black", alpha=0.5)# alpha=0.5 meio transparente
ax2.plot(x,x**3, 'g*-',label = "x^3",color = "#F31F49")# color pode ser tanto texto quando hexa e sobrescreve o 'g*-'

ax2.set_title("title");
ax2.set_xlabel("x")
ax2.set_ylabel("y");
ax2.legend( loc = 10)
# Out:
# /tmp/ipykernel_9267/380940496.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g*-" (-> color='g'). The keyword argument will take precedence.
#   ax2.plot(x,x**3, 'g*-',label = "x^3",color = "#F31F49")# color pode ser tanto texto quando hexa e sobrescreve o 'g*-'

# %% [markdown]
# ===============   =============
#         Location String   Location Code
#         ===============   =============
#         'best'            0
#         'upper right'     1
#         'upper left'      2
#         'lower left'      3
#         'lower right'     4
#         'right'           5
#         'center left'     6
#         'center right'    7
#         'lower center'    8
#         'upper center'    9
#         'center'          10
#         ===============   =============

# %% [markdown]
# ### Legendas

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()

# %%
# Muitas opções....

ax.legend(loc=1) # Canto superior direito
ax.legend(loc=2) # Canto superior esquerdo
ax.legend(loc=3) # Canto inferior esquerdo
ax.legend(loc=4) # Canto inferior direito

# .. muitas outras opções estão disponíveis

# Mais comum para escolher
ax.legend(loc=0) # deixe matplotlib decidir a localização ideal
fig

# %% [markdown]
# ### Cores com sintaxe semelhante ao MatLab

# %%
# Cor e estilo da linha como MATLAB
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') # linha azul tracejada
ax.plot(x, x**3, 'g--') # linha verde pontilhada

# %% [markdown]
# ### Cores com a cor = parâmetro

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # meio-transparente
ax.plot(x, x+2, color="#8B008B")        # RGB
ax.plot(x, x+3, color="#FF8C00")        # RGB

# %% [markdown]
# ### Linha e estilos de marcadores

# %% [markdown]
# Para alterar a largura da linha, podemos usar o argumento de palavras-chave `linewidth` ou` lw`. O estilo de linha pode ser selecionado usando os argumentos de palavras-chave `linestyle` ou` ls`:

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)
#linewidth = lw
# Possiveis estilos de linha: ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# Traços estilizados
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # Formato: comprimento da linha, comprimento do espaço, ...

# possíveis símbolos de marcador: marcador = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# tamanho e cor do marcador
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ## Intervalo de distância

# %% [markdown]
# Podemos configurar os intervalos dos eixos usando os métodos `set_ylim` e` set_xlim` no objeto do eixo, ou `axis ('tight')` para obter automaticamente faixas de eixos "bem ajustados":

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("intervalos de eixos padrão")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("eixos apertados")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])#limite do eixo y
axes[2].set_xlim([2, 5])#limite do eixo x
axes[2].set_title("distância personalizada dos eixos");

# %% [markdown]
# # Tipos de plots especiais
#
# Existem muitas plots especiais que podemos criar, como, por exemplo, barras, histogramas, gráficos de dispersão e muito mais. A maioria desses tipos de plots, na verdade, criaremos usando seaborn, uma biblioteca de plotagem estatística para o Python. Mas aqui estão alguns exemplos desse tipo de gráficos:

# %%
plt.scatter(x,y)

# %%
from random import sample #biblioteca de numeros aleatorios
data = sample(range(1, 1000), 100)#gera 100 valores no intervalo de 1-1000
data
# Out:
# [834,
#  203,
#  449,
#  399,
#  254,
#  874,
#  72,
#  267,
#  296,
#  798,
#  707,
#  410,
#  801,
#  966,
#  217,
#  572,
#  5,
#  656,
#  69,
#  28,
#  20,
#  581,
#  463,
#  952,
#  157,
#  822,
#  99,
#  405,
#  503,
#  507,
#  108,
#  914,
#  216,
#  884,
#  433,
#  170,
#  147,
#  41,
#  311,
#  266,
#  772,
#  517,
#  674,
#  382,
#  870,
#  592,
#  365,
#  349,
#  694,
#  40,
#  407,
#  371,
#  280,
#  385,
#  13,
#  192,
#  370,
#  550,
#  335,
#  627,
#  518,
#  653,
#  255,
#  262,
#  984,
#  123,
#  381,
#  124,
#  268,
#  937,
#  609,
#  906,
#  752,
#  105,
#  129,
#  701,
#  788,
#  717,
#  974,
#  238,
#  34,
#  451,
#  850,
#  293,
#  636,
#  957,
#  484,
#  587,
#  213,
#  188,
#  522,
#  419,
#  329,
#  480,
#  887,
#  843,
#  32,
#  745,
#  502,
#  579]

# %%
plt.hist(data)
# Out:
# (array([11., 10., 14., 10., 11., 12.,  6.,  8.,  9.,  9.]),
#  array([  5. , 102.9, 200.8, 298.7, 396.6, 494.5, 592.4, 690.3, 788.2,
#         886.1, 984. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)
#         -2.27958896, -1.43083996, -0.85367551, -1.2363519 , -3.53761959,
#         -1.82395084, -0.59290599,  3.62035377, -0.32691397, -1.10832134,
#         -2.72849368,  2.34421098, -2.59503876,  0.9795256 ,  0.15576244,
#          1.98797495,  5.54142049,  0.221386  , -1.72266135, -1.91299787,
#         -2.87638298,  0.52054515,  0.4517997 , -0.41511553,  0.02296849,
#         -3.34348856, -2.28330584,  1.04743819,  0.48019737,  0.82788971,
#         -1.58183317,  2.26235087, -3.13287086, -1.67140525,  2.49586342]),
#  array([-2.16586093e+00, -4.77178289e-01,  2.51451329e+00,  6.45958645e-01,
#         -1.01762988e+00,  5.05889293e+00,  4.13904604e+00,  3.29211191e+00,
#          2.81825860e+00,  1.69952502e+00,  2.36050390e+00, -1.25646442e-01,
#         -1.98196840e+00, -2.17847687e-01, -1.22637232e+00, -2.14559094e+00,
#          7.87212461e-01,  1.70115323e+00, -2.65127372e-01,  1.92724944e+00,
#          2.13047671e+00,  1.34412606e+00,  6.58482591e+00,  1.32763321e+00,
#         -2.95818694e+00,  3.07192060e-01,  1.66008842e+00, -2.67019675e+00,
#          4.89936816e+00,  8.30255674e-01,  2.35881748e+00, -5.32655266e+00,
#          2.69940268e+00, -4.55224904e+00, -1.05751972e+00, -3.76158937e-01,
#         -1.65887628e+00,  3.27290174e+00,  5.07826145e+00, -1.84891023e+00,
#          1.92748258e+00, -2.90903679e-01, -2.22926077e+00, -1.37648572e+00,
#         -1.09421840e+00,  4.28967825e+00, -2.17881294e+00,  5.99006773e-02,
#         -1.35493835e+00, -6.24829130e+00,  6.07730741e+00,  5.03820452e-01,
#         -3.83328326e+00,  1.09112600e-02,  3.81377887e+00, -7.08447892e+00,
#         -3.81393458e+00,  2.47362064e+00,  3.66697366e+00, -8.39013986e+00,
#         -3.72122411e+00, -2.55992462e+00,  2.51378989e+00,  1.25124847e+00,
#         -1.81996891e+00, -1.17836508e-01,  4.41286159e-01, -2.86980035e+00,
#         -1.85594129e+00, -2.93839131e+00, -9.77183396e-01,  2.59508732e+00,
#         -5.90992658e-01, -5.53173126e+00,  1.13594356e+00, -1.51885852e+00,
#          1.04046709e+00, -2.24671532e+00,  1.47834179e+00, -4.12274785e+00,
#          3.70641508e+00,  3.57031950e+00, -4.95273968e-01, -1.89865842e+00,
#         -7.39440936e+00,  5.17227517e-01,  6.19053676e-01,  3.92704127e+00,
#         -8.65232572e-01,  6.82388193e+00, -1.59457348e+00, -7.61666628e-01,
#         -2.71991557e-03, -5.30620913e-01, -4.56014354e+00, -7.26346469e-01,
#         -6.96807669e-01,  8.65254939e-01,  1.58160749e+00,  4.19799872e+00])]

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]# distribuição normal media = 0 ; desvio padrão std com 100 valores de intervalo

# box plot retangular
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ## Mais leituras...

# %% [markdown]
# * http://www.matplotlib.org - A página web do projeto matplotlib.
# * https://github.com/matplotlib/matplotlib - O código fonte de matplotlib.
# * http://matplotlib.org/gallery.html - Uma grande galeria mostrando diversos tipos de gráficos que Matplotlib pode criar. Altamente recomendado!
# * http://www.loria.fr/~rougier/teaching/matplotlib - Um excelente tutorial sobre a biblioteca.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html -  Outra excelente referência no asssunto.
