# %% [markdown]
# # Plots matriciais
#
# Os gráficos matriciais permitem traçar dados como matrizes codificadas por cores e também podem ser usados para indicar clusters dentro dos dados (mais tarde, na seção de Machine Learning, aprenderemos a formatear dados de cluster).
#
# Comecemos por explorar o mapa térmico e o clutermap de Seaborn:

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ## Heatmap - mapa de calor
#
# Para que um mapa de calor funcione corretamente, seus dados já devem estar em uma forma de matriz e a função sns.heatmap basicamente apenas põe cor pra você. Por exemplo:

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Correlograma
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
# Out:
# <AxesSubplot:>

# %%
flights.pivot_table(index= "year", columns="month", values="passengers")
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"))
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"))
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"), ax = ax)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"), ax = ax,annot= True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"), ax = ax,annot= True,fmt="0.0f")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"), ax = ax,annot= True,fmt="0.0f",linewidths=1)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
fig, ax = plt.subplots(figsize=(20,8))
sns.heatmap(flights.pivot_table(index= "year", columns="month", values="passengers"), ax = ax,annot= True,fmt="0.0f",linewidths=1,cmap ="magma")#outra paleta de cores magma
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ou para os dados dos vôos:

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')
sns.heatmap(pvflights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pvflights,cmap='magma',linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ## clustermap
#
# O clustermap usa agrupamento hierárquico para produzir uma versão em cluster do heatmap. Por exemplo:

# %%
sns.clustermap(pvflights, standard_scale=1)

# %%
sns.clustermap(flights.pivot_table(index= "year", columns="month", values="passengers"))

# %% [markdown]
# Observe agora como os anos e os meses não estão mais em ordem, em vez disso, eles são agrupados por similaridade em valor (contagem de passageiros). Isso significa que podemos começar a inferir coisas desse plot, como agosto e julho sendo semelhantes (faz sentido, uma vez que são ambos os meses de viagem de verão no hemisfério norte)

# %%
# Mais opções para obter a informação um pouco mais clara, como a normalização
sns.clustermap(pvflights,cmap='coolwarm',standard_scale=1)
