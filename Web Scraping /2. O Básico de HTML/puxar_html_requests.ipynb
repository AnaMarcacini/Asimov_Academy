# %%
from bs4 import BeautifulSoup
import requests    # pip install requests

# %%
site_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=&txtLocation=New+York').text
doc = BeautifulSoup(site_text, 'lxml')

# %%
print(doc)
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.9" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript"></script>
# <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
# <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=&amp;txtLocation=New+York/&amp;sequence=2&amp;startPage=1" rel="next"/>
# <title>Jobs  in New York  - TimesJobs</title>
# <meta content="Jobs  in New York . Search and apply jobs online at Timesjobs.com" name="description"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');</script>
# <!-- End Google Tag Manager -->
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script>
#           //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#         </script>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8137430087055934"></script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="wfe3las4pmeawzwv6sbq-f-8c28b537b-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":2,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"da97e9e","ak.r":46670,"ak.a2":n,"ak.m":"","ak.n":"essl","ak.bpcip":"177.73.181.0","ak.cport":46859,"ak.gh":"92.123.3.41","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1725297795","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"10","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <div id="site">
# <!-- Header Starts -->
# <!-- Google Tag Manager (noscript) -->
# <!-- <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript> -->
# <!-- End Google Tag Manager (noscript) -->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- <meta name="google-adsense-account" content="ca-pub-6237678872163755" />
#  -->
# <script src="https://wchat.freshchat.com/js/widget.js" type="text/javascript"></script>
# <script>
# window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#
# </script>
# <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
# <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript"></script>
# <div class="msg notify" id="fb_connect_suggest" style="display: none;">
# 		Dear Jobseeker, Find millions of jobs on single click.
# 		<span id="fb_auto_connect"><a href="javascript:fconnect_auto();"><img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/></a></span>
# <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide"><i class="material-icons">close</i></span>
# <span id="fb_connect_status"></span>
# </div>
# <div class="msg success" id="fb_connect_success" style="display: none;">
# 			Congratulations! You have been logged in via Facebook
# 		</div>
# <header class="main-header">
# <div class="top-header">
# <div class="ubility-wrap clearfix">
# <ul class="top-link">
# <li><a class="link-active" href="https://www.timesjobs.com">TimesJobs</a></li>
# <li><a href="http://jobbuzz.timesjobs.com" target="_blank">JobBuzz</a></li>
# <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
# <li><a href="https://ae.timesjobs.com" target="_blank">Gulf Jobs</a></li>
# <li><a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">Career Insight</a></li>
# </ul>
# <ul class="top-contact">
# <li><i class="material-icons">call</i>0120 6358222</li>
# <li>
# <span class="live-chat" id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();">Live Chat (10am to 6pm IST)</span>
# </li>
# </ul>
# </div>
# </div>
# <div class="ubility-wrap logo-section clearfix">
# <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
# <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
# </a>
# <script type="text/javascript">
# 				jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
# 			</script>
# <ul class="main-tj-nav clearfix">
# <script type="text/javascript">
# var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#
# </script>
# <!--- view notification section begin --->
# <li class="notification viewnote">
# <a class="dropdown-button" data-activates="notifyDropdown" href="#">
# <i class="material-icons left">notifications_none</i>
# <span class="notif-count-new" id="notification_count">1</span>
# 	</a>
# <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
# <div class="showdiv">
# <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
# <div class="notif-welcm-msg clearfix">To see all recommended jobs, profile views, recruiter's contacted information, updates and more...</div>
# <div class="notif-act clearfix">
# <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">Login</button>
# <strong class="or">or</strong>
# <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">Register</a>
# </div>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-login-frm" id="inline_login" style="display:none;">
# <span class="notif-cls" title="Click to Hide"></span>
# <strong>Login to View Notifications!</strong>
# <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
# <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
# <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
# <input class="clearNotification" size="42" type="text" value="Enter Password"/>
# <div class="frgt-pass"><a class="fp" href="javascript:forgotPasswordNotification();">Forgot Password?</a></div>
# <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
# <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
# <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
# <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#        	      Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
# 	      </div>
# <input name="notlogin" type="hidden" value="mytj"/>
# <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
# </form>
# </div>
# <!-- INLINE LOGIN PAGE -->
# <div class="notif-main" id="base" style="display: none;">
# <ul>
# <li class="heading clearfix" id="heading">
# <a href="#" id="heading-link"><span>Job Alerts(10)</span></a>
# </li>
# <li id="base-li" style="display: none;"><a href="#" id="base-li-anchor">5 Matching Jobs <span id="base-li-time">3 hrs ago</span></a>
# </li>
# <span class="base_li" id="base-li-data" style="display: none;"></span>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <!--- view notification section ends here --->
# <script type="text/javascript">
#
# function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1725297795-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#
# </script>
# <li class="login-reg">
# <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">Login</a>
# </li>
# <li class="login-reg">
# <a href="/candidate/register.html?pageFlow=TJ_SEARCH">Register</a>
# </li>
# </ul>
# </div>
# </header>
# <!--bottom banner starts-->
# <!--bottom banner ends-->
# <div class="open-search">
# <div class="usability-srch clearfix">
# <div class="main-srch-form clearfix">
# <div class="msg error" id="errorMsgDiv" style="display:none">Please provide inputs for at least one field</div>
# <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
# <input name="searchType" type="hidden" value="personalizedSearch"/>
# <input name="from" type="hidden" value="submit"/>
# <input id="searchTextSrc" name="searchTextSrc" type="hidden" value=""/>
# <input id="searchTextText" name="searchTextText" type="hidden" value=""/>
# <div class="auto-suggest-blk">
# <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="Enter Skills, Designation, etc"/>
# <div id="autoSuggestList" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestList" style="display:none;"></iframe>
# <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
# <h5>Suggested Keywords</h5>
# <ul></ul></div>
# </div>
# <div class="auto-suggest-blk location-srch">
# <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="New York"/><div id="autoSuggestLocation" style="display:none;"><ul></ul></div><iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none"></iframe></div>
# <div class="srch-select">
# <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
# <option value="-1">Experience</option>
# <option value="0">Entry Level</option>
# <option value="1">1 year</option>
# <option value="2">2 years</option>
# <option value="3">3 years</option>
# <option value="4">4 years</option>
# <option value="5">5 years</option>
# <option value="6">6 years</option>
# <option value="7">7 years</option>
# <option value="8">8 years</option>
# <option value="9">9 years</option>
# <option value="10">10 years</option>
# <option value="11">11 years</option>
# <option value="12">12 years</option>
# <option value="13">13 years</option>
# <option value="14">14 years</option>
# <option value="15">15 years</option>
# <option value="16">16 years</option>
# <option value="17">17 years</option>
# <option value="18">18 years</option>
# <option value="19">19 years</option>
# <option value="20">20 years</option>
# <option value="21">20+ years</option>
# </select>
# </div>
# <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">Find Jobs</button>
# </form>
# </div>
# <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;"></div>
# <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
# <div class="upload-res-txt clearfix">
# <span class="upload-icon"></span>
# <div class="upload-res-input">
# <h5>New to Timesjobs?</h5>
# <label class="upload-res-btn" id="uploadResume_basic">
#           upload your resume
#           <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
# </label>
# <span id="uploadingResume_basic" style="display:none"><img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/></span>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# $(document).ready(function(){
#
# 		jQuery("#txtKeywords").blur(function() {
# 			let txtKeywordsValue__ = 'Enter Skills, Designation, etc';
# 			let txtKeywords__ = $('#txtKeywords').val();
# 			if(txtKeywordsValue__ === txtKeywords__){
# 				return ;
# 			}
# 			let searchTextText__ = $('#searchTextText').val();
# 			let searchTextSrc__ = $('#searchTextSrc').val();
#
# 			console.log(' .......... txtKeywords__ : '+txtKeywords__);
# 			console.log(' .......... searchTextText__ : '+searchTextText__);
#
#
# 			// if skill box is not empty
# 			if(txtKeywords__ != undefined && txtKeywords__.trim() != ''){
# 				// if autosuggest-skill is empty and skill-box is not empty, is free-text
# 				if(searchTextText__ === undefined || searchTextText__.trim() === ''){
# 					$('#searchTextSrc').val('ft');
# 					//console.log(' ......... set ft 1')
# 				// if skill-box is not empty and autosuggest-skill is not empty and skill-box and autosuggest-skill don't match
# 				}else if(searchTextText__ != undefined && searchTextText__.trim() != '' && searchTextText__ != txtKeywords__){
# 					$('#searchTextSrc').val('ft');
# 					//console.log(' ......... set ft 2')
# 				}
# 			}
#
#
#
# 		});
# 	});
#
#
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
#
# 			that1_ = that.trim().split(' ');
# 			if(that1_.length > 1){
# 				that1_ = '"'+that+'"';
# 			}else{
# 				that1_ = that;
# 			}
#
# 			try{
# 				var s_ = $('#searchTextText').val();
# 				$('#searchTextText').val(s_ + ","+ that1_.trim());
# 				s_ = '';
# 			}catch(ex){
# 				console.log(ex)
# 			}
#
#
#
# 			jQuery("#txtKeywords").val(text +","+ that1_);
# 			jQuery("#txtKeywords").focus();
# 			that1_ ='';
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#   </script>
# </div>
# <script>
# var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
# </script>
# <script type="text/javascript">
#
# //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#
# </script>
# <script type="text/javascript">
#
# if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
# </script>
# <script type="text/javascript">
# 		$(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
# 	</script>
# <script>
# 	jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
# </script>
# <!-- Header Ends -->
# <!-- Content Starts   -->
# <div class="ubility-wrap clearfix">
# <!--Cluster related page inclusion start here-->
# <!--Cluster related page inclusion end here-->
# <section class="ubility-lhs clearfix">
# <div class="inside-lhs" id="search-result-cluster">
# <div class="wht-bdr-bx tj-cluster">
# <h4><i class="filter-icons"></i> All Filters</h4>
# <!--  <div id="clusterRefineHistoryId"></div>-->
# <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#       <li class="tab-exp" id="tab-exp"><a href="#tabexp">Experience</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
# <div id="tj-tab-container-clusterId">
# <div id="clusterDataInitial">
# <ul class="search-filter">
# <li id="tabtc">
# <div class="collapsible-header active"><h6>Companies</h6></div>
# <div class="cluster-scroll">
# <ul>
# <div id="comp_show">
# <li>
# <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=moody%27s+corporation&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=moody%27s+corporation&amp;gadLink=View Jobs By This Company','Moody's Corporation');" type="checkbox"/>
# <label for="com_0">
# <span title="Moody's Corporation">
# 	                Moody's Corpora..
# 	                </span> <span class="grey-text">(31)</span></label>
# </li>
# <li>
# <input id="com_1" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=veeva+systems&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=veeva+systems&amp;gadLink=View Jobs By This Company','Veeva Systems');" type="checkbox"/>
# <label for="com_1">
# <span title="Veeva Systems">
# 	                Veeva Systems
# 	                </span> <span class="grey-text">(22)</span></label>
# </li>
# <li>
# <input id="com_2" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=ion+trading+india+pvt.+ltd.&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=ion+trading+india+pvt.+ltd.&amp;gadLink=View Jobs By This Company','Ion Trading India Pvt. Ltd.');" type="checkbox"/>
# <label for="com_2">
# <span title="Ion Trading India Pvt. Ltd.">
# 	                Ion Trading Ind..
# 	                </span> <span class="grey-text">(18)</span></label>
# </li>
# <li>
# <input id="com_3" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=alphasense&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=alphasense&amp;gadLink=View Jobs By This Company','Alphasense');" type="checkbox"/>
# <label for="com_3">
# <span title="Alphasense">
# 	                Alphasense
# 	                </span> <span class="grey-text">(8)</span></label>
# </li>
# <li>
# ...
#
# 		}
# 		function googleOneTapLogin(jwt){
#
# 			var context="/candidate/";
# 			jQuery.ajax({
#  					url:context + "googleonetaplogin.json?source=gTap&jwt="+jwt+"&curl="+encodeURIComponent(window.location.href),
#  					beforeSend:function(){
# 						console.log("beforeSend... googleonetaplogin");
# 						},
# 					success:function(jsonResp){
#    	 					 console.log('success ... googleonetaplogin : ',jsonResp)
#    	 					 if(jsonResp != null && jsonResp["rurl"] != null){
# 					   	 	window.location.href = jsonResp["rurl"];
#    	 					 }
# 						},
# 					complete:function(){
# 						console.log("complete... loadBannerCampaigns");
# 					}
#  				});
# 		}
#
# </script>
# <div class="modalwrap" id="modalwrap" style="display: none;">
# <div class="zindex loggedin_gmail">
# <div data-auto_prompt="false" data-client_id="819793255355-3574gl7e6o6pkq7cc46dedolg7hae69k.apps.googleusercontent.com" data-login_uri="https://social.timesjobs.com/harvest/callback.html?pId=ggl&amp;apc=tj" data-param1="any_value_1" data-param2="any_value_2" id="g_id_onload">
# </div>
# <span class="_login-pointer">
# <svg fill="none" height="162" viewbox="0 0 166 162" width="166" xmlns="http://www.w3.org/2000/svg">
# <path d="M10.9536 121.632C9.18704 98.2792 19.7831 71.1014 45.7116 66.9675C57.7636 65.0261 71.1034 70.4703 77.3043 81.2384C82.1152 89.5968 79.105 100.525 68.408 100.595C64.6947 100.481 61.0627 99.4795 57.8152 97.6752C54.5677 95.8709 51.799 93.316 49.7401 90.2236C33.8821 66.7456 61.036 44.6484 82.2698 40.9457C106.898 36.6232 132.221 45.559 149.884 62.8212C152.45 65.3223 156.561 61.5664 153.996 59.0653C134.84 40.3518 107.627 30.8122 80.9956 35.5246C59.3008 39.3371 37.1508 56.1104 40.1948 80.479C40.846 85.6727 42.8749 90.5976 46.0711 94.7428C49.2673 98.888 53.5144 102.103 58.3718 104.053C66.2422 107.224 77.528 107.258 83.0163 99.6773C89.3553 91.0395 83.7398 78.8803 77.2158 72.1079C73.563 68.3837 69.1656 65.4719 64.3109 63.5629C59.4561 61.6539 54.2533 60.7905 49.0421 61.0292C18.3578 62.5281 3.31383 94.1729 5.39542 121.466C5.66604 124.985 11.2255 125.21 10.9536 121.632Z" fill="white"></path>
# <path d="M139.964 37.2776C145.036 45.5849 149.617 54.1822 153.684 63.0255L155.52 59.032C144.221 61.0458 133.121 64.0504 122.349 68.011C119.038 69.2389 120.284 74.69 123.623 73.432C134.387 69.465 145.482 66.4585 156.777 64.4475C157.189 64.3463 157.573 64.1534 157.9 63.8831C158.227 63.6128 158.489 63.2721 158.666 62.8865C158.843 62.5009 158.931 62.0803 158.922 61.656C158.914 61.2318 158.81 60.8148 158.619 60.4363C154.574 51.6024 150.016 43.0125 144.97 34.7104C143.114 31.6717 138.162 34.2553 140.052 37.305L139.964 37.2776Z" fill="white"></path>
# </svg>
# </span>
# <div style="z-index: 1; position: relative;">
# <span><img alt="TechGig" src="/images_cand/tj_images/usability/timesjobs-white-logo.png" style="height:17px;"/> </span>
# <h2 class="google_login_head">
# 	Unlock Your Potential:<br/> Find Your Dream Job Today!</h2>
# <ul class="info-list">
# <li>2 Lakh+ Jobs</li>
# <li>25K+ recruiters</li>
# <li>FREE and Unlimited applies</li>
# </ul>
# </div>
# </div>
# </div>
# <!-- Footer Ends   -->
# <script type="text/javascript">
#         var GB_ROOT_DIR = "/candidate/greybox/";
#     </script>
# <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.9" type="text/javascript"></script>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
# <script type="text/javascript">
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#
#
# </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script type="text/javascript">
# /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
# </script>
# <script type="text/javascript">
# 	jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
# </script>
# <script type="text/javascript">
# 	function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
# 	</script>
# <script type="text/javascript">
#
# var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
# </script>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "applicantLocationRequirements": { "@type": "Country", "name": "-" },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
# </script>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
# </script>
# <!--Common Template Included in all files end here  -->
# <!--google analytics start-->
# <!--  New Code of GA 4 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-Z15Q1G661Y"></script>
# <!--  New Code of GA 4 -->
# <script type="text/javascript">
# 	var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
# </script>
# <!--  New Code of GA 4 -->
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-Z15Q1G661Y');
#
#   var banner_custom_params = {
# 		  campaign_name : "tesCompanyName",
# 		  campaign_action : "tesCompanyName_Impression"
#    };
#
#   var banner_custom_params1 = {
# 		  campaign_name : "tesCompanyName1",
# 		  campaign_action : "tesCompanyName1_Impression"
#    };
#
#  /*  gtag('event', 'banner_performance', window.banner_custom_params);
#
#   gtag('event', 'banner_performance', window.banner_custom_params1);
#  */
#   </script>
# <!--  New Code of GA 4 -->
# <!--google analytics ends-->
# <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
# <script type="text/javascript">
#
# 	function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
# </script>
# </div>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript"></script>
# <div class="modal" id="light-box-popup">
# <span class="material-icons close-modal modal-action modal-close">close</span>
# <div class="modal-content" id="light-box-popup-content"></div>
# </div>
# <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
# <!--  ##########################  JobBuzz Ads  ################## -->
# </section></div></div></body>
# </html>

# %%
trabalho = doc.find('li', class_='clearfix job-bx wht-shd-bx')

# %%
print(trabalho.text)
# Out:
#       Content Analyst
#
#     AlphaSense
#
#
#
#
# card_travel0 - 4 yrs
#
# location_on
# New York City
#
#
#
#
# Job Description:
# About AlphaSense:AlphaSense is a market intelligence and search platform used by the world's leading companies and financial institutions. Since 2011, our AI-based technology ... More Details
#
#
# KeySkills:
#
#
#           content analysis  ,  communication skills  ,  analytical skills  ,  troubleshooting  ,  research skills  , press , written communication
#
#
#
#
#
#
#
# Apply
#
#
#
#
# Posted 2 days ago

# %%
doc.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>\n  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>\n  <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">\n  </script>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript">\n  </script>\n  <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->\n  <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript">\n  </script>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript">\n  </script>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.9" type="text/javascript">\n  </script>\n  <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript">\n  </script>\n  <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>\n  <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=&amp;txtLocation=New+York/&amp;sequence=2&amp;startPage=1" rel="next"/>\n  <title>\n   Jobs  in New York  - TimesJobs\n  </title>\n  <meta content="Jobs  in New York . Search and apply jobs online at Timesjobs.com" name="description"/>\n  <!-- Google Tag Manager -->\n  <script>\n   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n})(window,document,\'script\',\'dataLayer\',\'GTM-59SJDG4\');\n  </script>\n  <!-- End Google Tag Manager -->\n  <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">\n  </script>\n  <script>\n   //google.charts.load(\'current\', {\'packages\':[\'bar\']});\r\n          google.charts.load(\'current\', {packages: [\'corechart\', \'bar\']});\n  </script>\n  <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8137430087055934">\n  </script>\n  <script>\n   !function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appen ...

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.9" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript">
#   </script>
#   <!-- <script type="text/javascript" src="https://code.angularjs.org/1.7.0/angular.min.js"></script> -->
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/angular1.7.0.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/materialize.min.js" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/dwrGroup.js?v=7.1.9" type="text/javascript">
#   </script>
#   <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/mustache.js" type="text/javascript">
#   </script>
#   <link href="https://www.timesjobs.com/candidate/job-search.html" rel="canonical"/>
#   <link href="https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&amp;from=submit&amp;txtKeywords=&amp;txtLocation=New+York/&amp;sequence=2&amp;startPage=1" rel="next"/>
#   <title>
#    Jobs  in New York  - TimesJobs
#   </title>
#   <meta content="Jobs  in New York . Search and apply jobs online at Timesjobs.com" name="description"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-59SJDG4');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript">
#   </script>
#   <script>
#    //google.charts.load('current', {'packages':['bar']});
#           google.charts.load('current', {packages: ['corechart', 'bar']});
#   </script>
#   <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8137430087055934">
#   </script>
#   <script>
#    !function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="C4P83-FLD8C-N9VTA-RP2SP-ZADRK",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"C4P83-FLD8C-N9VTA-RP2SP-ZADRK";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="wfe3las4pmeawzwv6sbq-f-8c28b537b-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"1277284","ak.ai":parseInt("765140",10),"ak.ol":"0","ak.cr":2,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"da97e9e","ak.r":46670,"ak.a2":n,"ak.m":"","ak.n":"essl","ak.bpcip":"177.73.181.0","ak.cport":46859,"ak.gh":"92.123.3.41","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1725297795","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"10","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#   </script>
#  </head>
#  <body>
#   <div id="site">
#    <!-- Header Starts -->
#    <!-- Google Tag Manager (noscript) -->
#    <!-- <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-59SJDG4"
# 		height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript> -->
#    <!-- End Google Tag Manager (noscript) -->
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <!-- <meta name="google-adsense-account" content="ca-pub-6237678872163755" />
#  -->
#    <script src="https://wchat.freshchat.com/js/widget.js" type="text/javascript">
#    </script>
#    <script>
#     window.fcWidget.init({
# token: "d7130618-a917-400b-804c-bdf44d8d178b",
# host: "https://wchat.freshchat.com",
# config: {
# headerProperty: {
# hideChatButton: true
# }
#         }
# });
#    </script>
#    <!--[if IE]>
# <script src="scripts/html5shiv.js"></script>
# <![endif]-->
#    <script src="https://static.timesjobs.com/newtj_js/scripts/ajax-upload.js" type="text/javascript">
#    </script>
#    <div class="msg notify" id="fb_connect_suggest" style="display: none;">
#     Dear Jobseeker, Find millions of jobs on single click.
#     <span id="fb_auto_connect">
#      <a href="javascript:fconnect_auto();">
#       <img alt="fconnect" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/top-facebook-notify.png"/>
#      </a>
#     </span>
#     <span class="big-cls cls-icn" onclick="javascript:ack_fbconnect_cancel();" title="Click to Hide">
#      <i class="material-icons">
#       close
#      </i>
#     </span>
#     <span id="fb_connect_status">
#     </span>
#    </div>
#    <div class="msg success" id="fb_connect_success" style="display: none;">
#     Congratulations! You have been logged in via Facebook
#    </div>
#    <header class="main-header">
#     <div class="top-header">
#      <div class="ubility-wrap clearfix">
#       <ul class="top-link">
#        <li>
#         <a class="link-active" href="https://www.timesjobs.com">
#          TimesJobs
#         </a>
#        </li>
#        <li>
#         <a href="http://jobbuzz.timesjobs.com" target="_blank">
#          JobBuzz
#         </a>
#        </li>
#        <!--<li><a href="http://stepahead.timesjobs.com" target="_blank">Career Services</a></li>
#      <li><a href="http://www.techgig.com" target="_blank">TechGig</a></li> -->
#        <li>
#         <a href="https://ae.timesjobs.com" target="_blank">
#          Gulf Jobs
#         </a>
#        </li>
#        <li>
#         <a href="http://content.timesjobs.com/recruitex?fromsite=tjcand" target="_blank">
#          Career Insight
#         </a>
#        </li>
#       </ul>
#       <ul class="top-contact">
#        <li>
#         <i class="material-icons">
#          call
#         </i>
#         0120 6358222
#        </li>
#        <li>
#         <span class="live-chat" id="chat-widget" onclick="window.fcWidget.open();window.fcWidget.show();">
#          Live Chat (10am to 6pm IST)
#         </span>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="ubility-wrap logo-section clearfix">
#      <a class="top-tj-logo" href="https://www.timesjobs.com" itemprop="url" title="TIMESJOBS">
#       <img alt="TimesJobs" height="23" itemprop="logo" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/tj-logo-new.png" title="TimesJobs" width="140"/>
#      </a>
#      <script type="text/javascript">
#       jQuery(document).ready(function() {
# 					jQuery("#career-affection").show();
# 					jQuery("#career-affection-rhs").show();
# 				})
#      </script>
#      <ul class="main-tj-nav clearfix">
#       <script type="text/javascript">
#        var notification_timeout = 10000;
# var notification_cache = true;
# if (!window.console) console = {log: function() {}};
#
# if(typeof String.prototype.trim !== 'function') {
#   String.prototype.trim = function() {
#     return this.replace(/^\s+|\s+$/g, '');
#   }
# }
#
#
# /* This function is used to set cookies */
# function setCookie(name,value,expires,path,domain,secure) {
#   document.cookie = name + "=" + escape (value) +
#     ((expires) ? "; expires=" + expires.toGMTString() : "") +
#     ((path) ? "; path=" + path : "") +
#     ((domain) ? "; domain=" + domain : "") + ((secure) ? "; secure" : "");
# }
#
# /* This function is used to get cookies */
# function getCookie(name) {
# 	var prefix = name + "=" ;
# 	var start = document.cookie.indexOf(prefix);
#
# 	if (start==-1) {
# 		return null;
# 	}
#
# 	var end = document.cookie.indexOf(";", start+prefix.length);
# 	if (end==-1) {
# 		end=document.cookie.length;
# 	}
#
# 	var value=document.cookie.substring(start+prefix.length, end) ;
# 	return unescape(value);
# }
#
#
# function deleteCookie(name,path,domain) {
#   if (getCookie(name)) {
#     document.cookie = name + "=" +
#       ((path) ? "; path=" + path : "") +
#       ((domain) ? "; domain=" + domain : "") +
#       "; expires=Thu, 01-Jan-70 00:00:01 GMT";
#   }
# }
#
# var authenticated = 'false';
#
# jQuery(document).ready(function(){
# var alreadyCalled = false;
#
# //alert("logged-in:"+authenticated);
# //alert("comparison to true, for"+authenticated +", "+ ('true' == authenticated));
#
# if('true' == authenticated){
# 	//jQuery(".viewnoteTab").mouseout(function(){
# //	  jQuery(".showdiv").hide();
# //	});
# //	jQuery(".viewnoteTab").mouseenter(function(){
# //	  jQuery(".showdiv").show();
# //	});
# 	//alert("logged in ");
# }else{
# 	//alert("not logged in ");
# 	jQuery(".notif-cls").on("click",function(){
# 		//alert('hi');
# 	  jQuery("#inline_login").hide();
# 	  //jQuery(".notification .nav-drop").hide();
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# 	updateNonLoggedInUsersTime();
# }
# function updateNonLoggedInUsersTime(){
# 	//alert("non_loggedin_time:"+getCookie('non_loggedin_time'));
# 	var setCookieForTime = getCookie('non_loggedin_time');
# 	if(null!=setCookieForTime){
# 		//alert("cookie found to be set to : "+setCookieForTime+" where time since is:"+timeSince(setCookieForTime));
# 		jQuery("#non_loggedin_time").html(timeSince(setCookieForTime));
# 	}else{
# 		var currentTime = new Date().getTime();
# 		setCookie('non_loggedin_time',currentTime);
# 	}
# }
#
# jQuery(".viewnote").on("click",function(){
# 	var loggedInClicked = getCookie('loggedin_click');
# 	if(null!=loggedInClicked){
# 		jQuery("#notification_count").css("background-color","#075DC1");
# 	}else{
# 		if('true' == authenticated){
# 			setCookie('loggedin_click',1);
# 			//alert("setting loggedInClicked");
# 		}
# 	}
# });
#
# });
#       </script>
#       <!--- view notification section begin --->
#       <li class="notification viewnote">
#        <a class="dropdown-button" data-activates="notifyDropdown" href="#">
#         <i class="material-icons left">
#          notifications_none
#         </i>
#         <span class="notif-count-new" id="notification_count">
#          1
#         </span>
#        </a>
#        <div class="nav-drop viewnoteTab dropdown-content" id="notifyDropdown">
#         <div class="showdiv">
#          <div class="notif-not-logedin" id="non_loggedin" style="display:none;">
#           <div class="notif-welcm-msg clearfix">
#            To see all recommended jobs, profile views, recruiter's contacted information, updates and more...
#           </div>
#           <div class="notif-act clearfix">
#            <button class="waves-effect waves-light btn red-bdr-btn" onclick="javascript:openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');" type="button">
#             Login
#            </button>
#            <strong class="or">
#             or
#            </strong>
#            <a class="waves-effect waves-light btn red-bdr-btn" href="/candidate/register.html">
#             Register
#            </a>
#           </div>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-login-frm" id="inline_login" style="display:none;">
#           <span class="notif-cls" title="Click to Hide">
#           </span>
#           <strong>
#            Login to View Notifications!
#           </strong>
#           <form action="/candidate/times_login?BeforeLoginUrl=notification&amp;tab=1" method="post" name="loginFormNotification">
#            <input class="txt2 defaultValue inpt-typ" id="txtUseNameNotification" name="j_username" onblur="javascript:settextNotification('txtUseNameNotification');" onclick="filltxtNotification(txtUseNameNotification)" size="42" type="text" value="Enter Email id / Login id"/>
#            <input class="password_input_notification" name="j_password" size="42" style="display:none" type="password" value=""/>
#            <input class="clearNotification" size="42" type="text" value="Enter Password"/>
#            <div class="frgt-pass">
#             <a class="fp" href="javascript:forgotPasswordNotification();">
#              Forgot Password?
#             </a>
#            </div>
#            <input class="" onclick="javascript:return validateLoginFormNotification();" type="submit" value="Login"/>
#            <div class="error-msg dflt-msg" id="loginErrNotification" style="display:none;">
#             <!--<img class="errTip" title="Error" alt="Error" src="https://static.timesjobs.com/images_cand/tj_images/home/errTipL.gif">-->
#             <!--<a class="errCls" href="#"><img border="0" title="Close" alt="Close" src="/images_cand/tj_images/home/logginErrClse.gif"></a>-->
#             Login-ID/Password cannot be left blank. Enter the full email ID (like: ram@gmail.com), if you are using registered email-id for login.
#            </div>
#            <input name="notlogin" type="hidden" value="mytj"/>
#            <input name="_acegi_security_remember_me" type="hidden" value="yes"/>
#           </form>
#          </div>
#          <!-- INLINE LOGIN PAGE -->
#          <div class="notif-main" id="base" style="display: none;">
#           <ul>
#            <li class="heading clearfix" id="heading">
#             <a href="#" id="heading-link">
#              <span>
#               Job Alerts(10)
#              </span>
#             </a>
#            </li>
#            <li id="base-li" style="display: none;">
#             <a href="#" id="base-li-anchor">
#              5 Matching Jobs
#              <span id="base-li-time">
#               3 hrs ago
#              </span>
#             </a>
#            </li>
#            <span class="base_li" id="base-li-data" style="display: none;">
#            </span>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </li>
#       <!--- view notification section ends here --->
#       <script type="text/javascript">
#        function forgotPasswordNotification(){
# 		GB_showCenter('Forgot Password','/candidate/ForgetPassword.html',180,420);
# 	}
# var race = 0;
# function showNotificationLoginThickBox(){
#
# race = 1;
#
# 			//jQuery("#inline_login").addClass('notifyshow');
# 			//jQuery('.viewnoteTab').addClass('notifyshow');
# 			//jQuery('.showdiv').addClass('notifyshow');
# 			//jQuery(".notif-not-logedin").hide();
# 			//jQuery(".notification .nav-drop").css('display','block');
# 			//jQuery(".notification").addClass("notifi");
# 			jQuery('.clearNotification').css({color:"#b3b3b3"});
# 					jQuery('.clearNotification').focus(function(){
# 						//alert('check');
# 						jQuery(this).hide();
# 						jQuery(' .password_input_notification').show();
# 						jQuery('.password_input_notification').focus();
# 					});
# 					jQuery('.password_input_notification').blur(function(){
# 						if(this.value==''){
# 						jQuery(this).hide();
# 							jQuery('.clearNotification').show();
# 						}
# 					});
#
#
#
# }
# jQuery(".notif-cls").on("click",function(){
# 	  //jQuery("#inline_login").removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.viewnoteTab').removeClass('notifyshow');
# 	  //jQuery("#inline_login").parents('.showdiv').removeClass('notifyshow');
#
# 	 // jQuery(".notif-not-logedin").show();
# 	 jQuery(".notif-not-logedin").css('display','');
# 	  //jQuery(".notification .nav-drop").css('display','none');
# 	  jQuery(".notification").removeClass("notifi");
# 	});
# jQuery(".viewnote").mouseenter(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").show();
#   //jQuery(".notification .nav-drop").show();
#
#   if('false' == authenticated){
#     var hideCountCookie = getCookie('hide_nologgedin_count');
#     if(null == hideCountCookie){
#   		setCookie('hide_nologgedin_count',1);
#   		//alert("setting hide_nologgedin_count");
#   	}else{
#   		jQuery("#notification_count").hide();
#   	}
#   }else{
#    jQuery("#inline_login").hide();
#    jQuery("#non_loggedin").hide();
#
#    	updateNotificationComponentWithIECheck();
#   }
#
# });
# jQuery(".viewnote").mouseleave(function(){
# //alert("mouseenter called..");
#   //jQuery(".showdiv").hide();
#   //jQuery(".notification .nav-drop").hide();
# });
# jQuery(".notif-login-frm").mouseleave(function(){
# //alert("mouseenter called..");
#   event.stopPropagation()
# });
# function settextNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value !=''){
# 			document.getElementById(id).checked=true;
# 		}else{
# 			document.getElementById(id).checked=false;
# 			document.getElementById('txtUseNameNotification').value='Enter Email id / Login id';
# 			document.getElementById('txtUseNameNotification').style.color='#999'
# 		}
# 	}
# function filltxtNotification(id){
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id')
# 			document.getElementById('txtUseNameNotification').value=''
# 		document.getElementById('txtUseNameNotification').style.color='#333'
# 	}
# function validateLoginFormNotification(){
# var status = true;
# 		if(document.getElementById('txtUseNameNotification').value=='Enter Email id / Login id'){
# 			document.getElementById('txtUseNameNotification').value='';
# 			status =  false;
# 		}
#
# 		if(checkBlankNotification(document.loginFormNotification.j_username,"Login ID")){
# 			status =  false;
# 		}
# 		if(checkBlankNotification(document.loginFormNotification.j_password,"Password")){
# 			status =  false;
# 		}
# 		//update_notification_cookie
# 		if(status){
# 			deleteCookie('update_notification_cookie');
# 		}
# 		return status;
# 	}
# function checkBlankNotification(field,name){
# 		if(field.value.trim() == ""){
# 			field.value = "";
# 			field.focus();
# 			document.getElementById("loginErrNotification").style.display="";
# 			return true;
# 		}
# 		return false;
# 	}
#
# var diff = 1725297795-((new Date().getTime())/1000);
#
#
# function ellipsize(str, len) {
# 	if(str.length > len) {
#  		return str.substr(0,len) + "...";
# 	} else {
# 		return str;
# 	}
# }
#
# function timeSince(previous){
#
# 	current =  new Date().getTime()+diff;
# 	var milleSecondsPerMinute = 60 * 1000;
#     var milleSecondsPerHour = milleSecondsPerMinute * 60;
#     var milleSecondsPerDay = milleSecondsPerHour * 24;
#     var milleSecondsPerMonth = milleSecondsPerDay * 30;
#     var milleSecondsPerYear = milleSecondsPerDay * 365;
#
#     var elapsed = current - previous;
#
#     if (elapsed < milleSecondsPerMinute) {
#          value = Math.round(elapsed/1000) + ' seconds ago';
#     }
#
#     else if (elapsed < milleSecondsPerHour) {
#     	value = Math.round(elapsed/milleSecondsPerMinute) + ' minutes ago';
#     }
#
#     else if (elapsed < milleSecondsPerDay ) {
#     	value = Math.round(elapsed/milleSecondsPerHour ) + ' hours ago';
#     }
#
#     else if (elapsed < milleSecondsPerMonth) {
#     	value =  Math.round(elapsed/milleSecondsPerDay) + ' days ago';
#     }
#
#     else if (elapsed < milleSecondsPerYear) {
#     	value = Math.round(elapsed/milleSecondsPerMonth) + ' months ago';
#     }
#
#     else {
#     	value = Math.round(elapsed/milleSecondsPerYear ) + ' years ago';
#     }
#     //return (value);
#     return (value);
# }
#
#
# function updateNotificationComponent(){
#  alreadyCalled  =true;
# 	var context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  context="/candidate/";
# 		  //alert("bingo");
# 	}
#
#
# 	ajaxController.getLoginId(function(response){
# 	//alert("updateNotificationComponent,response:"+response)
# 		if (response != null && response.trim().length > 0) {
# 			jQuery.ajax({
# 							cache:notification_cache,
# 							timeout:notification_timeout,
# 							url:context+"inbox-notifications.html?from=submit",
# 							success:function(data){
# 							var trimLength = 30;
# 									jQuery("#base_ja").remove();
# 									jQuery("#base_j").remove();
# 									jQuery("#base_rv").remove();
# 									//alert(data);
# 									var parsedData = JSON.parse(data);
# 									var theCount = parsedData["count"];
#
# 									var jaCount = parsedData["jaCount"];
# 									var jCount = parsedData["jCount"];
# 									var rvCount = parsedData["rvCount"];
#
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
# 									//theCount = theCount - jCount;
# 									/**
# 									*UNTILL Resume Contacted is pulled down do the following:
# 									*/
#
# 									if(theCount >= 0){
# 										if(theCount >= 0){
# 											if(theCount <99){
# 												jQuery("#notification_count").html(theCount);
# 												setCookie('notification_cookie_count',theCount);
# 											}else{
# 												jQuery("#notification_count").html("99+");
# 												setCookie('notification_cookie_count',"99+");
# 											}
# 										}
#
# 										var isNew = parsedData["new"];
# 										//alert("new:"+(isNew == true));
# 										if(isNew == true){
# 											jQuery("#notification_count").css("background-color","red");
# 											setCookie('notification_cookie_color','red');
# 											deleteCookie('loggedin_click');
# 										}else{
# 											var loggedInClicked = getCookie('loggedin_click');
# 											//alert("loggedInClicked:"+loggedInClicked);
# 											if(null!=loggedInClicked){
# 												jQuery("#notification_count").css("background-color","#075DC1");
# 												setCookie('notification_cookie_color','#075DC1');
# 											}else{
# 												jQuery("#notification_count").css("background-color","red");
# 												setCookie('notification_cookie_color','red');
# 											}
#
# 										}
# 									}
# 									jQuery("#notification_count").show();
#
# 									/* alert("count:"+parsedData["count"]);
# 									alert("jaCount:"+parsedData["jaCount"]);
# 									alert("jCount:"+parsedData["jCount"]);
# 									alert("rvCount:"+parsedData["rvCount"]); */
#
# 									/**
# 									start-JA
# 									*/
# 									if(jaCount){
# 										if(jaCount <25){
# 											jQuery("#base .heading span").html("Job alerts ("+jaCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Job alerts (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Job alerts");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=1&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jaData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jaData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jaData"])[i].subject;
# 										var since = timeSince(JSON.parse(parsedData["jaData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=1&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_ja_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_ja");
# 									//alert("jaData[0]:"+ (JSON.parse(parsedData["jaData"]).length));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-JA
# 									*/
#
# 									/**
# 									start-J
# 									*/
# 								   if(jCount){
# 									 	if(jCount <25){
# 											jQuery("#base .heading span").html("Mails from recruiters ("+jCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Mails from recruiters (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Mails from recruiters");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=2&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["jData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["jData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["jData"])[i].EmployerName + " contacted you.";
# 										var since = timeSince(JSON.parse(parsedData["jData"])[i].creationTime);
# 										jQuery("#base-li-anchor").html(ellipsize(subject,trimLength));
# 										jQuery("#base-li-anchor").attr("title",subject);
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=2&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_j_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_j");
# 									//alert("jData[0]:"+timeSince(JSON.parse(parsedData["jData"])[0].creationTime));
# 									jQuery("#base > ul span.base_li").html("");
#
# 									/**
# 									end-J
# 									*/
#
# 									/**
# 									start-RV
# 									*/
# 									if(rvCount > 0){
# 										if(rvCount <25){
# 											jQuery("#base .heading span").html("Who's viewed your profile ("+rvCount+")");
# 										}else{
# 											jQuery("#base .heading span").html("Who's viewed your profile (25+)");
# 										}
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}else{
# 										jQuery("#base .heading span").html("Who's viewed your profile");
# 										jQuery("#base .heading a#heading-link").attr("href",context+"inbox-home.html?tab=5&from=notification");
# 									}
# 									var size =JSON.parse(parsedData["rvData"]).length;
#
# 									for(var i=0;i<size;i++){
# 										var id = JSON.parse(parsedData["rvData"])[i].notificationId;
# 										var subject = JSON.parse(parsedData["rvData"])[i].subject;
# 										var employerName = JSON.parse(parsedData["rvData"])[i].EmployerName + " viewed your resume.";
# 										var since = timeSince(JSON.parse(parsedData["rvData"])[i].creationTime);
# 										if(null!=employerName && employerName.length > 0){
# 											jQuery("#base-li-anchor").html(ellipsize(employerName,trimLength));
# 											jQuery("#base-li-anchor").attr("title",employerName);
# 										}else{
# 											jQuery("#base-li-anchor").html("Resume Viewed");
# 										}
# 										jQuery("#base-li-anchor").attr("href",context+"inbox-home.html?tab=5&from=notification&showMessage=yes&ObjectId="+id);
# 										jQuery("#base-li-time").html(since);
#
# 										var $clonedLI = jQuery("#base-li").clone();
# 										//$clonedLI.appendTo(".base_li");
# 										$clonedLI.appendTo("#base-li-data");
# 										$clonedLI.attr("id","base_rv_"+i);
# 										$clonedLI.show();
# 									}
# 									jQuery("#base").show();
# 									//alert("DATA:"+$("#base > ul.base_li").html())
# 									var $cloned = jQuery("#base").clone();
# 									$cloned.appendTo(".showdiv");
# 									$cloned.attr("id","base_rv");
# 									//alert("rvData[0]:"+timeSince(JSON.parse(parsedData["rvData"])[0].employerName));
# 									jQuery("#base > ul span.base_li").html("");
# 									/**
# 									end-RV
# 									*/
#
# 									jQuery("#base").hide();
# 									jQuery("li#base-li").hide();
# 								},
# 							complete:function(){
# 								console.log("complete... inbox-notifications");
# 								jQuery("#inline_login").hide();
#    								jQuery("#non_loggedin").hide();
#    								alreadyCalled  = false;
# 							},
# 							error: function(x, t, m) {
# 								console.log("Error message"+m);
# 								 var randomnumber=Math.floor(Math.random()*100000001);
# 								 var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+context+"inbox-notifications.html?from=submit"+'&op=respTracking#'+randomnumber;
# 								 ping(nlpurl);
# 						        jQuery("#error").show();
# 							}
# 						});
#
# 		}else{
# 					jQuery("#base_ja").remove();
# 					jQuery("#base_j").remove();
# 					jQuery("#base_rv").remove();
# 					if(0 == race){
# 						jQuery("#non_loggedin").show();
# 					}
#
#
# 					var hideCountCookie = getCookie('hide_nologgedin_count');
# 					if(null != hideCountCookie){
# 						/*This is commented because for non logged in user default count 1 is being hidden.*/
# 						//jQuery("#notification_count").hide();
# 					}else{
# 						jQuery("#notification_count").css("background-color","red");
# 						jQuery("#notification_count").show();
# 					}
# 					alreadyCalled  = false;
# 		}
# 	});
# }
#
# var updateNotificationCookie = getCookie('update_notification_cookie');
# //alert("updateNotificationCookie: "+updateNotificationCookie);
# if(null == updateNotificationCookie || updateNotificationCookie==''){
# 	updateNotificationComponentWithIECheck();
# 	setCookie('update_notification_cookie',1);
# 	//alert("cookie set");
# 	scheduleNotificationCookieToDie();
# }else{
# 	if('true' == authenticated){
# 		//alert("updating from cookie!!!");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		if(null==notificationCookieCount){
# 			updateNotificationComponent();
# 		}
# 		updateNotificationFromCookie();
# 	}else{
# 		//alert("not updating from cookie!!!");
# 		updateNotificationComponentWithIECheck();
# 	}
# }
#
# function scheduleNotificationCookieToDie(){
# 	setTimeout(function() {
# 	      deleteCookie('update_notification_cookie');
# 	      deleteCookie('notification_cookie_count');
# 	      deleteCookie('notification_cookie_color');
# 	},5*60*1000);
# }
#
# function updateNotificationFromCookie(){
# console.log("cookie set for updateNotificationCookie, not making server call.");
# 		var notificationCookieCount = getCookie('notification_cookie_count');
# 		//alert("not setting cookie"+updateNotificationCookie);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").html(""+notificationCookieCount);
# 		}else{
# 			jQuery("#notification_count").html("1");
# 		}
# 		var notificationCookieColor = getCookie('notification_cookie_color');
# 		//alert("cookie color"+notificationCookieColor);
# 		if(null!=notificationCookieCount){
# 			jQuery("#notification_count").css("background-color",notificationCookieColor);
# 		}else{
# 			jQuery("#notification_count").css("background-color","red");
# 		}
# 		jQuery("#notification_count").show();
# }
#
# function updateNotificationComponentWithIECheck(){
# <!--[if gte IE 9]>
# 		updateNotificationComponent();
# 	<!--<![endif]-->
# 	<!--[if lt IE 9]>
#    		jQuery(document).ready(function() {
# 			updateNotificationComponent();
# 		});
# 	<!--<![endif]-->
# }
#       </script>
#       <li class="login-reg">
#        <a href="javascript:void(0);" onclick="openModal.openLightBoxModal('loginLightboxModal.html?callFrom=header','light-box-popup');">
#         Login
#        </a>
#       </li>
#       <li class="login-reg">
#        <a href="/candidate/register.html?pageFlow=TJ_SEARCH">
#         Register
#        </a>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <!--bottom banner starts-->
#    <!--bottom banner ends-->
#    <div class="open-search">
#     <div class="usability-srch clearfix">
#      <div class="main-srch-form clearfix">
#       <div class="msg error" id="errorMsgDiv" style="display:none">
#        Please provide inputs for at least one field
#       </div>
#       <form action="https://www.timesjobs.com/candidate/job-search.html" id="quickSearchBean" method="get" name="quickSearchBean" onsubmit="return searchEngine.validateSearchForm(this);">
#        <input name="searchType" type="hidden" value="personalizedSearch"/>
#        <input name="from" type="hidden" value="submit"/>
#        <input id="searchTextSrc" name="searchTextSrc" type="hidden" value=""/>
#        <input id="searchTextText" name="searchTextText" type="hidden" value=""/>
#        <div class="auto-suggest-blk">
#         <input class="browser-default" id="txtKeywords" name="txtKeywords" type="text" value="Enter Skills, Designation, etc"/>
#         <div id="autoSuggestList" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestList" style="display:none;">
#         </iframe>
#         <div class="suggestionList srch-suggest" id="autoSuggestList2ndKeywordsListSFB" style="display:none;">
#          <h5>
#           Suggested Keywords
#          </h5>
#          <ul>
#          </ul>
#         </div>
#        </div>
#        <div class="auto-suggest-blk location-srch">
#         <input class="location-srch browser-default" id="txtLocation" name="txtLocation" type="text" value="New York"/>
#         <div id="autoSuggestLocation" style="display:none;">
#          <ul>
#          </ul>
#         </div>
#         <iframe frameborder="0" id="FrameautoSuggestLocation" style="display:none">
#         </iframe>
#        </div>
#        <div class="srch-select">
#         <select class="browser-default" id="cboWorkExp1" name="cboWorkExp1">
#          <option value="-1">
#           Experience
#          </option>
#          <option value="0">
#           Entry Level
#          </option>
#          <option value="1">
#           1 year
#          </option>
#          <option value="2">
#           2 years
#          </option>
#          <option value="3">
#           3 years
#          </option>
#          <option value="4">
#           4 years
#          </option>
#          <option value="5">
#           5 years
#          </option>
#          <option value="6">
#           6 years
#          </option>
#          <option value="7">
#           7 years
#          </option>
#          <option value="8">
#           8 years
#          </option>
#          <option value="9">
#           9 years
#          </option>
#          <option value="10">
#           10 years
#          </option>
#          <option value="11">
#           11 years
#          </option>
#          <option value="12">
#           12 years
#          </option>
#          <option value="13">
#           13 years
#          </option>
#          <option value="14">
#           14 years
#          </option>
#          <option value="15">
#           15 years
#          </option>
#          <option value="16">
#           16 years
#          </option>
#          <option value="17">
#           17 years
#          </option>
#          <option value="18">
#           18 years
#          </option>
#          <option value="19">
#           19 years
#          </option>
#          <option value="20">
#           20 years
#          </option>
#          <option value="21">
#           20+ years
#          </option>
#         </select>
#        </div>
#        <button class="waves-effect waves-light btn" onclick="javascript:setAClickOnSearch();" value="Search">
#         Find Jobs
#        </button>
#       </form>
#      </div>
#      <div class="recent-srchs home-srchptext srch-top-right" id="recentSearchId" style="display: none;">
#      </div>
#      <div class="upload-res-uni srch-top-right clearfix" id="resNewUpload" style="display:none;">
#       <div class="upload-res-txt clearfix">
#        <span class="upload-icon">
#        </span>
#        <div class="upload-res-input">
#         <h5>
#          New to Timesjobs?
#         </h5>
#         <label class="upload-res-btn" id="uploadResume_basic">
#          upload your resume
#          <input id="resumeFile_basic" name="resumeFile_basic" size="25" type="file"/>
#         </label>
#         <span id="uploadingResume_basic" style="display:none">
#          <img alt="Uploading Resume" src="https://static.timesjobs.com/images_cand/tj_images/personlisation/loader.gif"/>
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      $(document).ready(function(){
#
# 		jQuery("#txtKeywords").blur(function() {
# 			let txtKeywordsValue__ = 'Enter Skills, Designation, etc';
# 			let txtKeywords__ = $('#txtKeywords').val();
# 			if(txtKeywordsValue__ === txtKeywords__){
# 				return ;
# 			}
# 			let searchTextText__ = $('#searchTextText').val();
# 			let searchTextSrc__ = $('#searchTextSrc').val();
#
# 			console.log(' .......... txtKeywords__ : '+txtKeywords__);
# 			console.log(' .......... searchTextText__ : '+searchTextText__);
#
#
# 			// if skill box is not empty
# 			if(txtKeywords__ != undefined && txtKeywords__.trim() != ''){
# 				// if autosuggest-skill is empty and skill-box is not empty, is free-text
# 				if(searchTextText__ === undefined || searchTextText__.trim() === ''){
# 					$('#searchTextSrc').val('ft');
# 					//console.log(' ......... set ft 1')
# 				// if skill-box is not empty and autosuggest-skill is not empty and skill-box and autosuggest-skill don't match
# 				}else if(searchTextText__ != undefined && searchTextText__.trim() != '' && searchTextText__ != txtKeywords__){
# 					$('#searchTextSrc').val('ft');
# 					//console.log(' ......... set ft 2')
# 				}
# 			}
#
#
#
# 		});
# 	});
#
#
#   var ssCounterSFB=0;
# 	function openSecondSuggestionSFB(theSelectedSuggestionText){
# 		if(ssCounterSFB < 5){
# 			ajaxController.getSuggestedSkillList(theSelectedSuggestionText,"","SKILL",8,true,cb_openSecondSuggestionSFB);
# 		}else{
# 			console.log("CAND-131 Not showing 2nd suggestion.");
# 		}
# 	}
#
# 	function cb_openSecondSuggestionSFB(result){
# 		//alert("cb_openSecondSuggestion:"+result);
# 		var splitData = (""+result).split(",");
# 		var li_data = "";
# 		var dataLength = splitData.length;
# 	    var text = jQuery("#txtKeywords").val();
# 	    text =text.toLowerCase();
# 	    if(dataLength >1){
# 			for(i=0;i<dataLength;i++){
# 	            if(text.indexOf(splitData[i].toLowerCase()) < 0){
# 	                var hyperlink =  "javascript:secondSelectionClickedSFB('"+encodeURI(splitData[i])+"');";
# 					li_data+="<li><a href="+hyperlink+">"+splitData[i]+"</a></li>";
# 				}
# 			}
# 			jQuery("#autoSuggestList2ndKeywordsListSFB ul").html(li_data);
# 			jQuery("#autoSuggestList2ndKeywordsListSFB").slideDown(300);
# 			//ssCounterSFB = ssCounterSFB  + 1;
# 		}
# 	}
#
# 	function secondSelectionClickedSFB(that){
# 		//alert("that:"+that);
# 		_gaq.push(['_trackEvent','Click2Ad','tj_skillsuggestion']);
# 		jQuery("#autoSuggestList2ndKeywordsListSFB").hide();
# 		var text = jQuery("#txtKeywords").val();
# 		var text2 = text.toLowerCase() + ",";
# 		var that2 = that.toLowerCase();
# 		var res = text2.split(",");
# 		var exists = false;
# 		for(i in res){
# 			if(null!=res[i] && res[i].length > 0 && res[i]+"".trim() === that2){
# 				exists = true;
# 				break;
# 			}
# 		}
# 		//var index = text2.search(new RegExp(that2, "i"));
# 		//console.log("exists:"+exists);
# 		if(!exists){
#
# 			that1_ = that.trim().split(' ');
# 			if(that1_.length > 1){
# 				that1_ = '"'+that+'"';
# 			}else{
# 				that1_ = that;
# 			}
#
# 			try{
# 				var s_ = $('#searchTextText').val();
# 				$('#searchTextText').val(s_ + ","+ that1_.trim());
# 				s_ = '';
# 			}catch(ex){
# 				console.log(ex)
# 			}
#
#
#
# 			jQuery("#txtKeywords").val(text +","+ that1_);
# 			jQuery("#txtKeywords").focus();
# 			that1_ ='';
# 		}
# 		openSecondSuggestionSFB(that);
# 	}
# jQuery(document).ready(function(){
# 	jQuery('#quickSearchBean input[type="text"]').DefaultInputValue();
# })
#
# function BasicResFileUpload(){
# 		//alert('uploaded re loaded');
# 		new AjaxUpload('resumeFile_basic', {
# 			action:'/candidate/servlet/FileUploadServlet',
# 			//responseType: 'json',
# 			responseType: 'true',
# 			name: 'resumeFile_basic',
# 			onSubmit : function() {
# 				//alert('11');
# 				document.getElementById("uploadResume_basic").style.display="none";
# 				document.getElementById("uploadingResume_basic").style.display="block";
# 			},
# 			onComplete : function(file,response){
# 				var displayFilename=file;
# 				if(file.length >18){
# 					displayFilename=file.substring(0,18)+"..";
# 				}
# 				response = response.replace(/'/g , '"');
# 				var jsonObj = jQuery.parseJSON(response);
# 				jsonObj["filename"] = displayFilename;
# 				ajaxController.setSessionAttribute('tjindexResumeUploadMsg', jsonObj["MESSAGE"]);
# 				response = JSON.stringify(jsonObj);
# 				ajaxController.setSessionAttribute('tjindexResumeUpload', response);
# 				//window.open('/candidate/register.html', '_blank');
# 				window.location ='/candidate/register.html';
# 			}
# 		});
# 	}
# 	BasicResFileUpload();
#     </script>
#    </div>
#    <script>
#     var name='null';
# var phone='null';
# var email='null';
# //alert("name"+name);
# //alert("phone Num"+phone);
# if((phone!=null && $.trim(phone).length>0)&& phone.indexOf("+91-")!=-1){
#    phone = phone.replace("+91-",'');
# }
#
# FRESHCHAT_VISITORINFO={"name":name,"email":email,"phone":phone};
#    </script>
#    <script type="text/javascript">
#     //	alert("Hello");
# 	    var fc_CSS = document.createElement('link');
# 	    fc_CSS.setAttribute('rel', 'stylesheet');
# 	    var fc_isSecured = (window.location && window.location.protocol == 'https:');
# 	    var fc_lang = document.getElementsByTagName('html')[0].getAttribute('lang');
# 	    var fc_rtlLanguages = ['ar', 'he'];
# 	    var fc_rtlSuffix = (fc_rtlLanguages.indexOf(fc_lang) >= 0) ? '-rtl' : '';
# 	    fc_CSS.setAttribute('type', 'text/css');
# 	    fc_CSS.setAttribute('href', ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets1.chat.freshdesk.com') + '/css/visitor' + fc_rtlSuffix + '.css');
# 	    document.getElementsByTagName('head')[0].appendChild(fc_CSS);
# 	    var fc_JS = document.createElement('script');
# 	    fc_JS.type = 'text/javascript';
# 	    fc_JS.defer = true;
# 	    fc_JS.src = ((fc_isSecured) ? 'https://d36mpcpuzc4ztk.cloudfront.net' : 'http://assets.chat.freshdesk.com') + '/js/visitor.js';
# 	    (document.body ? document.body : document.getElementsByTagName('head')[0]).appendChild(fc_JS);
# 	    window.freshchat_setting = '...';
#    </script>
#    <script type="text/javascript">
#     if(document.getElementById("chat-widget") != undefined){
# document.getElementById("chat-widget").addEventListener("click", function(event){
#     event.preventDefault()
# });
# }
#    </script>
#    <script type="text/javascript">
#     $(function(){
# 			$('.nav-search').click(function(e){
# 				$('.common-search').slideToggle();
# 			});
# 			 $('.dropdown-button').dropdown({
# 				  inDuration: 300,
# 				  outDuration: 225,
# 				  constrainWidth: false,
# 				  hover: true,
# 				  gutter: 0,
# 				  belowOrigin: false,
# 				  alignment: 'left',
# 				  stopPropagation: false
# 			}
# 		  );
# 		});
#    </script>
#    <script>
#     jQuery(function() {
# 		//bottom banner starts
# 		jQuery('.bot-bnr').append('<span class="up-dwn-arrow"></span><span class="bot-bnr-cls"></span>');
# 		jQuery('.bot-bnr').addClass('bot-bnr-expnd',1000);
# 		setTimeout(function(){
# 		jQuery('.bot-bnr').removeClass('bot-bnr-expnd',1000);}, 5000);
# 		jQuery('.bot-bnr-cls').on("click", function() {
# 		  jQuery(this).parent("div").addClass('bot-bnr-csl',1000);
# 		});
# 		jQuery('.up-dwn-arrow').on("click", function() {
# 		  jQuery(this).parent("div").toggleClass('bot-bnr-expnd',1000);
# 		});
# 		//bottom banner ends
# 	});
#    </script>
#    <!-- Header Ends -->
#    <!-- Content Starts   -->
#    <div class="ubility-wrap clearfix">
#     <!--Cluster related page inclusion start here-->
#     <!--Cluster related page inclusion end here-->
#     <section class="ubility-lhs clearfix">
#      <div class="inside-lhs" id="search-result-cluster">
#       <div class="wht-bdr-bx tj-cluster">
#        <h4>
#         <i class="filter-icons">
#         </i>
#         All Filters
#        </h4>
#        <!--  <div id="clusterRefineHistoryId"></div>-->
#        <!--
#   <ul class="tab-filter clearfix">
#
#       <li class="tab-tc" id="tab-tc"><a href="#tabtc">Top Companies</a></li>
#
#
#     <li class="tab-jf" id="tab-jf"><a href="#tabjf">Job Function</a></li>
#
#
#       <li class="tab-exp" id="tab-exp"><a href="#tabexp">Experience</a></li>
#
#
#
#       <li class="tab-ind" id="tab-ind"><a href="#tabind">Industry</a></li>
#
#
#
#
#       <li class="tab-sal" id="tab-sal"><a href="#tabsal">Salary</a></li>
#
#   </ul>
# -->
#        <div id="tj-tab-container-clusterId">
#         <div id="clusterDataInitial">
#          <ul class="search-filter">
#           <li id="tabtc">
#            <div class="collapsible-header active">
#             <h6>
#              Companies
#             </h6>
#            </div>
#            <div class="cluster-scroll">
#             <ul>
#              <div id="comp_show">
#               <li>
#                <input id="com_0" name="topCompanies" onclick="getSRPResultByDwr('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=moody%27s+corporation&amp;gadLink=View Jobs By This Company');trackAjaxSRPresult('/job-search.html?clusterName=CLUSTER_COMP&amp;refineBy=dateWise&amp;from=undo&amp;luceneResultSize=25&amp;postWeek=60&amp;searchType=personalizedSearch&amp;txtLocation=New York&amp;undokey=compCluster&amp;compCluster=moody%27s+corporation&amp;gadLink=View Jobs By This Company','Moody's Corporation');" type="checkbox"/>
#                <label for="com_0">
#                 <span title="Moody's Corporation">
#                  Moody's Corpora..
#                 </span>
#                 <span class="grey-text">
#                  (31)
#                 </span>
#                </label>
#               </li>
#               <li>
# ...
#        <div class="zindex loggedin_gmail">
#         <div data-auto_prompt="false" data-client_id="819793255355-3574gl7e6o6pkq7cc46dedolg7hae69k.apps.googleusercontent.com" data-login_uri="https://social.timesjobs.com/harvest/callback.html?pId=ggl&amp;apc=tj" data-param1="any_value_1" data-param2="any_value_2" id="g_id_onload">
#         </div>
#         <span class="_login-pointer">
#          <svg fill="none" height="162" viewbox="0 0 166 162" width="166" xmlns="http://www.w3.org/2000/svg">
#           <path d="M10.9536 121.632C9.18704 98.2792 19.7831 71.1014 45.7116 66.9675C57.7636 65.0261 71.1034 70.4703 77.3043 81.2384C82.1152 89.5968 79.105 100.525 68.408 100.595C64.6947 100.481 61.0627 99.4795 57.8152 97.6752C54.5677 95.8709 51.799 93.316 49.7401 90.2236C33.8821 66.7456 61.036 44.6484 82.2698 40.9457C106.898 36.6232 132.221 45.559 149.884 62.8212C152.45 65.3223 156.561 61.5664 153.996 59.0653C134.84 40.3518 107.627 30.8122 80.9956 35.5246C59.3008 39.3371 37.1508 56.1104 40.1948 80.479C40.846 85.6727 42.8749 90.5976 46.0711 94.7428C49.2673 98.888 53.5144 102.103 58.3718 104.053C66.2422 107.224 77.528 107.258 83.0163 99.6773C89.3553 91.0395 83.7398 78.8803 77.2158 72.1079C73.563 68.3837 69.1656 65.4719 64.3109 63.5629C59.4561 61.6539 54.2533 60.7905 49.0421 61.0292C18.3578 62.5281 3.31383 94.1729 5.39542 121.466C5.66604 124.985 11.2255 125.21 10.9536 121.632Z" fill="white">
#           </path>
#           <path d="M139.964 37.2776C145.036 45.5849 149.617 54.1822 153.684 63.0255L155.52 59.032C144.221 61.0458 133.121 64.0504 122.349 68.011C119.038 69.2389 120.284 74.69 123.623 73.432C134.387 69.465 145.482 66.4585 156.777 64.4475C157.189 64.3463 157.573 64.1534 157.9 63.8831C158.227 63.6128 158.489 63.2721 158.666 62.8865C158.843 62.5009 158.931 62.0803 158.922 61.656C158.914 61.2318 158.81 60.8148 158.619 60.4363C154.574 51.6024 150.016 43.0125 144.97 34.7104C143.114 31.6717 138.162 34.2553 140.052 37.305L139.964 37.2776Z" fill="white">
#           </path>
#          </svg>
#         </span>
#         <div style="z-index: 1; position: relative;">
#          <span>
#           <img alt="TechGig" src="/images_cand/tj_images/usability/timesjobs-white-logo.png" style="height:17px;"/>
#          </span>
#          <h2 class="google_login_head">
#           Unlock Your Potential:
#           <br/>
#           Find Your Dream Job Today!
#          </h2>
#          <ul class="info-list">
#           <li>
#            2 Lakh+ Jobs
#           </li>
#           <li>
#            25K+ recruiters
#           </li>
#           <li>
#            FREE and Unlimited applies
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <!-- Footer Ends   -->
#       <script type="text/javascript">
#        var GB_ROOT_DIR = "/candidate/greybox/";
#       </script>
#       <link href="https://static.timesjobs.com/newtj_css/css/tj_css/personlisation/gb_styles.css" media="all" rel="stylesheet" type="text/css"/>
#       <script src="https://static.timesjobs.com/newtj_js/scripts/groupJs/searchResultTempGroup.js?v=7.1.9" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        var _sf_startpt=(new Date()).getTime()
#       </script>
#       <!--[if IE]><script src="https://static.timesjobs.com/newtj_js/scripts/html5.js"></script><![endif]-->
#       <script type="text/javascript">
#        var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6036484" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
#
#   function trackAjaxSRPresult(url, type) {
# 		var title = document.getElementsByTagName("title")[0].innerHTML;
# 		title = title.replace("TimesJobs.com", type + " Jobs");
# 		title = title.concat(" | TimesJobs.com");
#
# 		var t = "2", n = "6036484", r = "", i = encodeURIComponent(url), s = "", o = "", u = encodeURIComponent(title), a = "", f = "2.0", l = "1";
# 		var c = document.createElement("img");
# 		c.src = "https://sb.scorecardresearch.com/p?c1=" + t + "&c2=" + n +"&c3=" + r + "&c4=" + i + "&c5=" + s + "&c6=" + o + "&c8=" + u + "&c15=" + a + "&cv=" + f + "&cj=" + l + "&ns__t=" + (new Date).getTime();
# 		document.body.appendChild(c);
# 	}
#       </script>
#       <noscript>
#        <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6036484&amp;cv=2.0&amp;cj=1"/>
#       </noscript>
#       <script type="text/javascript">
#        /*!
# * jQuery Cookie Plugin v1.3.1
# * https://github.com/carhartl/jquery-cookie
# *
# * Copyright 2013 Klaus Hartl
# * Released under the MIT license
# */
# (function (factory) {
# if (typeof define === 'function' && define.amd && define.amd.jQuery) {
# // AMD. Register as anonymous module.
# define(['jquery'], factory);
# } else {
# // Browser globals.
# factory(jQuery);
# }
# }(function ($) {
#
# var pluses = /\+/g;
#
# function raw(s) {
# return s;
# }
#
# function decoded(s) {
# return decodeURIComponent(s.replace(pluses, ' '));
# }
#
# function converted(s) {
# if (s.indexOf('"') === 0) {
# // This is a quoted cookie as according to RFC2068, unescape
# s = s.slice(1, -1).replace(/\\"/g, '"').replace(/\\\\/g, '\\');
# }
# try {
# return config.json ? JSON.parse(s) : s;
# } catch(er) {}
# }
#
# var config = $.cookie = function (key, value, options) {
#
# // write
# if (value !== undefined) {
# options = $.extend({}, config.defaults, options);
#
# if (typeof options.expires === 'number') {
# var days = options.expires, t = options.expires = new Date();
# t.setDate(t.getDate() + days);
# }
#
# value = config.json ? JSON.stringify(value) : String(value);
#
# return (document.cookie = [
# encodeURIComponent(key), '=', config.raw ? value : encodeURIComponent(value),
# options.expires ? '; expires=' + options.expires.toUTCString() : '', // use expires attribute, max-age is not supported by IE
# options.path ? '; path=' + options.path : '',
# options.domain ? '; domain=' + options.domain : '',
# options.secure ? '; secure' : ''
# ].join(''));
# }
#
# // read
# var decode = config.raw ? raw : decoded;
# var cookies = document.cookie.split('; ');
# var result = key ? undefined : {};
# for (var i = 0, l = cookies.length; i < l; i++) {
# var parts = cookies[i].split('=');
# var name = decode(parts.shift());
# var cookie = decode(parts.join('='));
#
# if (key && key === name) {
# result = converted(cookie);
# break;
# }
#
# if (!key) {
# result[name] = converted(cookie);
# }
# }
#
# return result;
# };
#
# config.defaults = {};
#
# $.removeCookie = function (key, options) {
# if ($.cookie(key) !== undefined) {
# $.cookie(key, '', $.extend(options, { expires: -1 }));
# return true;
# }
# return false;
# };
#
# }));
#       </script>
#       <script type="text/javascript">
#        jQuery.cookie('previous_browser_url', $.cookie('current_browser_url'));
# 	jQuery.cookie('current_browser_url', window.location.href);
# 	//setCookie('previous_browser_url',getCookie('current_browser_url'));
# 	//setCookie('current_browser_url', window.location.href);
#       </script>
#       <script type="text/javascript">
#        function getPredefinedActionName(url){
# 		var returnActionName = "";
# 		var from = url.lastIndexOf("/");
# 		var to = url.indexOf("?",from);
# 		if(-1!=to){
# 			returnActionName = url.substring(from,to);
# 		}else{
# 			returnActionName = url.substring(from);
# 		}
# 		return returnActionName;
# 	}
#       </script>
#       <script type="text/javascript">
#        var notification_timeout = 10000;
# var notification_cache = true;
# function ping(url){
#  var ImageObject = new Image();
#  ImageObject.src = url; //e.g. logo
# }
# var cand_context="";
# 	if(-1 == window.location.href.indexOf("/candidate/")) {
# 		  cand_context="/candidate/";
# 		  //alert("bingo");
# 	}
#
# 		function getMailInBoxUnreadCount(){
# 			var rurl=cand_context+"inbox-message-get-unread-count.html";
# 			jQuery.ajax({
# 				cache:notification_cache,
# 				url:rurl,
# 				success:function(data){
# 					console.log("success... inbox-message-get-unread-count.html"+'');
# 				},
# 				error: function(x, textStatus, m) {
# 					console.log("Failed"+m);
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            //do something. Try again perhaps?
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    	}
# 			});
# 		}
#
# 		function getDistinctEmployerCounts(){
# 		 var rurl=cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_RE";
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:rurl,
# 			success:function(data){
# 				//alert("RE-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_re").html(data);
# 				jQuery("#mytj_header_re").html(data);
# 				jQuery("#homeindex_inbox_re").html(data);
# 				jQuery("#headerhome_inbox_re").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			            console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+rurl+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			            //do something. Try again perhaps?
# 			        }
# 		    }
#
# 		});
# 	//alert("call in progress...");
# 		 jQuery.ajax({
# 			cache:notification_cache,
# 			timeout:notification_timeout,
# 			url:cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV",
# 			success:function(data){
# 				//alert("PV-success");
# 				//alert(selectedTab+",data"+data+" for"+jQuery("#inbox_header").hasClass("inbox-header"));
# 				jQuery("#mytj_inbox_pv").html(data);
# 				jQuery("#mytj_header_pv").html(data);
# 				jQuery("#homeindex_inbox_pv").html(data);
# 				jQuery("#headerhome_inbox_pv").html(data);
# 			},
# 			error: function(x, textStatus, m) {
# 					if(textStatus == 'timeout')
# 			        {
# 			             console.log("Failed from timeout");
# 			            var randomnumber=Math.floor(Math.random()*100000001);
# 						var nlpurl='https://alerts.timesjobs.com/naf/nlpTracking.html?captchaType='+cand_context+"inbox-getDistinctEmployerForLoginIdAndFolder.html?mode=inbox_PV"+'&op=respTracking#'+randomnumber;
# 						ping(nlpurl);
# 			        }
# 		    }
# 		});
# 	 }
# 	function displayLoading(div){
# 	if(1 == tab || 2 == tab || 4 == tab || 5 == tab  ){
# 			jQuery(div).append("<div class='loading'>&nbsp;</div>");
# 	}
# }
#       </script>
#       <script type="application/ld+json">
#        {
#   "@context": "https://schema.org",
#   "@type": "Organization",
#   "location": {
#     "@type": "Place",
#     "address": "TimesJobs.com, Times Business Solutions (A Division of Times Internet Ltd.), Times Center (Digital Content Production Facility), FC - 6, (Ground Floor), Sector 16 A, Film City, NOIDA - 201 301, Uttar Pradesh, India"
#   },
#   "applicantLocationRequirements": { "@type": "Country", "name": "-" },
#   "name": "TimesJobs.com",
#   "description": "TimesJobs: India's Leading Job Portal",
#   "logo": "https://static.timesjobs.com/images_cand/tj_images/logos/tj_logo_300x300.jpg",
#   "url": "https://www.timesjobs.com",
#   "email": "timesjobs@timesgroup.com"
# }
#       </script>
#       <script type="application/ld+json">
#        {
#     "@context": "https://schema.org",
#     "@type": "WebSite",
#     "url": "https://www.timesjobs.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
# }
#       </script>
#       <!--Common Template Included in all files end here  -->
#       <!--google analytics start-->
#       <!--  New Code of GA 4 -->
#       <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-Z15Q1G661Y">
#       </script>
#       <!--  New Code of GA 4 -->
#       <script type="text/javascript">
#        var _gaq = _gaq || [];
#
#
#
#
#
#
#
#
# 			_gaq.push(['_setAccount', 'UA-1688637-1']);
#
#
#   _gaq.push(['_trackPageview']);
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
#   function trackClickEvent(category,action){
# 		_gaq.push(['_trackEvent',category,action]);
# 	}
#       </script>
#       <!--  New Code of GA 4 -->
#       <script>
#        window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-Z15Q1G661Y');
#
#   var banner_custom_params = {
# 		  campaign_name : "tesCompanyName",
# 		  campaign_action : "tesCompanyName_Impression"
#    };
#
#   var banner_custom_params1 = {
# 		  campaign_name : "tesCompanyName1",
# 		  campaign_action : "tesCompanyName1_Impression"
#    };
#
#  /*  gtag('event', 'banner_performance', window.banner_custom_params);
#
#   gtag('event', 'banner_performance', window.banner_custom_params1);
#  */
#       </script>
#       <!--  New Code of GA 4 -->
#       <!--google analytics ends-->
#       <img alt="" border="0" height="1" src="https://tracking.sokrati.com/site?client_id=60&amp;product_category=Site_Search" width="1"/>
#       <script type="text/javascript">
#        function removeSpecificRefineNew(urltoHit){
#  	getSRPResultByDwrNew(urltoHit);
#  	return false;
#  }
#
#  function getSRPResultByDwrNew(urlToHit) {
# 		jQuery( "#refine-opt-search-datewise a" ).removeClass( "refinejobsopt" );
# 		jQuery("#defualtSelectedDate").addClass( "refinejobsopt" );
# 		jQuery("#searchResultData").remove();
# 		jQuery("#searchResultContents").html(dataImageLoader);
# 		var matchStr=urlToHit.match("&undo=(.*)&undoValue");//For Selecting tab on Cluster
#
# 		ajaxController.getDWRBasedWebResponse(urlToHit,function(data) {
# 							if (data != null && data != 'undefined') {
# 								jQuery("#searchResultContents").html(data);
#
# 								console.info("matchStr=="+matchStr);
# 								if(chkNull(matchStr)){
# 									console.info("matched text at posotion 1="+matchStr[1]);
# 									showSelectedTabData(matchStr[1]);
# 								}
# 								if(matchStr==null && urlToHit.indexOf("undo=")!=-1){
# 									//jQuery( ".refined-bx" ).tabs("refresh");
#
# 								}
# 								//For making initial tab selected
# 								if(urlToHit.indexOf("&reset")!=-1){
# 									console.info("inside reset all tab");
# 									//jQuery( ".refined-bx" ).tabs("refresh");
# 								}
# 							} else {
# 								jQuery("#searchResultContents").html("Oops! There seems to be a technical problem. Please try again");
# 							}
# 						});
# 						return false;
# 	}
#
#
#
# 	if (top != self){
# 		window.open(self.location.href,"_top");
# 	}
# 	var siteId='1040';
# 	var stype = 'timesjobs.com';
#     (function () {
#          var s = document.createElement('script');
#          s.type = 'text/javascript';
#          s.async = true;
#          s.src = 'https://ceoconnect.in/feedback/scripts/feedbackInc.js';
#          var x = document.getElementsByTagName('script')[0];
#          x.parentNode.insertBefore(s, x);
#     })();
#       </script>
#      </div>
#      <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/lightBox.js" type="text/javascript">
#      </script>
#      <div class="modal" id="light-box-popup">
#       <span class="material-icons close-modal modal-action modal-close">
#        close
#       </span>
#       <div class="modal-content" id="light-box-popup-content">
#       </div>
#      </div>
#      <!-- <script type="text/javascript">
#   $(document).ready(function(){
# 	    // the "href" attribute of the modal trigger must specify the modal ID that wants to be triggered
# 	    $('.modal').modal();
# 	  });
#
#   </script> -->
#      <!--  ##########################  JobBuzz Ads  ################## -->
#     </section>
#    </div>
#   </div>
#  </body>
# </html>

# %%
trabalhos = doc.find_all('li', class_='clearfix job-bx wht-shd-bx')

# %%
trabalhos
# Out:
# [<li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/content-analyst-alphasense-new-york-city-0-to-4-yrs-jobid-3zcl5giKKjpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70592697','content analysis  ,  communication skills  ,  analytical skills  ,  troubleshooting  ,  research skills  , press , written communication','New York City','0 - 4','Content / Editors / Journalists','1','' )" target="_blank">
#        Content Analyst</a> </h2>
#  <h3 class="joblist-comp-name">
#      AlphaSense
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 4 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  About AlphaSense:AlphaSense is a market intelligence and search platform used by the world's leading companies and financial institutions. Since 2011, our AI-based technology ... <a href="https://www.timesjobs.com/job-detail/content-analyst-alphasense-new-york-city-0-to-4-yrs-jobid-3zcl5giKKjpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            content analysis  ,  communication skills  ,  analytical skills  ,  troubleshooting  ,  research skills  , press , written communication
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70592697">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70592697','adId=3zcl5giKKjpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70592697','content analysis  ,  communication skills  ,  analytical skills  ,  troubleshooting  ,  research skills  , press , written communication','New York City','0 - 4','Content / Editors / Journalists','1','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 2 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/veeva-systems-director-advanced-tv-audience-data-partnerships-veeva-systems-new-york-city-5-to-9-yrs-jobid-nI4w1G1__SLASH__vIxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70518319','advanced tv activation  ,  client facing communication  ,  data analytics  ,  strategic account management  ,  business development  , communication skills , recruitment process , compensation','New York City','5 - 9','Sales / Business Development','2','' )" target="_blank">
#        Veeva Systems - Director - Advanced TV Audience Data Partnerships</a> </h2>
#  <h3 class="joblist-comp-name">
#      Veeva Systems
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  : Director - Advanced TV Audience Data PartnershipsLocation: New York City, New YorkDepartment: Analytics  628-Stgy Crossix pdt MgmtEmployment Type: Full-Time, RemoteVeeva Sys... <a href="https://www.timesjobs.com/job-detail/veeva-systems-director-advanced-tv-audience-data-partnerships-veeva-systems-new-york-city-5-to-9-yrs-jobid-nI4w1G1__SLASH__vIxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            advanced tv activation  ,  client facing communication  ,  data analytics  ,  strategic account management  ,  business development  , communication skills , recruitment process , compensation
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70518319">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70518319','adId=nI4w1G1__SLASH__vIxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70518319','advanced tv activation  ,  client facing communication  ,  data analytics  ,  strategic account management  ,  business development  , communication skills , recruitment process , compensation','New York City','5 - 9','Sales / Business Development','2','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 2 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/001176.jpg" alt="NTT Data Vertex Software Inc." title="NTT Data Vertex Software Inc."/> </span> -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/financial-services-risk-and-compliance-consulting-senior-manager-ntt-data-vertex-software-inc-new-york-city-7-to-9-yrs-jobid-95p8zKQfsJxzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70590180','risk management ,  compliance consulting ,  financial services ,  project management ,  data privacy  , delivery excellence , senior manager , technology consulting , infrastructure services , project initiation , customer engagement','New York City','7 - 9','Finance','3','' )" target="_blank">
#        Financial Services Risk and Compliance Consulting Senior Manager</a> </h2>
#  <h3 class="joblist-comp-name">
#      NTT Data Vertex Software Inc.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>7 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  : Financial Services Risk and Compliance Consulting Senior ManagerDate: Aug 21, 2024Location: New York City, NY, USCompany: NTT DATA ServicesReq ID: 275384NTT DATA Services st... <a href="https://www.timesjobs.com/job-detail/financial-services-risk-and-compliance-consulting-senior-manager-ntt-data-vertex-software-inc-new-york-city-7-to-9-yrs-jobid-95p8zKQfsJxzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            risk management ,  compliance consulting ,  financial services ,  project management ,  data privacy  , delivery excellence , senior manager , technology consulting , infrastructure services , project initiation , customer engagement
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70590180">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70590180','adId=95p8zKQfsJxzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70590180','risk management ,  compliance consulting ,  financial services ,  project management ,  data privacy  , delivery excellence , senior manager , technology consulting , infrastructure services , project initiation , customer engagement','New York City','7 - 9','Finance','3','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/software-engineer-front-end-at-capital-one-capital-one-financial-services-client-new-york-city-2-to-3-yrs-jobid-BK__SLASH__E0wBS5W5zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589854','front end development  ,  software engineering  ,  test driven development  ,  agile practices  ,  cloud services  , css , java , html , san , javascript','New York City','2 - 3','IT Software : Software Products &amp; Services','4','' )" target="_blank">
#        Software Engineer, Front End at Capital One</a> </h2>
#  <h3 class="joblist-comp-name">
#      CAPITAL ONE FINANCIAL SERVICES CLIENT
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>2 - 3 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  R194318 Posted 08/13/2024Software Engineer, Front EndLocation: Richmond, Virginia | New York, New YorkCategory: EngineeringExperience: Sr. AssociatePrimary Address: Richmond, ... <a href="https://www.timesjobs.com/job-detail/software-engineer-front-end-at-capital-one-capital-one-financial-services-client-new-york-city-2-to-3-yrs-jobid-BK__SLASH__E0wBS5W5zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            front end development  ,  software engineering  ,  test driven development  ,  agile practices  ,  cloud services  , css , java , html , san , javascript
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589854">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589854','adId=BK__SLASH__E0wBS5W5zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589854','front end development  ,  software engineering  ,  test driven development  ,  agile practices  ,  cloud services  , css , java , html , san , javascript','New York City','2 - 3','IT Software : Software Products &amp; Services','4','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/veeva-systems-field-marketing-manager-veeva-systems-new-york-city-5-to-9-yrs-jobid-q9VJ2LCoN25zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70517218','demand generation  ,  field marketing  ,  integrated marketing  ,  vendor management  ,  project management  , medical , campaigns , social media , marketing automation , product marketing , marketing programs','New York City','5 - 9','Marketing / Media Planning / MR / Comm. (Digital &amp; Offline)','5','' )" target="_blank">
#        Veeva Systems - Field Marketing Manager</a> </h2>
#  <h3 class="joblist-comp-name">
#      Veeva Systems
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  : Field Marketing ManagerLocation: New York City, New YorkDepartment: MarketingCode: 502-Mktg CommEmployment Type: Full-TimeWork Arrangement: RemoteVeeva Systems is a mission-... <a href="https://www.timesjobs.com/job-detail/veeva-systems-field-marketing-manager-veeva-systems-new-york-city-5-to-9-yrs-jobid-q9VJ2LCoN25zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            demand generation  ,  field marketing  ,  integrated marketing  ,  vendor management  ,  project management  , medical , campaigns , social media , marketing automation , product marketing , marketing programs
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70517218">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70517218','adId=q9VJ2LCoN25zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70517218','demand generation  ,  field marketing  ,  integrated marketing  ,  vendor management  ,  project management  , medical , campaigns , social media , marketing automation , product marketing , marketing programs','New York City','5 - 9','Marketing / Media Planning / MR / Comm. (Digital &amp; Offline)','5','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/veeva-systems-marketing-data-analyst-adp-veeva-systems-new-york-city-0-to-1-yrs-jobid-6eITDHNILP1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589660','data analytics  ,  marketing analysis  ,  sql  ,  business intelligence  ,  communication skills  , spring , database , san , team player','New York City','0 - 1','Marketing / Media Planning / MR / Comm. (Digital &amp; Offline)','6','' )" target="_blank">
#        Veeva Systems - Marketing Data Analyst - ADP</a> </h2>
#  <h3 class="joblist-comp-name">
#      Veeva Systems
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Position: Marketing Data AnalystCompany: VeevaLocation: New York CityCompany Information:Generation Veeva  806-G&amp;amp;A ES CorpVeeva Systems is a mission-driven organizatio... <a href="https://www.timesjobs.com/job-detail/veeva-systems-marketing-data-analyst-adp-veeva-systems-new-york-city-0-to-1-yrs-jobid-6eITDHNILP1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            data analytics  ,  marketing analysis  ,  sql  ,  business intelligence  ,  communication skills  , spring , database , san , team player
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589660">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589660','adId=6eITDHNILP1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589660','data analytics  ,  marketing analysis  ,  sql  ,  business intelligence  ,  communication skills  , spring , database , san , team player','New York City','0 - 1','Marketing / Media Planning / MR / Comm. (Digital &amp; Offline)','6','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/veeva-systems-analytics-services-associate-adp-veeva-systems-new-york-city-0-to-1-yrs-jobid-YmdMlAN9h__SLASH__pzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589659','healthcare analytics  ,  client relationship management  ,  data driven insights  ,  communication skills  ,  quantitative analysis  , learning , recruitment process , compensation','New York City','0 - 1','Medical / Health / Fitness','7','' )" target="_blank">
#        Veeva Systems - Analytics Services Associate - ADP</a> </h2>
#  <h3 class="joblist-comp-name">
#      Veeva Systems
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Analytics Services AssociateCompany: ADP New York - New York CityLocation: Generation Veeva  806-G&amp;amp;A ES CorpType: Full-TimeWork Arrangement: On-siteVeeva Systems is a ... <a href="https://www.timesjobs.com/job-detail/veeva-systems-analytics-services-associate-adp-veeva-systems-new-york-city-0-to-1-yrs-jobid-YmdMlAN9h__SLASH__pzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            healthcare analytics  ,  client relationship management  ,  data driven insights  ,  communication skills  ,  quantitative analysis  , learning , recruitment process , compensation
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589659">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589659','adId=YmdMlAN9h__SLASH__pzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589659','healthcare analytics  ,  client relationship management  ,  data driven insights  ,  communication skills  ,  quantitative analysis  , learning , recruitment process , compensation','New York City','0 - 1','Medical / Health / Fitness','7','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/001176.jpg" alt="NTT Data Vertex Software Inc." title="NTT Data Vertex Software Inc."/> </span> -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/cloud-infrastructure-engineer-ntt-data-vertex-software-inc-new-york-city-5-to-7-yrs-jobid-SYS__SLASH__Smgt8PtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589570','azure services  ,  kubernetes  ,  terraform scripting  ,  python development  ,  azure active directory  , storage , artificial intelligence , sql , spring , security , java , iam , devops , technology consulting , shell scripting , api , github , access management , infrastructure , splunk , gateway','New York City','5 - 7','IT Software : Software Products &amp; Services','8','' )" target="_blank">
#        Cloud Infrastructure Engineer</a> </h2>
#  <h3 class="joblist-comp-name">
#      NTT Data Vertex Software Inc.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 7 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  : Cloud Infrastructure EngineerDate: Aug 26, 2024Location: New York City, NY, USCompany: NTT DATA ServicesReq ID: 293373NTT DATA strives to hire exceptional, innovative, and p... <a href="https://www.timesjobs.com/job-detail/cloud-infrastructure-engineer-ntt-data-vertex-software-inc-new-york-city-5-to-7-yrs-jobid-SYS__SLASH__Smgt8PtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            azure services  ,  kubernetes  ,  terraform scripting  ,  python development  ,  azure active directory  , storage , artificial intelligence , sql , spring , security , java , iam , devops , technology consulting , shell scripting , api , github , access management , infrastructure , splunk , gateway
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589570">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589570','adId=SYS__SLASH__Smgt8PtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589570','azure services  ,  kubernetes  ,  terraform scripting  ,  python development  ,  azure active directory  , storage , artificial intelligence , sql , spring , security , java , iam , devops , technology consulting , shell scripting , api , github , access management , infrastructure , splunk , gateway','New York City','5 - 7','IT Software : Software Products &amp; Services','8','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/001176.jpg" alt="NTT Data Vertex Software Inc." title="NTT Data Vertex Software Inc."/> </span> -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/machine-learning-engineer-ntt-data-vertex-software-inc-new-york-city-3-to-9-yrs-jobid-5GnIJmJSu__PLUS__dzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589531','pytorch ,  nltk  ,  scipy ,  numpy  ,  sql ,  nosql databases  ,  deep learning concepts  ,  gpu training ,  docker  , cloudera , algorithms , soa , ensemble , artificial intelligence , oop , technology consulting , mysql , technical skills , mongodb , rest , python , oracle , machine learning , messaging , infrastructure , opencv','New York City','3 - 9','IT Software : Software Products &amp; Services','9','' )" target="_blank">
#        Machine Learning Engineer</a> </h2>
#  <h3 class="joblist-comp-name">
#      NTT Data Vertex Software Inc.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>3 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Machine Learning EngineerDate: Aug 27, 2024Location: New York, NY, USCompany: NTT DATA ServicesReq ID: 292343NTT DATA strives to hire exceptional, innovative, and passionate i... <a href="https://www.timesjobs.com/job-detail/machine-learning-engineer-ntt-data-vertex-software-inc-new-york-city-3-to-9-yrs-jobid-5GnIJmJSu__PLUS__dzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            pytorch ,  nltk  ,  scipy ,  numpy  ,  sql ,  nosql databases  ,  deep learning concepts  ,  gpu training ,  docker  , cloudera , algorithms , soa , ensemble , artificial intelligence , oop , technology consulting , mysql , technical skills , mongodb , rest , python , oracle , machine learning , messaging , infrastructure , opencv
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589531">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589531','adId=5GnIJmJSu__PLUS__dzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589531','pytorch ,  nltk  ,  scipy ,  numpy  ,  sql ,  nosql databases  ,  deep learning concepts  ,  gpu training ,  docker  , cloudera , algorithms , soa , ensemble , artificial intelligence , oop , technology consulting , mysql , technical skills , mongodb , rest , python , oracle , machine learning , messaging , infrastructure , opencv','New York City','3 - 9','IT Software : Software Products &amp; Services','9','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/de-jobs-sprinklr-director-of-product-management-ads-marketing-in-haryana-india-buck-global-llc-new-york-city-6-to-9-yrs-jobid-i7LKSuxmMWJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70589134','strategic leadership  ,  customer insight  ,  data analytics  ,  executive communication  ,  team empowerment  , fundamentals , director , forms','New York City','6 - 9','Sales / Business Development','10','' )" target="_blank">
#        DE Jobs - Sprinklr Director of Product Management - Ads &amp; Marketing in Haryana, India</a> </h2>
#  <h3 class="joblist-comp-name">
#      buck global llc
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>6 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Company: SprinklrLocation: New York CityWebsite: SprinklrTitle: Director Product ManagementRequired Educational Qualification: Btech   MBA (Optional)Summary: As a Director of ... <a href="https://www.timesjobs.com/job-detail/de-jobs-sprinklr-director-of-product-management-ads-marketing-in-haryana-india-buck-global-llc-new-york-city-6-to-9-yrs-jobid-i7LKSuxmMWJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            strategic leadership  ,  customer insight  ,  data analytics  ,  executive communication  ,  team empowerment  , fundamentals , director , forms
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70589134">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70589134','adId=i7LKSuxmMWJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70589134','strategic leadership  ,  customer insight  ,  data analytics  ,  executive communication  ,  team empowerment  , fundamentals , director , forms','New York City','6 - 9','Sales / Business Development','10','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 3 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/staff-software-engineer-moody-s-corporation-new-york-city-5-to-9-yrs-jobid-HfLzanB4nBZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70523145','typescript &amp; reactjs  ,  html &amp; css  ,  nodejs  ,  aws serverless  ,  front end development tools  , sso , api , nosql , web technologies , docker , elastic search , git , postgresql , san , cloud services , ant , gateway','New York City','5 - 9','IT Software : Software Products &amp; Services','11','' )" target="_blank">
#        Staff Software Engineer</a> </h2>
#  <h3 class="joblist-comp-name">
#      Moody's Corporation
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  ### **Experience Level:** Experienced Hire  **Categories:** Engineering &amp;amp; Technology  **Location(s):** 7 World Trade Center, 250 Greenwich Street, New York, New York, ... <a href="https://www.timesjobs.com/job-detail/staff-software-engineer-moody-s-corporation-new-york-city-5-to-9-yrs-jobid-HfLzanB4nBZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            typescript &amp; reactjs  ,  html &amp; css  ,  nodejs  ,  aws serverless  ,  front end development tools  , sso , api , nosql , web technologies , docker , elastic search , git , postgresql , san , cloud services , ant , gateway
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70523145">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70523145','adId=HfLzanB4nBZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70523145','typescript &amp; reactjs  ,  html &amp; css  ,  nodejs  ,  aws serverless  ,  front end development tools  , sso , api , nosql , web technologies , docker , elastic search , git , postgresql , san , cloud services , ant , gateway','New York City','5 - 9','IT Software : Software Products &amp; Services','11','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 4 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/ui-ux-architect-grawlix-software-private-limited-pune-new-york-city-12-to-15-yrs-jobid-3JYNSltPdC1zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70510044','github , html5 , javascript , web technologies , mysql','New York City','12 - 15','IT Software : Software Products &amp; Services','12','' )" target="_blank">
#        UI/UX Architect</a> </h2>
#  <h3 class="joblist-comp-name">
#      grawlix software private limited pune
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>12 - 15 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  # ## UI/UX Architect- **Experience**: 8  Years- **Location**: New York City, NY (local to NY only)### Responsibilities:- Lead the development and implementation of complex web... <a href="https://www.timesjobs.com/job-detail/ui-ux-architect-grawlix-software-private-limited-pune-new-york-city-12-to-15-yrs-jobid-3JYNSltPdC1zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            github , html5 , javascript , web technologies , mysql
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70510044">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70510044','adId=3JYNSltPdC1zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70510044','github , html5 , javascript , web technologies , mysql','New York City','12 - 15','IT Software : Software Products &amp; Services','12','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/senior-net-developer-grawlix-software-private-limited-pune-new-york-city-6-to-9-yrs-jobid-hixlZ6RrRcpzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70510042','.net developer , asp .net , jquery , oop , database , .net , business applications','New York City','6 - 9','IT Software : Software Products &amp; Services','13','' )" target="_blank">
#        Senior.Net Developer</a> </h2>
#  <h3 class="joblist-comp-name">
#      grawlix software private limited pune
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>6 - 9 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  : Senior .Net DeveloperLocation: New York (Onsite)Experience: 6  YearsResponsibilities:6  years of Experience working with, asp .net, .net Core, Angular 8 , Jquery, Javascript... <a href="https://www.timesjobs.com/job-detail/senior-net-developer-grawlix-software-private-limited-pune-new-york-city-6-to-9-yrs-jobid-hixlZ6RrRcpzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            .net developer , asp .net , jquery , oop , database , .net , business applications
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70510042">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70510042','adId=hixlZ6RrRcpzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70510042','.net developer , asp .net , jquery , oop , database , .net , business applications','New York City','6 - 9','IT Software : Software Products &amp; Services','13','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/senior-cloud-platform-engineer-core-azure-alphasense-new-york-city-5-to-10-yrs-jobid-cn75ULtM0ylzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70286962','cloud infrastructure  ,  kubernetes operations  ,  devsecops skills  ,  automation tools  ,  programming proficiency  , security specialist , orchestration , storage , docker , java , linux , api , cloud services , python , mobile , csi','New York City','5 - 10','IT Software : Software Products &amp; Services','14','' )" target="_blank">
#        Senior Cloud Platform Engineer (Core, Azure)</a> </h2>
#  <h3 class="joblist-comp-name">
#      AlphaSense
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 10 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  About AlphaSenseAlphaSense is a market intelligence platform used by the world's leading companies and financial institutions. Since 2011, our AI-based technology has helped p... <a href="https://www.timesjobs.com/job-detail/senior-cloud-platform-engineer-core-azure-alphasense-new-york-city-5-to-10-yrs-jobid-cn75ULtM0ylzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            cloud infrastructure  ,  kubernetes operations  ,  devsecops skills  ,  automation tools  ,  programming proficiency  , security specialist , orchestration , storage , docker , java , linux , api , cloud services , python , mobile , csi
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70286962">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70286962','adId=cn75ULtM0ylzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70286962','cloud infrastructure  ,  kubernetes operations  ,  devsecops skills  ,  automation tools  ,  programming proficiency  , security specialist , orchestration , storage , docker , java , linux , api , cloud services , python , mobile , csi','New York City','5 - 10','IT Software : Software Products &amp; Services','14','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/ion-group-senior-cloud-infrastructure-engineer-new-york-374-ion-trading-india-pvt-ltd-new-york-city-6-to-10-yrs-jobid-dMyiDmP0dURzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70587310','cloud infrastructure engineering  ,  aws / azure environments  ,  infrastructure as code  ( iac )   ,  devops infrastructure  ,  monitoring &amp; observability  , orchestration , security , java , iam , mks , technology consulting , software engineering , python , mq , access management','New York City','6 - 10','IT Software : Software Products &amp; Services','15','' )" target="_blank">
#        ION Group - Senior Cloud Infrastructure Engineer, New York (374)</a> </h2>
#  <h3 class="joblist-comp-name">
#      ion trading india pvt. ltd.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>6 - 10 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Senior Cloud Infrastructure Engineer, New York (374) New YorkLab49  Software Engineering / HybridWe are seeking a Cloud Infrastructure Engineer to join our newly created sub-p... <a href="https://www.timesjobs.com/job-detail/ion-group-senior-cloud-infrastructure-engineer-new-york-374-ion-trading-india-pvt-ltd-new-york-city-6-to-10-yrs-jobid-dMyiDmP0dURzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            cloud infrastructure engineering  ,  aws / azure environments  ,  infrastructure as code  ( iac )   ,  devops infrastructure  ,  monitoring &amp; observability  , orchestration , security , java , iam , mks , technology consulting , software engineering , python , mq , access management
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70587310">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70587310','adId=dMyiDmP0dURzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70587310','cloud infrastructure engineering  ,  aws / azure environments  ,  infrastructure as code  ( iac )   ,  devops infrastructure  ,  monitoring &amp; observability  , orchestration , security , java , iam , mks , technology consulting , software engineering , python , mq , access management','New York City','6 - 10','IT Software : Software Products &amp; Services','15','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/ion-group-senior-cloud-infrastructure-engineer-new-york-338-ion-trading-india-pvt-ltd-new-york-city-3-to-7-yrs-jobid-plB__SLASH__kfMgkdlzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70587308','cloud infrastructure  ,  aws / azure  ,  infrastructure as code  ( iac )   ,  monitoring solutions  ,  devops  , docker , security , java , iam , technology consulting , software engineering , python , maven , access management','New York City','3 - 7','IT Software : Software Products &amp; Services','16','' )" target="_blank">
#        ION Group - Senior Cloud Infrastructure Engineer, New York - 338</a> </h2>
#  <h3 class="joblist-comp-name">
#      ion trading india pvt. ltd.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>3 - 7 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Senior Cloud Infrastructure Engineer, New York - 338 New YorkLab49  Software Engineering / Full-time / HybridWe are seeking a Cloud Infrastructure Engineer to join our newly c... <a href="https://www.timesjobs.com/job-detail/ion-group-senior-cloud-infrastructure-engineer-new-york-338-ion-trading-india-pvt-ltd-new-york-city-3-to-7-yrs-jobid-plB__SLASH__kfMgkdlzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            cloud infrastructure  ,  aws / azure  ,  infrastructure as code  ( iac )   ,  monitoring solutions  ,  devops  , docker , security , java , iam , technology consulting , software engineering , python , maven , access management
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70587308">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70587308','adId=plB__SLASH__kfMgkdlzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70587308','cloud infrastructure  ,  aws / azure  ,  infrastructure as code  ( iac )   ,  monitoring solutions  ,  devops  , docker , security , java , iam , technology consulting , software engineering , python , maven , access management','New York City','3 - 7','IT Software : Software Products &amp; Services','16','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted 5 days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/assc-dir-customer-success-banking-moody-s-corporation-new-york-city-7-to-10-yrs-jobid-BKmRWcEz729zpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70586379','customer success management  ,  relationship building  ,  communication  ,  banking industry  ,  credit data analysis  , financial services , commercial banking , lending , credit risk , loan origination , relationship manager , trade , underwriting , corporate lending','New York City','7 - 10','Sales / Business Development','17','' )" target="_blank">
#        Assc Dir-Customer Success - Banking</a> </h2>
#  <h3 class="joblist-comp-name">
#      Moody's Corporation
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>7 - 10 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Experience Level: Experienced HireCategories: Sales &amp;amp; MarketingLocation(s): 7 World Trade Center, 250 Greenwich Street, New York, New York, 10007, USThe Role / Respons... <a href="https://www.timesjobs.com/job-detail/assc-dir-customer-success-banking-moody-s-corporation-new-york-city-7-to-10-yrs-jobid-BKmRWcEz729zpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            customer success management  ,  relationship building  ,  communication  ,  banking industry  ,  credit data analysis  , financial services , commercial banking , lending , credit risk , loan origination , relationship manager , trade , underwriting , corporate lending
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
# ...
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            workplace strategy  ,  global budget management  ,  construction project management  ,  business relationship management  ,  team leadership  , recruitment process , compensation
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70584018">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70584018','adId=Hi9CBIC__PLUS__dY9zpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70584018','workplace strategy  ,  global budget management  ,  construction project management  ,  business relationship management  ,  team leadership  , recruitment process , compensation','New York City','5 - 10','Logistics / Procurement / Materials Mgmt. / Supply Chain','20','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/svp-investor-relations-moody-s-corporation-new-york-city-5-to-15-yrs-jobid-oe__PLUS__1enxtJKtzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70582450','investor relations  ,  equity research  ,  financial communication  ,  analytical thinking  ,  strategic planning  , accounting , stock , reporting , cfa , finance','New York City','5 - 15','Sales / Business Development','21','' )" target="_blank">
#        SVP-Investor Relations</a> </h2>
#  <h3 class="joblist-comp-name">
#      Moody's Corporation
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 15 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Experience Level: Experienced HireCategories: Corporate ServicesLocation(s): 7 World Trade Center, 250 Greenwich Street, New York, New York, 10007, USAAt Moody's, we unite the... <a href="https://www.timesjobs.com/job-detail/svp-investor-relations-moody-s-corporation-new-york-city-5-to-15-yrs-jobid-oe__PLUS__1enxtJKtzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            investor relations  ,  equity research  ,  financial communication  ,  analytical thinking  ,  strategic planning  , accounting , stock , reporting , cfa , finance
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70582450">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70582450','adId=oe__PLUS__1enxtJKtzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70582450','investor relations  ,  equity research  ,  financial communication  ,  analytical thinking  ,  strategic planning  , accounting , stock , reporting , cfa , finance','New York City','5 - 15','Sales / Business Development','21','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!--   <span class="comp-logo-bg"> <img src="https://static.timesjobs.com/images_cand/tj_images/insider_img/logos/052092.png" alt="GLG" title="GLG"/> </span> -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/client-solutions-associate-nyc-q1-2025-start-glg-new-york-city-0-to-1-yrs-jobid-G__SLASH__5xnssYcOdzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70582265','client service  ,  communication  ,  project management  ,  recruiting  ,  compliance  , interpersonal skills , learning , training programs , employee development , time management , compensation','New York City','0 - 1','Sales / Business Development','22','' )" target="_blank">
#        Client Solutions Associate - NYC Q1 2025 Start</a> </h2>
#  <h3 class="joblist-comp-name">
#      GLG
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Client Solutions Associate - NYC Q1 2025 StartExperience Level: JuniorWe are seeking recent graduates who have a strong passion for client service to join GLG as an Associate ... <a href="https://www.timesjobs.com/job-detail/client-solutions-associate-nyc-q1-2025-start-glg-new-york-city-0-to-1-yrs-jobid-G__SLASH__5xnssYcOdzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            client service  ,  communication  ,  project management  ,  recruiting  ,  compliance  , interpersonal skills , learning , training programs , employee development , time management , compensation
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70582265">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70582265','adId=G__SLASH__5xnssYcOdzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70582265','client service  ,  communication  ,  project management  ,  recruiting  ,  compliance  , interpersonal skills , learning , training programs , employee development , time management , compensation','New York City','0 - 1','Sales / Business Development','22','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/ion-group-information-security-manager-new-york-ion-trading-india-pvt-ltd-new-york-city-5-to-8-yrs-jobid-m66oPNU1oeJzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70581175','information security  ,  compliance management  ,  soc audits  ,  risk assessment  ,  regulatory compliance  , siem , cissp , cisa , cloud security , dlp , vulnerability , ids / ips , cism , nist , iso 27001 , infrastructure , data privacy , information security management','New York City','5 - 8','Education / Teaching / Language Specialist','23','' )" target="_blank">
#        ION Group - Information Security Manager - New York</a> </h2>
#  <h3 class="joblist-comp-name">
#      ion trading india pvt. ltd.
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>5 - 8 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Information Security Manager - New York, New YorkCompany: ION Analytics  Information Security &amp;amp; ComplianceEmployment Type: Full-timeLocation: On-siteThe Role:We are se... <a href="https://www.timesjobs.com/job-detail/ion-group-information-security-manager-new-york-ion-trading-india-pvt-ltd-new-york-city-5-to-8-yrs-jobid-m66oPNU1oeJzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            information security  ,  compliance management  ,  soc audits  ,  risk assessment  ,  regulatory compliance  , siem , cissp , cisa , cloud security , dlp , vulnerability , ids / ips , cism , nist , iso 27001 , infrastructure , data privacy , information security management
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70581175">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70581175','adId=m66oPNU1oeJzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70581175','information security  ,  compliance management  ,  soc audits  ,  risk assessment  ,  regulatory compliance  , siem , cissp , cisa , cloud security , dlp , vulnerability , ids / ips , cism , nist , iso 27001 , infrastructure , data privacy , information security management','New York City','5 - 8','Education / Teaching / Language Specialist','23','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/staff-iam-engineer-alphasense-new-york-city-8-to-11-yrs-jobid-oKe9s5zpK6tzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70580012','identity management  ,  access control  ,  security architecture  ,  cloud security  ,  web applications  , ajax , iam , json , access management','New York City','8 - 11','IT Software : Software Products &amp; Services','24','' )" target="_blank">
#        Staff IAM Engineer</a> </h2>
#  <h3 class="joblist-comp-name">
#      AlphaSense
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>8 - 11 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  About AlphaSense:AlphaSense is a market intelligence and search platform used by the world's leading companies and financial institutions. Since 2011, our AI-based technology ... <a href="https://www.timesjobs.com/job-detail/staff-iam-engineer-alphasense-new-york-city-8-to-11-yrs-jobid-oKe9s5zpK6tzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            identity management  ,  access control  ,  security architecture  ,  cloud security  ,  web applications  , ajax , iam , json , access management
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70580012">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70580012','adId=oKe9s5zpK6tzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70580012','identity management  ,  access control  ,  security architecture  ,  cloud security  ,  web applications  , ajax , iam , json , access management','New York City','8 - 11','IT Software : Software Products &amp; Services','24','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>,
#  <li class="clearfix job-bx wht-shd-bx">
#  <header class="clearfix">
#  <!--
#  -->
#  <!-- -->
#  <h2>
#  <a href="https://www.timesjobs.com/job-detail/veeva-systems-senior-health-data-analyst-data-onboarding-veeva-compass-veeva-systems-new-york-city-4-to-7-yrs-jobid-yKuXntSdezZzpSvf__PLUS__uAgZw==&amp;source=srp" onclick="logViewUSBT('view','70494891','health data analysis  ,  data onboarding  ,  sql querying  ,  analytics presentation  ,  python programming  , recruitment process , compensation','New York City','4 - 7','Biotech / Pharma / R&amp;D','25','' )" target="_blank">
#        Veeva Systems - Senior Health Data Analyst - Data Onboarding - Veeva Compass</a> </h2>
#  <h3 class="joblist-comp-name">
#      Veeva Systems
#
#      </h3>
#  </header>
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>4 - 7 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="New York City">New York City</span>
#  </li>
#  </ul>
#  <ul class="list-job-dtl clearfix">
#  <li>
#  <label>Job Description:</label>
#  Senior Health Data Analyst - Data Onboarding - Veeva CompassLocation: New York CityAnalytics  627-Stgy Crossix VDCFull-TimeRemoteVeeva Systems is a mission-driven organization... <a href="https://www.timesjobs.com/job-detail/veeva-systems-senior-health-data-analyst-data-onboarding-veeva-compass-veeva-systems-new-york-city-4-to-7-yrs-jobid-yKuXntSdezZzpSvf__PLUS__uAgZw==&amp;source=srp" target="_blank">More Details</a>
#  </li>
#  <li>
#  <label>KeySkills:</label>
#  <span class="srp-skills">
#
#            health data analysis  ,  data onboarding  ,  sql querying  ,  analytics presentation  ,  python programming  , recruitment process , compensation
#
#        </span> </li>
#  <!--
#              <li>
#                <i class="material-icons">location_on</i>
#                New York City
#                </li>
#  -->
#  </ul>
#  <div class="list-job-bt clearfix">
#  <div class="list-action">
#  <div class="applied-dtl clearfix" id="showPostApplyData_70494891">
#  <a class="waves-effect waves-light btn" href="javascript:callExtJobApply('70494891','adId=yKuXntSdezZzpSvf__PLUS__uAgZw==&amp;compName=Career Progress Consultants','TJPFSRP');" onclick="trackClickEvent('View_AND_Apply_SRP','from_srp_externalJobs');logViewUSBT('apply','70494891','health data analysis  ,  data onboarding  ,  sql querying  ,  analytics presentation  ,  python programming  , recruitment process , compensation','New York City','4 - 7','Biotech / Pharma / R&amp;D','25','')">Apply</a>
#  <span class="jobs-status clearfix">
#  <!--
#         <i class="material-icons trnding-up" title="Recently posted job, Recruiter is actively looking for candidates">check_circle</i>
#
#  -->
#  </span>
#  <span class="sim-posted">
#  <span>Posted few days ago</span>
#  </span>
#  </div>
#  </div>
#  </div>
#  </li>]

# %%
for trabalho in trabalhos:
    empresa = trabalho.find('h3', class_='joblist-comp-name').text.split()
    habilidades = trabalho.find('span', class_='srp-skills').text.strip().split(',')
    for i in range(len(habilidades)):
        habilidades[i] = habilidades[i].strip()
    tempo = trabalho.find('span', class_='sim-posted').span.text

    print(f'''
    Empresa: {empresa}
    Habilidades: {habilidades}
    Tempo de Postagem: {tempo}
    ''')
# Out:
#     Empresa: ['AlphaSense']
#     Habilidades: ['content analysis', 'communication skills', 'analytical skills', 'troubleshooting', 'research skills', 'press', 'written communication']
#     Tempo de Postagem: Posted 2 days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['advanced tv activation', 'client facing communication', 'data analytics', 'strategic account management', 'business development', 'communication skills', 'recruitment process', 'compensation']
#     Tempo de Postagem: Posted 2 days ago
#
#
#     Empresa: ['NTT', 'Data', 'Vertex', 'Software', 'Inc.']
#     Habilidades: ['risk management', 'compliance consulting', 'financial services', 'project management', 'data privacy', 'delivery excellence', 'senior manager', 'technology consulting', 'infrastructure services', 'project initiation', 'customer engagement']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['CAPITAL', 'ONE', 'FINANCIAL', 'SERVICES', 'CLIENT']
#     Habilidades: ['front end development', 'software engineering', 'test driven development', 'agile practices', 'cloud services', 'css', 'java', 'html', 'san', 'javascript']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['demand generation', 'field marketing', 'integrated marketing', 'vendor management', 'project management', 'medical', 'campaigns', 'social media', 'marketing automation', 'product marketing', 'marketing programs']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['data analytics', 'marketing analysis', 'sql', 'business intelligence', 'communication skills', 'spring', 'database', 'san', 'team player']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['healthcare analytics', 'client relationship management', 'data driven insights', 'communication skills', 'quantitative analysis', 'learning', 'recruitment process', 'compensation']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['NTT', 'Data', 'Vertex', 'Software', 'Inc.']
#     Habilidades: ['azure services', 'kubernetes', 'terraform scripting', 'python development', 'azure active directory', 'storage', 'artificial intelligence', 'sql', 'spring', 'security', 'java', 'iam', 'devops', 'technology consulting', 'shell scripting', 'api', 'github', 'access management', 'infrastructure', 'splunk', 'gateway']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['NTT', 'Data', 'Vertex', 'Software', 'Inc.']
#     Habilidades: ['pytorch', 'nltk', 'scipy', 'numpy', 'sql', 'nosql databases', 'deep learning concepts', 'gpu training', 'docker', 'cloudera', 'algorithms', 'soa', 'ensemble', 'artificial intelligence', 'oop', 'technology consulting', 'mysql', 'technical skills', 'mongodb', 'rest', 'python', 'oracle', 'machine learning', 'messaging', 'infrastructure', 'opencv']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ['buck', 'global', 'llc']
#     Habilidades: ['strategic leadership', 'customer insight', 'data analytics', 'executive communication', 'team empowerment', 'fundamentals', 'director', 'forms']
#     Tempo de Postagem: Posted 3 days ago
#
#
#     Empresa: ["Moody's", 'Corporation']
#     Habilidades: ['typescript & reactjs', 'html & css', 'nodejs', 'aws serverless', 'front end development tools', 'sso', 'api', 'nosql', 'web technologies', 'docker', 'elastic search', 'git', 'postgresql', 'san', 'cloud services', 'ant', 'gateway']
#     Tempo de Postagem: Posted 4 days ago
#
#
#     Empresa: ['grawlix', 'software', 'private', 'limited', 'pune']
#     Habilidades: ['github', 'html5', 'javascript', 'web technologies', 'mysql']
#     Tempo de Postagem: Posted 5 days ago
#
#
#     Empresa: ['grawlix', 'software', 'private', 'limited', 'pune']
#     Habilidades: ['.net developer', 'asp .net', 'jquery', 'oop', 'database', '.net', 'business applications']
#     Tempo de Postagem: Posted 5 days ago
#
#
#     Empresa: ['AlphaSense']
#     Habilidades: ['cloud infrastructure', 'kubernetes operations', 'devsecops skills', 'automation tools', 'programming proficiency', 'security specialist', 'orchestration', 'storage', 'docker', 'java', 'linux', 'api', 'cloud services', 'python', 'mobile', 'csi']
#     Tempo de Postagem: Posted 5 days ago
#
#
#     Empresa: ['ion', 'trading', 'india', 'pvt.', 'ltd.']
#     Habilidades: ['cloud infrastructure engineering', 'aws / azure environments', 'infrastructure as code  ( iac )', 'devops infrastructure', 'monitoring & observability', 'orchestration', 'security', 'java', 'iam', 'mks', 'technology consulting', 'software engineering', 'python', 'mq', 'access management']
#     Tempo de Postagem: Posted 5 days ago
#
#
#     Empresa: ['ion', 'trading', 'india', 'pvt.', 'ltd.']
#     Habilidades: ['cloud infrastructure', 'aws / azure', 'infrastructure as code  ( iac )', 'monitoring solutions', 'devops', 'docker', 'security', 'java', 'iam', 'technology consulting', 'software engineering', 'python', 'maven', 'access management']
#     Tempo de Postagem: Posted 5 days ago
#
#
#     Empresa: ["Moody's", 'Corporation']
#     Habilidades: ['customer success management', 'relationship building', 'communication', 'banking industry', 'credit data analysis', 'financial services', 'commercial banking', 'lending', 'credit risk', 'loan origination', 'relationship manager', 'trade', 'underwriting', 'corporate lending']
#     Tempo de Postagem: Posted 6 days ago
#
#
#     Empresa: ['PUBLICIS', 'GROUPE']
#     Habilidades: ['media planning', '', 'advertising agency', '', 'marketing services', '', 'diversity & inclusion', '', 'talent development', 'performance management']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['Looking', 'for', 'H1B', 'Sponsorship']
#     Habilidades: ['business development', 'sales strategy', 'team leadership', 'crm management', 'data analysis', 'medical', 'campaigns', 'marketing automation', 'hubspot']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['workplace strategy', 'global budget management', 'construction project management', 'business relationship management', 'team leadership', 'recruitment process', 'compensation']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ["Moody's", 'Corporation']
#     Habilidades: ['investor relations', 'equity research', 'financial communication', 'analytical thinking', 'strategic planning', 'accounting', 'stock', 'reporting', 'cfa', 'finance']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['GLG']
#     Habilidades: ['client service', 'communication', 'project management', 'recruiting', 'compliance', 'interpersonal skills', 'learning', 'training programs', 'employee development', 'time management', 'compensation']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['ion', 'trading', 'india', 'pvt.', 'ltd.']
#     Habilidades: ['information security', 'compliance management', 'soc audits', 'risk assessment', 'regulatory compliance', 'siem', 'cissp', 'cisa', 'cloud security', 'dlp', 'vulnerability', 'ids / ips', 'cism', 'nist', 'iso 27001', 'infrastructure', 'data privacy', 'information security management']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['AlphaSense']
#     Habilidades: ['identity management', 'access control', 'security architecture', 'cloud security', 'web applications', 'ajax', 'iam', 'json', 'access management']
#     Tempo de Postagem: Posted few days ago
#
#
#     Empresa: ['Veeva', 'Systems']
#     Habilidades: ['health data analysis', 'data onboarding', 'sql querying', 'analytics presentation', 'python programming', 'recruitment process', 'compensation']
#     Tempo de Postagem: Posted few days ago

# %%
empresa
# Out:
# ['Veeva', 'Systems']

# %%
habilidades
# Out:
# ['health data analysis',
#  'data onboarding',
#  'sql querying',
#  'analytics presentation',
#  'python programming',
#  'recruitment process',
#  'compensation']

# %%
habilidades[i].strip()
# Out:
# 'compensation'
