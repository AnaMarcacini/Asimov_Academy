# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.24.0-py3-none-any.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: typing_extensions~=4.9 in /home/anamarcacini/.local/lib/python3.10/site-packages (from selenium) (4.12.2)
# Collecting trio~=0.17
#   Downloading trio-0.26.2-py3-none-any.whl (475 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.0/476.0 KB 11.0 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Collecting websocket-client~=1.8
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /home/anamarcacini/.local/lib/python3.10/site-packages (from selenium) (1.26.15)
# Requirement already satisfied: certifi>=2021.10.8 in /home/anamarcacini/.local/lib/python3.10/site-packages (from selenium) (2022.12.7)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Collecting attrs>=23.2.0
#   Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 KB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.3.0 in /home/anamarcacini/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: idna in /home/anamarcacini/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: exceptiongroup in /home/anamarcacini/.local/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.1)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /home/anamarcacini/.local/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.9.0)
# Installing collected packages: sortedcontainers, wsproto, websocket-client, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.1
#     Uninstalling websocket-client-1.6.1:
#       Successfully uninstalled websocket-client-1.6.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-24.2.0 outcome-1.3.0.post0 selenium-4.24.0 sortedcontainers-2.4.0 trio-0.26.2 trio-websocket-0.11.1 websocket-client-1.8.0 wsproto-1.2.0

# %%
# !pip install webdriver_manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /home/anamarcacini/.local/lib/python3.10/site-packages (from webdriver_manager) (23.1)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from webdriver_manager) (2.25.1)
# Installing collected packages: python-dotenv, webdriver_manager
# Successfully installed python-dotenv-1.0.1 webdriver_manager-4.0.2

# %%
import statistics
from lxml import html
from bs4 import BeautifulSoup, Comment
import pandas as pd
import requests

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

import plotly.graph_objects as go


teams_adress_A = {'palmeiras' : 'palmeiras/1963', 'internacional' : 'internacional/1966', 'flamengo' : 'flamengo/5981', 'fluminense' : 'fluminense/1961',
'corinthians' : 'corinthians/1957', 'athletico paranaense' : 'athletico/1967', 'atletico mineiro' : 'atletico-mineiro/1977',
'america mineiro' : 'america-mineiro/1973', 'fortaleza' : 'fortaleza/2020', 'botafogo' : 'botafogo/1958', 'santos' : 'santos/1968',
'sao paulo' : 'sao-paulo/1981', 'bragantino' : 'red-bull-bragantino/1999', 'goias' : 'goias/1960', 'coritiba' : 'coritiba/1982',
'ceara' : 'ceara/2001', 'cuiaba' : 'cuiaba/49202', 'atletico goianiense' : 'atletico-goianiense/7314', 'avai' : 'avai/7315', 'juventude' : 'juventude/1980'}

teams_adress_B = {'cruzeiro' : 'cruzeiro/1954', 'gremio' : 'gremio/5926', 'vasco' : 'vasco-da-gama/1974', 'bahia' : 'bahia/1955', 'ituano' : 'ituano/2025',
'londrina' : 'londrina/2022', 'sport' : 'sport-recife/1959', 'sampaio correa' : 'sampaio-correa/2005', 'criciuma' : 'criciuma/1984', 'crb' : 'crb/22032',
'guarani' : 'guarani/1972', 'vila nova' : 'vila-nova/2021',  'ponte preta' : 'ponte-preta/1969', 'tombense' : 'tombense/87202', 'chapecoense' : 'chapecoense/21845',
'csa' : 'csa/2010', 'novorizontino' : 'novorizontino/135514', 'brusque' : 'brusque-fc/21884', 'operario' : 'operario/39634', 'nautico' : 'nautico/2011'}


browsers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \(KHTML, like Gecko) Chrome / 86.0.4240.198Safari / 537.36"}

base_api = 'https://api.sofascore.com/api/v1/team/'
end_api = '/statistics/overall'

pd.options.display.max_rows = 150



def escolhe_time(time:str):

    data_list = []
    cont_url_list = 0
    cont_data_list = 0

    division = input(str('Em qual divisão está o time?')).upper()

    if division == 'A':
        serie = '325'
        id_time = teams_adress_A[time.lower()][-4:]
        enpoint_17 = '13100'
        enpoint_18 = '16183'
        enpoint_19 = '22931'
        enpoint_20 = '27591'
        enpoint_21 = '36166'
        enpoint_22 = '40557'

    elif division == 'B':
        serie = '390'
        id_time = teams_adress_B[time.lower()][-4:]
        enpoint_17 = ''
        enpoint_18 = '16184'
        enpoint_19 = '22932'
        enpoint_20 = '27593'
        enpoint_21 = '36162'
        enpoint_22 = '40560'
    



    middle_api = f'/unique-tournament/{serie}/season/'

    url_17 = base_api + id_time + middle_api + enpoint_17 + end_api
    url_18 = base_api + id_time + middle_api + enpoint_18 + end_api
    url_19 = base_api + id_time + middle_api + enpoint_19 + end_api
    url_20 = base_api + id_time + middle_api + enpoint_20 + end_api
    url_21 = base_api + id_time + middle_api + enpoint_21 + end_api
    url_22 = base_api + id_time + middle_api + enpoint_22 + end_api

    urls_list = [url_17, url_18, url_19, url_20, url_21, url_22]
    

    for url in urls_list:
        api_link = requests.get(url, headers = browsers).json()
        if not 'error' in api_link:
            data_list.append(api_link['statistics'])
            if urls_list.index(urls_list[cont_url_list]) == 0:
                data_list[cont_data_list]['ano'] = 2017
            elif urls_list.index(urls_list[cont_url_list]) == 1:
                data_list[cont_data_list]['ano'] = 2018
            elif urls_list.index(urls_list[cont_url_list]) == 2:
                data_list[cont_data_list]['ano'] = 2019
            elif urls_list.index(urls_list[cont_url_list]) == 3:
                data_list[cont_data_list]['ano'] = 2020
            elif urls_list.index(urls_list[cont_url_list]) == 4:
                data_list[cont_data_list]['ano'] = 2021
            elif urls_list.index(urls_list[cont_url_list]) == 5:
                data_list[cont_data_list]['ano'] = 2022
            cont_data_list+=1
        cont_url_list+=1

    return data_list

def build_dataframe(time:str): 
    team = escolhe_time(time.lower())


    team_dataframe = pd.DataFrame(index = team[0].keys())

    for i in range(len(team)):
        team_dataframe[str(team[i]['ano'])] = team[i].values()
        team_dataframe[str(team[i]['ano'])] = team_dataframe[str(team[i]['ano'])].apply(lambda x: float("{:.0f}".format(x)))

    team_dataframe['Media'] = team_dataframe.mean(axis=1).apply(lambda x: float("{:.1f}".format(x)))

    return team_dataframe



def build_chart(metric:str, time1:str, time2:str):
    df_time1 = build_dataframe(time1.lower())
    df_time2 = build_dataframe(time2.lower())
    anos=['2017', '2018', '2019', '2020', '2021', '2022']

    fig = go.Figure(
        data=[
            go.Bar(name=time1, x=anos, y=[df_time1['2017'][metric], df_time1['2018'][metric], df_time1['2019'][metric], df_time1['2020'][metric], df_time1['2021'][metric], df_time1['2022'][metric]]),
            go.Bar(name=time2, x=anos, y=[df_time2['2017'][metric], df_time2['2018'][metric], df_time2['2019'][metric], df_time2['2020'][metric], df_time2['2021'][metric], df_time2['2022'][metric]])

        ],
        layout_title_text = metric
    )
    
    return fig.show()

# %%
escolhe_time("palmeiras")
# Out:
# [{'goalsScored': 52,
#   'goalsConceded': 58,
#   'ownGoals': 0,
#   'assists': 56,
#   'shots': 76,
#   'penaltyGoals': 4,
#   'penaltiesTaken': 8,
#   'freeKickGoals': 0,
#   'freeKickShots': 0,
#   'goalsFromInsideTheBox': 0,
#   'goalsFromOutsideTheBox': 6,
#   'shotsFromInsideTheBox': 0,
#   'shotsFromOutsideTheBox': 0,
#   'headedGoals': 18,
#   'leftFootGoals': 10,
#   'rightFootGoals': 50,
#   'bigChances': 10,
#   'bigChancesCreated': 44,
#   'bigChancesMissed': 20,
#   'shotsOnTarget': 230,
#   'shotsOffTarget': 262,
#   'blockedScoringAttempt': 60,
#   'successfulDribbles': 38,
#   'dribbleAttempts': 278,
#   'corners': 124,
#   'hitWoodwork': 6,
#   'fastBreaks': 14,
#   'fastBreakGoals': 0,
#   'fastBreakShots': 2,
#   'averageBallPossession': 76.98285007603641,
#   'totalPasses': 10174,
#   'accuratePasses': 21190,
#   'accuratePassesPercentage': 145.41465406681135,
#   'totalOwnHalfPasses': 3310,
#   'accurateOwnHalfPasses': 230,
#   'accurateOwnHalfPassesPercentage': 95.08907335510898,
#   'totalOppositionHalfPasses': 20632,
#   'accurateOppositionHalfPasses': 9482,
#   'accurateOppositionHalfPassesPercentage': 100.71425138617963,
#   'totalLongBalls': 372,
#   'accurateLongBalls': 1226,
#   'accurateLongBallsPercentage': 8.227940141800225,
#   'totalCrosses': 1696,
#   'accurateCrosses': 56,
#   'accurateCrossesPercentage': 25.98930208003073,
#   'cleanSheets': 0,
#   'tackles': 1116,
#   'interceptions': 910,
#   'saves': 26,
#   'errorsLeadingToGoal': 0,
#   'errorsLeadingToShot': 0,
#   'penaltiesCommited': 0,
#   'penaltyGoalsConceded': 0,
#   'clearances': 422,
#   'clearancesOffLine': 0,
#   'lastManTackles': 0,
#   'totalDuels': 3850,
#   'duelsWon': 3092,
#   'duelsWonPercentage': 15.90643462883164,
#   'totalGroundDuels': 2682,
#   'groundDuelsWon': 2492,
#   'groundDuelsWonPercentage': 24.182289312366066,
#   'totalAerialDuels': 1330,
#   'aerialDuelsWon': 0,
#   'aerialDuelsWonPercentage': 9.947284847045097,
#   'possessionLost': 5824,
#   'offsides': 78,
#   'fouls': 1102,
#   'yellowCards': 14,
#   'yellowRedCards': 0,
#   'redCards': 0,
#   'avgRating': 4.656814231276365,
#   'accurateFinalThirdPassesAgainst': 2172,
#   'accurateOppositionHalfPassesAgainst': 10010,
#   'accurateOwnHalfPassesAgainst': 8324,
#   'accuratePassesAgainst': 6366,
#   'bigChancesAgainst': 6,
#   'bigChancesCreatedAgainst': 14,
#   'bigChancesMissedAgainst': 26,
#   'clearancesAgainst': 716,
#   'cornersAgainst': 280,
#   'crossesSuccessfulAgainst': 98,
#   'crossesTotalAgainst': 660,
#   'dribbleAttemptsTotalAgainst': 280,
#   'dribbleAttemptsWonAgainst': 452,
#   'errorsLeadingToGoalAgainst': 2,
#   'errorsLeadingToShotAgainst': 4,
#   'hitWoodworkAgainst': 6,
#   'interceptionsAgainst': 400,
#   'keyPassesAgainst': 330,
#   'longBallsSuccessfulAgainst': 1544,
#   'longBallsTotalAgainst': 4118,
#   'offsidesAgainst': 78,
#   'redCardsAgainst': 4,
#   'shotsAgainst': 370,
#   'shotsBlockedAgainst': 94,
#   'shotsFromInsideTheBoxAgainst': 0,
#   'shotsFromOutsideTheBoxAgainst': 0,
#   'shotsOffTargetAgainst': 64,
#   'shotsOnTargetAgainst': 98,
#   'blockedScoringAttemptAgainst': 70,
#   'tacklesAgainst': 46,
#   'totalFinalThirdPassesAgainst': 1840,
#   'oppositionHalfPassesTotalAgainst': 13920,
#   'ownHalfPassesTotalAgainst': 358,
#   'totalPassesAgainst': 21734,
#   'yellowCardsAgainst': 20,
#   'id': 3514,
#   'matches': 56,
#   'awardedMatches': 0,
#   'ano': 2017},
#  {'goalsScored': 16,
#   'goalsConceded': 30,
#   'ownGoals': 0,
#   'assists': 36,
#   'shots': 382,
#   'penaltyGoals': 8,
#   'penaltiesTaken': 6,
#   'freeKickGoals': 2,
#   'freeKickShots': 2,
#   'goalsFromInsideTheBox': 14,
#   'goalsFromOutsideTheBox': 10,
#   'shotsFromInsideTheBox': 16,
#   'shotsFromOutsideTheBox': 4,
#   'headedGoals': 14,
#   'leftFootGoals': 18,
#   'rightFootGoals': 12,
#   'bigChances': 98,
#   'bigChancesCreated': 30,
#   'bigChancesMissed': 56,
#   'shotsOnTarget': 336,
#   'shotsOffTarget': 70,
#   'blockedScoringAttempt': 228,
#   'successfulDribbles': 140,
#   'dribbleAttempts': 304,
#   'corners': 24,
#   'hitWoodwork': 8,
#   'fastBreaks': 4,
#   'fastBreakGoals': 0,
#   'fastBreakShots': 10,
#   'averageBallPossession': 24.22097817572009,
#   'totalPasses': 25682,
#   'accuratePasses': 5850,
#   'accuratePassesPercentage': 90.9797584948945,
#   'totalOwnHalfPasses': 3466,
#   'accurateOwnHalfPasses': 11096,
#   'accurateOwnHalfPassesPercentage': 15.769265386685348,
#   'totalOppositionHalfPasses': 18024,
#   'accurateOppositionHalfPasses': 10314,
#   'accurateOppositionHalfPassesPercentage': 121.1323961258683,
#   'totalLongBalls': 2444,
#   'accurateLongBalls': 30,
#   'accurateLongBallsPercentage': 2.0450119080753737,
#   'totalCrosses': 232,
#   'accurateCrosses': 8,
#   'accurateCrossesPercentage': 17.160384301893554,
#   'cleanSheets': 10,
#   'tackles': 814,
#   'interceptions': 348,
#   'saves': 168,
#   'errorsLeadingToGoal': 4,
#   'errorsLeadingToShot': 0,
#   'penaltiesCommited': 2,
#   'penaltyGoalsConceded': 0,
#   'clearances': 1316,
#   'clearancesOffLine': 0,
#   'lastManTackles': 0,
#   'totalDuels': 640,
#   'duelsWon': 2124,
#   'duelsWonPercentage': 29.29714503031473,
#   'totalGroundDuels': 162,
#   'groundDuelsWon': 2284,
#   'groundDuelsWonPercentage': 35.04877162836957,
#   'totalAerialDuels': 2482,
#   'aerialDuelsWon': 750,
#   'aerialDuelsWonPercentage': 83.00713617067716,
#   'possessionLost': 802,
#   'offsides': 44,
#   'fouls': 10,
#   'yellowCards': 84,
#   'yellowRedCards': 0,
#   'redCards': 2,
#   'avgRating': 12.975816772948749,
#   'accurateFinalThirdPassesAgainst': 930,
#   'accurateOppositionHalfPassesAgainst': 5884,
#   'accurateOwnHalfPassesAgainst': 5406,
#   'accuratePassesAgainst': 10468,
#   'bigChancesAgainst': 86,
#   'bigChancesCreatedAgainst': 24,
#   'bigChancesMissedAgainst': 26,
#   'clearancesAgainst': 214,
#   'cornersAgainst': 220,
#   'crossesSuccessfulAgainst': 158,
#   'crossesTotalAgainst': 1044,
#   'dribbleAttemptsTotalAgainst': 792,
#   'dribbleAttemptsWonAgainst': 16,
#   'errorsLeadingToGoalAgainst': 4,
#   'errorsLeadingToShotAgainst': 4,
#   'hitWoodworkAgainst': 4,
#   'interceptionsAgainst': 156,
#   'keyPassesAgainst': 214,
#   'longBallsSuccessfulAgainst': 124,
#   'longBallsTotalAgainst': 692,
#   'offsidesAgainst': 18,
#   'redCardsAgainst': 4,
#   'shotsAgainst': 84,
#   'shotsBlockedAgainst': 180,
#   'shotsFromInsideTheBoxAgainst': 10,
#   'shotsFromOutsideTheBoxAgainst': 2,
#   'shotsOffTargetAgainst': 230,
#   'shotsOnTargetAgainst': 44,
#   'blockedScoringAttemptAgainst': 44,
#   'tacklesAgainst': 794,
#   'totalFinalThirdPassesAgainst': 6500,
#   'oppositionHalfPassesTotalAgainst': 8382,
#   'ownHalfPassesTotalAgainst': 14400,
#   'totalPassesAgainst': 24032,
#   'yellowCardsAgainst': 134,
#   'id': 890,
#   'matches': 42,
#   'awardedMatches': 0,
#   'ano': 2018},
#  {'goalsScored': 56,
#   'goalsConceded': 38,
#   'ownGoals': 0,
#   'assists': 6,
#   'shots': 476,
#   'penaltyGoals': 0,
#   'penaltiesTaken': 6,
#   'freeKickGoals': 0,
#   'freeKickShots': 50,
#   'goalsFromInsideTheBox': 18,
#   'goalsFromOutsideTheBox': 4,
#   'shotsFromInsideTheBox': 398,
#   'shotsFromOutsideTheBox': 186,
#   'headedGoals': 18,
#   'leftFootGoals': 0,
#   'rightFootGoals': 12,
#   'bigChances': 46,
#   'bigChancesCreated': 98,
#   'bigChancesMissed': 6,
#   'shotsOnTarget': 210,
#   'shotsOffTarget': 2,
#   'blockedScoringAttempt': 146,
#   'successfulDribbles': 336,
#   'dribbleAttempts': 354,
#   'corners': 94,
#   'hitWoodwork': 18,
#   'fastBreaks': 12,
#   'fastBreakGoals': 0,
#   'fastBreakShots': 12,
#   'averageBallPossession': 26.48295167544176,
#   'totalPasses': 15916,
#   'accuratePasses': 20696,
#   'accuratePassesPercentage': 152.06577144450785,
#   'totalOwnHalfPasses': 9584,
#   'accurateOwnHalfPasses': 2562,
#   'accurateOwnHalfPassesPercentage': 143.26933958672606,
#   'totalOppositionHalfPasses': 13938,
#   'accurateOppositionHalfPasses': 9246,
#   'accurateOppositionHalfPassesPercentage': 13.490555801962628,
#   'totalLongBalls': 554,
#   'accurateLongBalls': 970,
#   'accurateLongBallsPercentage': 36.46826679628722,
#   'totalCrosses': 888,
#   'accurateCrosses': 306,
#   'accurateCrossesPercentage': 9.581992762895709,
#   'cleanSheets': 18,
#   'tackles': 204,
#   'interceptions': 386,
#   'saves': 174,
#   'errorsLeadingToGoal': 0,
#   'errorsLeadingToShot': 2,
#   'penaltiesCommited': 10,
#   'penaltyGoalsConceded': 4,
#   'clearances': 872,
#   'clearancesOffLine': 0,
#   'lastManTackles': 0,
#   'totalDuels': 2270,
#   'duelsWon': 1292,
#   'duelsWonPercentage': 12.065567639884321,
#   'totalGroundDuels': 3694,
#   'groundDuelsWon': 1370,
#   'groundDuelsWonPercentage': 58.797825552740086,
#   'totalAerialDuels': 308,
#   'aerialDuelsWon': 346,
#   'aerialDuelsWonPercentage': 2.891757313989693,
#   'possessionLost': 7294,
#   'offsides': 8,
#   'fouls': 1068,
#   'yellowCards': 122,
#   'yellowRedCards': 0,
#   'redCards': 2,
#   'avgRating': 6.681964271522369,
#   'accurateFinalThirdPassesAgainst': 3948,
#   'accurateOppositionHalfPassesAgainst': 10066,
#   'accurateOwnHalfPassesAgainst': 3104,
#   'accuratePassesAgainst': 11162,
#   'bigChancesAgainst': 16,
#   'bigChancesCreatedAgainst': 4,
#   'bigChancesMissedAgainst': 20,
#   'clearancesAgainst': 838,
#   'cornersAgainst': 216,
#   'crossesSuccessfulAgainst': 72,
#   'crossesTotalAgainst': 860,
#   'dribbleAttemptsTotalAgainst': 1038,
#   'dribbleAttemptsWonAgainst': 40,
#   'errorsLeadingToGoalAgainst': 0,
#   'errorsLeadingToShotAgainst': 0,
#   'hitWoodworkAgainst': 0,
#   'interceptionsAgainst': 140,
#   'keyPassesAgainst': 562,
#   'longBallsSuccessfulAgainst': 1630,
#   'longBallsTotalAgainst': 2414,
#   'offsidesAgainst': 32,
#   'redCardsAgainst': 0,
#   'shotsAgainst': 570,
#   'shotsBlockedAgainst': 142,
#   'shotsFromInsideTheBoxAgainst': 204,
#   'shotsFromOutsideTheBoxAgainst': 92,
#   'shotsOffTargetAgainst': 220,
#   'shotsOnTargetAgainst': 244,
#   'blockedScoringAttemptAgainst': 160,
#   'tacklesAgainst': 788,
#   'totalFinalThirdPassesAgainst': 7432,
#   'oppositionHalfPassesTotalAgainst': 3322,
#   'ownHalfPassesTotalAgainst': 1048,
#   'totalPassesAgainst': 14614,
#   'yellowCardsAgainst': 152,
#   'id': 1086,
#   'matches': 14,
#   'awardedMatches': 0,
#   'ano': 2019},
#  {'goalsScored': 82,
#   'goalsConceded': 2,
#   'ownGoals': 0,
#   'assists': 42,
#   'shots': 784,
#   'penaltyGoals': 2,
#   'penaltiesTaken': 2,
#   'freeKickGoals': 0,
#   'freeKickShots': 4,
#   'goalsFromInsideTheBox': 68,
#   'goalsFromOutsideTheBox': 2,
#   'shotsFromInsideTheBox': 412,
#   'shotsFromOutsideTheBox': 16,
#   'headedGoals': 10,
#   'leftFootGoals': 22,
#   'rightFootGoals': 20,
#   'bigChances': 76,
#   'bigChancesCreated': 4,
#   'bigChancesMissed': 58,
#   'shotsOnTarget': 190,
#   'shotsOffTarget': 92,
#   'blockedScoringAttempt': 152,
#   'successfulDribbles': 270,
#   'dribbleAttempts': 488,
#   'corners': 96,
#   'hitWoodwork': 2,
#   'fastBreaks': 6,
#   'fastBreakGoals': 0,
#   'fastBreakShots': 22,
#   'averageBallPossession': 50.44944400011488,
#   'totalPasses': 9534,
#   'accuratePasses': 26772,
#   'accuratePassesPercentage': 56.23729734125382,
#   'totalOwnHalfPasses': 13928,
#   'accurateOwnHalfPasses': 8170,
#   'accurateOwnHalfPassesPercentage': 77.82469718590487,
#   'totalOppositionHalfPasses': 16174,
#   'accurateOppositionHalfPasses': 1088,
#   'accurateOppositionHalfPassesPercentage': 87.80019491088042,
#   'totalLongBalls': 1250,
#   'accurateLongBalls': 1488,
#   'accurateLongBallsPercentage': 95.20263532507056,
#   'totalCrosses': 1100,
#   'accurateCrosses': 176,
#   'accurateCrossesPercentage': 21.051518950519647,
#   'cleanSheets': 4,
#   'tackles': 588,
#   'interceptions': 772,
#   'saves': 28,
#   'errorsLeadingToGoal': 0,
#   'errorsLeadingToShot': 4,
#   'penaltiesCommited': 6,
#   'penaltyGoalsConceded': 0,
#   'clearances': 312,
#   'clearancesOffLine': 0,
#   'lastManTackles': 0,
#   'totalDuels': 5376,
#   'duelsWon': 388,
#   'duelsWonPercentage': 67.13911958521304,
#   'totalGroundDuels': 4202,
#   'groundDuelsWon': 1216,
#   'groundDuelsWonPercentage': 2.056834983266505,
#   'totalAerialDuels': 1912,
#   'aerialDuelsWon': 1008,
#   'aerialDuelsWonPercentage': 1.6675471460848144,
#   'possessionLost': 8670,
#   'offsides': 6,
#   'fouls': 280,
#   'yellowCards': 40,
#   'yellowRedCards': 0,
#   'redCards': 4,
#   'avgRating': 4.413548052355802,
#   'accurateFinalThirdPassesAgainst': 4256,
#   'accurateOppositionHalfPassesAgainst': 8744,
#   'accurateOwnHalfPassesAgainst': 8154,
#   'accuratePassesAgainst': 1640,
#   'bigChancesAgainst': 32,
#   'bigChancesCreatedAgainst': 28,
#   'bigChancesMissedAgainst': 14,
#   'clearancesAgainst': 58,
#   'cornersAgainst': 74,
#   'crossesSuccessfulAgainst': 72,
#   'crossesTotalAgainst': 484,
#   'dribbleAttemptsTotalAgainst': 1320,
#   'dribbleAttemptsWonAgainst': 624,
#   'errorsLeadingToGoalAgainst': 4,
#   'errorsLeadingToShotAgainst': 2,
#   'hitWoodworkAgainst': 0,
#   'interceptionsAgainst': 94,
#   'keyPassesAgainst': 48,
#   'longBallsSuccessfulAgainst': 212,
#   'longBallsTotalAgainst': 236,
#   'offsidesAgainst': 66,
#   'redCardsAgainst': 8,
#   'shotsAgainst': 146,
#   'shotsBlockedAgainst': 160,
#   'shotsFromInsideTheBoxAgainst': 320,
#   'shotsFromOutsideTheBoxAgainst': 28,
#   'shotsOffTargetAgainst': 228,
#   'shotsOnTargetAgainst': 194,
#   'blockedScoringAttemptAgainst': 128,
#   'tacklesAgainst': 594,
#   'totalFinalThirdPassesAgainst': 2460,
#   'oppositionHalfPassesTotalAgainst': 3694,
#   'ownHalfPassesTotalAgainst': 2058,
#   'totalPassesAgainst': 23822,
#   'yellowCardsAgainst': 8,
#   'id': 4075,
#   'matches': 62,
#   'awardedMatches': 0,
#   'ano': 2020},
#  {'goalsScored': 6,
#   'goalsConceded': 12,
#   'ownGoals': 0,
#   'assists': 70,
#   'shots': 106,
#   'penaltyGoals': 6,
#   'penaltiesTaken': 6,
#   'freeKickGoals': 0,
#   'freeKickShots': 56,
#   'goalsFromInsideTheBox': 4,
#   'goalsFromOutsideTheBox': 18,
#   'shotsFromInsideTheBox': 82,
#   'shotsFromOutsideTheBox': 46,
#   'headedGoals': 6,
#   'leftFootGoals': 14,
#   'rightFootGoals': 30,
#   'bigChances': 4,
#   'bigChancesCreated': 10,
#   'bigChancesMissed': 76,
#   'shotsOnTarget': 96,
#   'shotsOffTarget': 302,
#   'blockedScoringAttempt': 82,
#   'successfulDribbles': 264,
#   'dribbleAttempts': 98,
#   'corners': 166,
#   'hitWoodwork': 26,
#   'fastBreaks': 8,
#   'fastBreakGoals': 0,
#   'fastBreakShots': 6,
#   'averageBallPossession': 23.272197036857662,
#   'totalPasses': 21238,
#   'accuratePasses': 11684,
#   'accuratePassesPercentage': 67.63429030129177,
#   'totalOwnHalfPasses': 5606,
#   'accurateOwnHalfPasses': 12964,
#   'accurateOwnHalfPassesPercentage': 118.14322716787908,
#   'totalOppositionHalfPasses': 7940,
#   'accurateOppositionHalfPasses': 1646,
#   'accurateOppositionHalfPassesPercentage': 131.14544102888954,
#   'totalLongBalls': 1910,
#   'accurateLongBalls': 110,
#   'accurateLongBallsPercentage': 9.167427560060538,
#   'totalCrosses': 716,
#   'accurateCrosses': 218,
#   'accurateCrossesPercentage': 9.853177798599479,
#   'cleanSheets': 4,
#   'tackles': 330,
#   'interceptions': 828,
#   'saves': 116,
#   'errorsLeadingToGoal': 0,
#   'errorsLeadingToShot': 2,
#   'penaltiesCommited': 10,
#   'penaltyGoalsConceded': 2,
#   'clearances': 26,
#   'clearancesOffLine': 6,
#   'lastManTackles': 0,
#   'totalDuels': 1340,
#   'duelsWon': 54,
#   'duelsWonPercentage': 80.08212972913614,
#   'totalGroundDuels': 644,
#   'groundDuelsWon': 460,
#   'groundDuelsWonPercentage': 78.6812830998177,
#   'totalAerialDuels': 1642,
#   'aerialDuelsWon': 76,
#   'aerialDuelsWonPercentage': 19.333060662272857,
#   'possessionLost': 3400,
#   'offsides': 14,
#   'fouls': 402,
#   'yellowCards': 124,
#   'yellowRedCards': 4,
#   'redCards': 12,
#   'avgRating': 9.46561153090621,
#   'accurateFinalThirdPassesAgainst': 28,
#   'accurateOppositionHalfPassesAgainst': 9232,
#   'accurateOwnHalfPassesAgainst': 946,
#   'accuratePassesAgainst': 25702,
#   'bigChancesAgainst': 110,
#   'bigChancesCreatedAgainst': 32,
#   'bigChancesMissedAgainst': 66,
#   'clearancesAgainst': 244,
#   'cornersAgainst': 94,
#   'crossesSuccessfulAgainst': 108,
#   'crossesTotalAgainst': 278,
#   'dribbleAttemptsTotalAgainst': 1122,
#   'dribbleAttemptsWonAgainst': 50,
#   'errorsLeadingToGoalAgainst': 4,
#   'errorsLeadingToShotAgainst': 10,
#   'hitWoodworkAgainst': 20,
#   'interceptionsAgainst': 698,
#   'keyPassesAgainst': 148,
#   'longBallsSuccessfulAgainst': 1146,
#   'longBallsTotalAgainst': 1424,
#   'offsidesAgainst': 52,
#   'redCardsAgainst': 0,
#   'shotsAgainst': 380,
#   'shotsBlockedAgainst': 248,
#   'shotsFromInsideTheBoxAgainst': 200,
#   'shotsFromOutsideTheBoxAgainst': 338,
#   'shotsOffTargetAgainst': 268,
#   'shotsOnTargetAgainst': 224,
#   'blockedScoringAttemptAgainst': 250,
#   'tacklesAgainst': 448,
#   'totalFinalThirdPassesAgainst': 3006,
#   'oppositionHalfPassesTotalAgainst': 6814,
#   'ownHalfPassesTotalAgainst': 2322,
#   'totalPassesAgainst': 30076,
#   'yellowCardsAgainst': 40,
#   'id': 5579,
#   'matches': 20,
#   'awardedMatches': 0,
#   'ano': 2021},
#  {'goalsScored': 48,
#   'goalsConceded': 4,
#   'ownGoals': 0,
#   'assists': 32,
#   'shots': 1242,
#   'penaltyGoals': 2,
#   'penaltiesTaken': 14,
#   'freeKickGoals': 0,
#   'freeKickShots': 30,
#   'goalsFromInsideTheBox': 2,
#   'goalsFromOutsideTheBox': 4,
#   'shotsFromInsideTheBox': 138,
#   'shotsFromOutsideTheBox': 474,
#   'headedGoals': 8,
#   'leftFootGoals': 12,
#   'rightFootGoals': 42,
#   'bigChances': 142,
#   'bigChancesCreated': 90,
#   'bigChancesMissed': 16,
#   'shotsOnTarget': 186,
#   'shotsOffTarget': 400,
#   'blockedScoringAttempt': 142,
#   'successfulDribbles': 112,
#   'dribbleAttempts': 1200,
#   'corners': 362,
#   'hitWoodwork': 24,
#   'fastBreaks': 52,
#   'fastBreakGoals': 4,
#   'fastBreakShots': 16,
#   'averageBallPossession': 44.682004230131525,
#   'totalPasses': 3112,
#   'accuratePasses': 11250,
#   'accuratePassesPercentage': 42.086630359295455,
#   'totalOwnHalfPasses': 6062,
#   'accurateOwnHalfPasses': 8958,
#   'accurateOwnHalfPassesPercentage': 20.73324685202593,
#   'totalOppositionHalfPasses': 8786,
#   'accurateOppositionHalfPasses': 7400,
#   'accurateOppositionHalfPassesPercentage': 27.713914890436726,
#   'totalLongBalls': 2206,
#   'accurateLongBalls': 2210,
#   'accurateLongBallsPercentage': 84.99730929404376,
#   'totalCrosses': 224,
#   'accurateCrosses': 192,
#   'accurateCrossesPercentage': 26.54495487697437,
#   'cleanSheets': 6,
#   'tackles': 416,
#   'interceptions': 648,
#   'saves': 134,
#   'errorsLeadingToGoal': 0,
#   'errorsLeadingToShot': 0,
#   'penaltiesCommited': 4,
#   'penaltyGoalsConceded': 2,
#   'clearances': 186,
#   'clearancesOffLine': 0,
#   'lastManTackles': 0,
#   'totalDuels': 1642,
#   'duelsWon': 3850,
#   'duelsWonPercentage': 81.06761824315149,
#   'totalGroundDuels': 4720,
#   'groundDuelsWon': 1458,
#   'groundDuelsWonPercentage': 19.293429000007222,
#   'totalAerialDuels': 990,
#   'aerialDuelsWon': 310,
#   'aerialDuelsWonPercentage': 68.13577500145152,
#   'possessionLost': 8524,
#   'offsides': 134,
#   'fouls': 92,
#   'yellowCards': 84,
#   'yellowRedCards': 0,
#   'redCards': 4,
#   'avgRating': 9.483586725336028,
#   'accurateFinalThirdPassesAgainst': 1378,
#   'accurateOppositionHalfPassesAgainst': 940,
#   'accurateOwnHalfPassesAgainst': 5078,
#   'accuratePassesAgainst': 6090,
#   'bigChancesAgainst': 24,
#   'bigChancesCreatedAgainst': 48,
#   'bigChancesMissedAgainst': 40,
#   'clearancesAgainst': 1636,
#   'cornersAgainst': 234,
#   'crossesSuccessfulAgainst': 168,
#   'crossesTotalAgainst': 222,
#   'dribbleAttemptsTotalAgainst': 534,
#   'dribbleAttemptsWonAgainst': 216,
#   'errorsLeadingToGoalAgainst': 4,
#   'errorsLeadingToShotAgainst': 4,
#   'hitWoodworkAgainst': 8,
#   'interceptionsAgainst': 364,
#   'keyPassesAgainst': 8,
#   'longBallsSuccessfulAgainst': 302,
#   'longBallsTotalAgainst': 3036,
#   'offsidesAgainst': 36,
#   'redCardsAgainst': 6,
#   'shotsAgainst': 172,
#   'shotsBlockedAgainst': 30,
#   'shotsFromInsideTheBoxAgainst': 32,
#   'shotsFromOutsideTheBoxAgainst': 334,
#   'shotsOffTargetAgainst': 34,
#   'shotsOnTargetAgainst': 192,
#   'blockedScoringAttemptAgainst': 94,
#   'tacklesAgainst': 320,
#   'totalFinalThirdPassesAgainst': 4292,
#   'oppositionHalfPassesTotalAgainst': 5772,
#   'ownHalfPassesTotalAgainst': 1858,
#   'totalPassesAgainst': 6870,
#   'yellowCardsAgainst': 38,
#   'id': 7252,
#   'matches': 60,
#   'awardedMatches': 0,
#   'ano': 2022}]

# %%
build_dataframe("palmeiras")
# Out:
#                                            2017     2018     2019     2020  \
# goalsScored                                38.0     10.0     80.0     22.0
# goalsConceded                              22.0     12.0     26.0     48.0
# ownGoals                                    0.0      0.0      0.0      0.0
# assists                                    36.0     10.0     58.0     56.0
# shots                                     540.0    714.0    924.0    966.0
# penaltyGoals                                4.0      0.0      2.0      6.0
# penaltiesTaken                             10.0      2.0      8.0     12.0
# freeKickGoals                               0.0      0.0      0.0      0.0
# freeKickShots                               0.0     68.0     26.0     22.0
# goalsFromInsideTheBox                      12.0     60.0     24.0     48.0
# goalsFromOutsideTheBox                      8.0      8.0      0.0      4.0
# shotsFromInsideTheBox                       0.0      2.0    172.0    386.0
# shotsFromOutsideTheBox                      0.0      2.0    130.0    404.0
# headedGoals                                16.0     12.0     14.0      4.0
# leftFootGoals                               2.0     20.0     12.0     12.0
# rightFootGoals                             16.0     44.0     10.0     14.0
# bigChances                                 86.0     26.0     20.0     74.0
# bigChancesCreated                          14.0     80.0      0.0     88.0
# bigChancesMissed                           66.0     32.0      6.0     76.0
# shotsOnTarget                             298.0    322.0    324.0    114.0
# shotsOffTarget                            182.0     68.0    364.0     66.0
# blockedScoringAttempt                     194.0    170.0     20.0     16.0
# successfulDribbles                        140.0    372.0    346.0     20.0
# dribbleAttempts                           206.0    272.0    406.0    492.0
# corners                                   398.0     16.0    390.0    296.0
# hitWoodwork                                 0.0     16.0      2.0     26.0
# fastBreaks                                 12.0     14.0     28.0     14.0
# fastBreakGoals                              0.0      2.0      4.0      0.0
# fastBreakShots                              2.0     12.0      8.0     12.0
# averageBallPossession                      38.0     44.0     83.0      6.0
# totalPasses                             18038.0  21200.0  16054.0  10988.0
# accuratePasses                          23196.0   8764.0  16802.0   4634.0
# accuratePassesPercentage                  114.0    110.0     55.0     88.0
# totalOwnHalfPasses                      13684.0   7916.0   2014.0   6326.0
# accurateOwnHalfPasses                    5330.0   1948.0   1054.0   3574.0
# accurateOwnHalfPassesPercentage            28.0    164.0     23.0     64.0
# totalOppositionHalfPasses               12840.0  18806.0  13958.0  17046.0
# accurateOppositionHalfPasses            11792.0   1546.0   1952.0   7326.0
# accurateOppositionHalfPassesPercentage    117.0    103.0     89.0     23.0
# totalLongBalls                           1652.0   3304.0   2378.0   1724.0
# accurateLongBalls                         252.0    786.0   1420.0   1782.0
# accurateLongBallsPercentage                81.0     88.0     62.0     73.0
# totalCrosses                             1412.0   1226.0    562.0    544.0
# accurateCrosses                           152.0    252.0    370.0     80.0
# accurateCrossesPercentage                  11.0     44.0     18.0     20.0
# cleanSheets                                10.0     18.0     14.0     22.0
# tackles                                   578.0    288.0     50.0    350.0
# interceptions                             958.0     36.0    206.0    110.0
# saves                                     208.0     82.0    100.0    144.0
# errorsLeadingToGoal                         0.0      4.0      0.0      0.0
# errorsLeadingToShot                         0.0      0.0      2.0      4.0
# penaltiesCommited                           4.0      2.0      8.0      8.0
# penaltyGoalsConceded                        6.0      0.0      6.0      0.0
# clearances                                744.0   1032.0      8.0   1028.0
# clearancesOffLine                           0.0      0.0      0.0      0.0
# lastManTackles                              0.0      0.0      0.0      2.0
# totalDuels                               7240.0   8930.0   4718.0   7500.0
# duelsWon                                 3658.0   3562.0   4220.0    238.0
# duelsWonPercentage                         26.0     59.0     42.0     36.0
# totalGroundDuels                         4222.0   2976.0   3034.0   2844.0
# groundDuelsWon                           2164.0   2952.0    232.0   2540.0
# groundDuelsWonPercentage                   38.0     79.0     16.0     51.0
# totalAerialDuels                          262.0    782.0    222.0   1524.0
# aerialDuelsWon                            182.0    442.0    630.0    108.0
# aerialDuelsWonPercentage                   72.0     60.0     40.0    104.0
# possessionLost                           3686.0   1282.0     12.0   5248.0
# offsides                                   92.0     32.0     16.0     38.0
# fouls                                     246.0    138.0     54.0   1242.0
# yellowCards                                28.0    172.0     18.0     32.0
# yellowRedCards                              0.0      0.0      0.0      0.0
# redCards                                    0.0      0.0      4.0      8.0
# avgRating                                  10.0     12.0      4.0      1.0
# accurateFinalThirdPassesAgainst          3242.0    684.0    276.0   4310.0
# accurateOppositionHalfPassesAgainst      5594.0   8806.0   4104.0    644.0
# accurateOwnHalfPassesAgainst             3814.0   3960.0   5148.0  10638.0
# accuratePassesAgainst                   14044.0  17670.0  25236.0   3418.0
# bigChancesAgainst                          28.0     12.0     54.0     40.0
# bigChancesCreatedAgainst                    2.0     22.0     26.0     32.0
# bigChancesMissedAgainst                    62.0      8.0     24.0     20.0
# clearancesAgainst                         154.0   1428.0    116.0    920.0
# cornersAgainst                            138.0    258.0    230.0     48.0
# crossesSuccessfulAgainst                  254.0    208.0    134.0    264.0
# crossesTotalAgainst                       662.0    494.0    522.0    618.0
# dribbleAttemptsTotalAgainst               394.0    930.0    718.0   1292.0
# dribbleAttemptsWonAgainst                  82.0    246.0    272.0    774.0
# errorsLeadingToGoalAgainst                  2.0      8.0      2.0      0.0
# errorsLeadingToShotAgainst                  2.0      4.0     16.0      4.0
# hitWoodworkAgainst                          0.0      8.0      4.0     12.0
# interceptionsAgainst                      936.0    530.0    470.0    514.0
# keyPassesAgainst                          120.0    272.0     98.0    450.0
# longBallsSuccessfulAgainst                178.0   1250.0   1586.0   1262.0
# longBallsTotalAgainst                    3694.0   3124.0   2534.0   3544.0
# offsidesAgainst                           150.0     52.0     30.0     72.0
# redCardsAgainst                             8.0     16.0      4.0      4.0
# shotsAgainst                              422.0    266.0    750.0    418.0
# shotsBlockedAgainst                        78.0    172.0    142.0     66.0
# shotsFromInsideTheBoxAgainst                0.0      4.0    158.0    206.0
# shotsFromOutsideTheBoxAgainst               0.0      4.0    184.0     26.0
# shotsOffTargetAgainst                     132.0    164.0     90.0      2.0
# shotsOnTargetAgainst                      294.0     16.0    262.0    252.0
# blockedScoringAttemptAgainst              104.0     60.0    142.0    118.0
# tacklesAgainst                           1010.0    844.0    790.0    196.0
# totalFinalThirdPassesAgainst             4390.0   4658.0    136.0   3100.0
# oppositionHalfPassesTotalAgainst        15590.0   7782.0   7146.0   4376.0
# ownHalfPassesTotalAgainst                1114.0  13966.0   1252.0  11934.0
# totalPassesAgainst                       1710.0  15976.0   6428.0   5228.0
# yellowCardsAgainst                        128.0    202.0    112.0     96.0
# id                                       3514.0    890.0   1086.0   4075.0
# matches                                    68.0     48.0      2.0     14.0
# awardedMatches                              0.0      0.0      0.0      0.0
# ano                                      2017.0   2018.0   2019.0   2020.0
#
#                                            2021     2022    Media
# goalsScored                                92.0     34.0     46.0
# goalsConceded                              52.0     20.0     30.0
# ownGoals                                    0.0      2.0      0.3
# assists                                    42.0     12.0     35.7
# shots                                     772.0    998.0    819.0
# penaltyGoals                                0.0      2.0      2.3
# penaltiesTaken                              8.0     12.0      8.7
# freeKickGoals                               2.0      0.0      0.3
# freeKickShots                              20.0     14.0     25.0
# goalsFromInsideTheBox                      58.0     56.0     43.0
# goalsFromOutsideTheBox                     16.0      4.0      6.7
# shotsFromInsideTheBox                      22.0    246.0    138.0
# shotsFromOutsideTheBox                    104.0      0.0    106.7
# headedGoals                                12.0     18.0     12.7
# leftFootGoals                               4.0     38.0     14.7
# rightFootGoals                             20.0      4.0     18.0
# bigChances                                 98.0     82.0     64.3
# bigChancesCreated                           6.0     22.0     35.0
# bigChancesMissed                           84.0     34.0     49.7
# shotsOnTarget                             246.0    212.0    252.7
# shotsOffTarget                            472.0    514.0    277.7
# blockedScoringAttempt                      52.0    308.0    126.7
# successfulDribbles                        460.0    492.0    305.0
# dribbleAttempts                          1062.0   1062.0    583.3
# corners                                   398.0    152.0    275.0
# hitWoodwork                                 0.0     26.0     11.7
# fastBreaks                                  2.0     48.0     19.7
# fastBreakGoals                              0.0      8.0      2.3
# fastBreakShots                             14.0      6.0      9.0
# averageBallPossession                      15.0     83.0     44.8
# totalPasses                               702.0  30626.0  16268.0
# accuratePasses                          21418.0  26082.0  16816.0
# accuratePassesPercentage                  163.0     31.0     93.5
# totalOwnHalfPasses                       4710.0   4948.0   6599.7
# accurateOwnHalfPasses                   13730.0   5474.0   5185.0
# accurateOwnHalfPassesPercentage            81.0     79.0     73.2
# totalOppositionHalfPasses                6374.0   9304.0  13054.7
# accurateOppositionHalfPasses             1526.0   8446.0   5431.3
# accurateOppositionHalfPassesPercentage     81.0     78.0     81.8
# totalLongBalls                           1630.0   2934.0   2270.3
# accurateLongBalls                        2100.0    332.0   1112.0
# accurateLongBallsPercentage                29.0     46.0     63.2
# totalCrosses                              164.0    486.0    732.3
# accurateCrosses                            48.0    252.0    192.3
# accurateCrossesPercentage                   3.0     31.0     21.2
# cleanSheets                                18.0      0.0     13.7
# tackles                                   470.0    876.0    435.3
# interceptions                              74.0    680.0    344.0
# saves                                     198.0     86.0    136.3
# errorsLeadingToGoal                         0.0      0.0      0.7
# errorsLeadingToShot                         4.0      0.0      1.7
# penaltiesCommited                          10.0      4.0      6.0
# penaltyGoalsConceded                        4.0      0.0      2.7
# clearances                                992.0    910.0    785.7
# clearancesOffLine                           2.0      0.0      0.3
# lastManTackles                              0.0      0.0      0.3
# totalDuels                                922.0   4176.0   5581.0
# duelsWon                                  264.0   1628.0   2261.7
# duelsWonPercentage                         40.0     95.0     49.7
# totalGroundDuels                         3458.0   3040.0   3262.3
# groundDuelsWon                            852.0   2256.0   1832.7
# groundDuelsWonPercentage                   40.0     87.0     51.8
# totalAerialDuels                         1814.0   1288.0    982.0
# aerialDuelsWon                           1098.0    110.0    428.3
# aerialDuelsWonPercentage                   12.0     21.0     51.5
# possessionLost                           1348.0   5118.0   2782.3
# offsides                                    2.0     94.0     45.7
# fouls                                     896.0    442.0    503.0
# yellowCards                                20.0     84.0     59.0
# yellowRedCards                              2.0      0.0      0.3
# redCards                                    8.0      2.0      3.7
# avgRating                                   5.0     10.0      7.0
# accurateFinalThirdPassesAgainst          2436.0   1658.0   2101.0
# accurateOppositionHalfPassesAgainst      1904.0    652.0   3617.3
# accurateOwnHalfPassesAgainst             6216.0   2770.0   5424.3
# accuratePassesAgainst                   25852.0  15052.0  16878.7
# bigChancesAgainst                         102.0     44.0     46.7
# bigChancesCreatedAgainst                    4.0     34.0     20.0
# bigChancesMissedAgainst                    10.0     26.0     25.0
# clearancesAgainst                         716.0    952.0    714.3
# cornersAgainst                             22.0    234.0    155.0
# crossesSuccessfulAgainst                   74.0    110.0    174.0
# crossesTotalAgainst                       966.0    604.0    644.3
# dribbleAttemptsTotalAgainst              1200.0   1098.0    938.7
# dribbleAttemptsWonAgainst                  80.0     14.0    244.7
# errorsLeadingToGoalAgainst                  6.0      4.0      3.7
# errorsLeadingToShotAgainst                  0.0      0.0      4.3
# hitWoodworkAgainst                         16.0     24.0     10.7
# interceptionsAgainst                      358.0    568.0    562.7
# keyPassesAgainst                          122.0    270.0    222.0
# longBallsSuccessfulAgainst               1292.0    436.0   1000.7
# longBallsTotalAgainst                     888.0    860.0   2440.7
# offsidesAgainst                            34.0     24.0     60.3
# redCardsAgainst                             6.0      2.0      6.7
# shotsAgainst                              654.0    404.0    485.7
# shotsBlockedAgainst                       242.0    148.0    141.3
# shotsFromInsideTheBoxAgainst              308.0     76.0    125.3
# shotsFromOutsideTheBoxAgainst             226.0    302.0    123.7
# shotsOffTargetAgainst                     352.0    146.0    147.7
# shotsOnTargetAgainst                       14.0    240.0    179.7
# blockedScoringAttemptAgainst              234.0     86.0    124.0
# tacklesAgainst                            234.0    192.0    544.3
# totalFinalThirdPassesAgainst             3500.0    928.0   2785.3
# oppositionHalfPassesTotalAgainst         3026.0   6992.0   7485.3
# ownHalfPassesTotalAgainst                2478.0   7294.0   6339.7
# totalPassesAgainst                      26972.0  19956.0  12711.7
# yellowCardsAgainst                         14.0     48.0    100.0
# id                                       5579.0   7252.0   3732.7
# matches                                    48.0     10.0     31.7
# awardedMatches                              0.0      0.0      0.0
# ano                                      2021.0   2022.0   2019.5

# %%
build_chart('goalsScored',"palmeiras","flamengo")
