# %% [markdown]
# # Visualizando Tabelas com pandas

# %% [markdown]
# ### Visaulização básica no jupyter

# %%
import pandas as pd

data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
		'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}

df = pd.DataFrame(data)

df
# Out:
#       Nome   Sobrenome
# 0  Adriano      Soares
# 1  Rodrigo    Tadewald
# 2  Juliano    Faccioni
# 3   Mateus     Kienzle
# 4    Luiza   Cherobini
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %% [markdown]
# ### Visualização os primeiros valores (.head)

# %%
import pandas as pd
  
data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
        'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}
df = pd.DataFrame(data)
  
df.head()
# Out:
#       Nome  Sobrenome
# 0  Adriano     Soares
# 1  Rodrigo   Tadewald
# 2  Juliano   Faccioni
# 3   Mateus    Kienzle
# 4    Luiza  Cherobini

# %%
df.head(2)
# Out:
#       Nome Sobrenome
# 0  Adriano    Soares
# 1  Rodrigo  Tadewald

# %% [markdown]
# ### Visualização os últimos valores (.tail)

# %%
import pandas as pd

data = {'Nome': ['Adriano', 'Rodrigo', 'Juliano', 'Mateus', 'Luiza', 'Rodrigo', 'Ayres', 'Aninha'],
        'Sobrenome': ['Soares', 'Tadewald', 'Faccioni', 'Kienzle', 'Cherobini', 'Vanzelotti', 'Júnior', 'Tadewald'],}

df = pd.DataFrame(data)

df.tail()
# Out:
#       Nome   Sobrenome
# 3   Mateus     Kienzle
# 4    Luiza   Cherobini
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %%
df.tail(3)
# Out:
#       Nome   Sobrenome
# 5  Rodrigo  Vanzelotti
# 6    Ayres      Júnior
# 7   Aninha    Tadewald

# %% [markdown]
# ### Visualizando tabelas maiores no Jupyter (display.max_rows)

# %%
import pandas as pd

tabela_vendas = pd.read_csv('datasets/vendas.csv', sep=';', decimal=',')
pd.set_option('display.max_rows', 50)
tabela_vendas.head(50)
# Out:
#                           data  id_venda         filial            vendedor  \
# 0   2023-01-20 08:00:56.384224         0         Canoas       Luis Fernando
# 1   2023-01-20 08:50:58.755843         1  Florianópolis        Mario Sérgio
# 2   2023-01-20 11:44:56.776745         2         Canoas     Carlos Henrique
# 3   2023-01-20 12:07:58.025749         3  Caxias do Sul   Rodrigo Vanzeloti
# 4   2023-01-20 12:49:56.606703         4      São Paulo       Cassia Moraes
# 5   2023-01-20 14:01:58.316971         5  Caxias do Sul      Mateus Kienzle
# 47    Tenis Fila         Kara Lewis       feminino         credito
# 48    Tenis Fila       Milo Cumming      masculino         credito
# 49  Tenis Adidas   Terrance Coppage      masculino         credito

# %% [markdown]
# ### Estilizando a visualização

# %% [markdown]
# #### Formatando floats

# %%
import pandas as pd
import numpy as np

df_tempo = pd.DataFrame(np.random.rand(10,2)*5,
                          index=pd.date_range(start="2023-01-01", periods=10),
                          columns=["Porto Alegre", "São Paulo"])
df_tempo.style.format(precision=3, decimal=",")
# Out:
# <style type="text/css">
# </style>
# <table id="T_255cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_255cc_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_255cc_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_255cc_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_255cc_row0_col0" class="data row0 col0" >1,641</td>
#       <td id="T_255cc_row0_col1" class="data row0 col1" >1,015</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_255cc_row1_col0" class="data row1 col0" >0,178</td>
#       <td id="T_255cc_row1_col1" class="data row1 col1" >1,351</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_255cc_row2_col0" class="data row2 col0" >4,630</td>
#       <td id="T_255cc_row2_col1" class="data row2 col1" >3,998</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_255cc_row3_col0" class="data row3 col0" >4,784</td>
#       <td id="T_255cc_row3_col1" class="data row3 col1" >3,807</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_255cc_row4_col0" class="data row4 col0" >1,983</td>
#       <td id="T_255cc_row4_col1" class="data row4 col1" >0,346</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_255cc_row5_col0" class="data row5 col0" >3,766</td>
#       <td id="T_255cc_row5_col1" class="data row5 col1" >3,952</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_255cc_row6_col0" class="data row6 col0" >3,789</td>
#       <td id="T_255cc_row6_col1" class="data row6 col1" >1,429</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_255cc_row7_col0" class="data row7 col0" >3,018</td>
#       <td id="T_255cc_row7_col1" class="data row7 col1" >0,926</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_255cc_row8_col0" class="data row8 col0" >0,010</td>
#       <td id="T_255cc_row8_col1" class="data row8 col1" >3,425</td>
#     </tr>
#     <tr>
#       <th id="T_255cc_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_255cc_row9_col0" class="data row9 col0" >1,584</td>
#       <td id="T_255cc_row9_col1" class="data row9 col1" >2,875</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Estilizando colunas

# %%
df_tempo.style.format_index(str.upper, axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7d4c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d4c9_level0_col0" class="col_heading level0 col0" >PORTO ALEGRE</th>
#       <th id="T_7d4c9_level0_col1" class="col_heading level0 col1" >SÃO PAULO</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d4c9_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_7d4c9_row0_col0" class="data row0 col0" >1.641186</td>
#       <td id="T_7d4c9_row0_col1" class="data row0 col1" >1.015192</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_7d4c9_row1_col0" class="data row1 col0" >0.177710</td>
#       <td id="T_7d4c9_row1_col1" class="data row1 col1" >1.350812</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_7d4c9_row2_col0" class="data row2 col0" >4.630022</td>
#       <td id="T_7d4c9_row2_col1" class="data row2 col1" >3.997702</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_7d4c9_row3_col0" class="data row3 col0" >4.783664</td>
#       <td id="T_7d4c9_row3_col1" class="data row3 col1" >3.806793</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_7d4c9_row4_col0" class="data row4 col0" >1.983351</td>
#       <td id="T_7d4c9_row4_col1" class="data row4 col1" >0.345924</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_7d4c9_row5_col0" class="data row5 col0" >3.766149</td>
#       <td id="T_7d4c9_row5_col1" class="data row5 col1" >3.952022</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_7d4c9_row6_col0" class="data row6 col0" >3.788730</td>
#       <td id="T_7d4c9_row6_col1" class="data row6 col1" >1.428688</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_7d4c9_row7_col0" class="data row7 col0" >3.017750</td>
#       <td id="T_7d4c9_row7_col1" class="data row7 col1" >0.925546</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_7d4c9_row8_col0" class="data row8 col0" >0.010001</td>
#       <td id="T_7d4c9_row8_col1" class="data row8 col1" >3.424726</td>
#     </tr>
#     <tr>
#       <th id="T_7d4c9_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_7d4c9_row9_col0" class="data row9 col0" >1.584143</td>
#       <td id="T_7d4c9_row9_col1" class="data row9 col1" >2.874749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Estilizando index

# %%
df_tempo.style.format_index(lambda v: v.strftime("%d/%m/%Y"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7672">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7672_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_b7672_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7672_level0_row0" class="row_heading level0 row0" >01/01/2023</th>
#       <td id="T_b7672_row0_col0" class="data row0 col0" >1.641186</td>
#       <td id="T_b7672_row0_col1" class="data row0 col1" >1.015192</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row1" class="row_heading level0 row1" >02/01/2023</th>
#       <td id="T_b7672_row1_col0" class="data row1 col0" >0.177710</td>
#       <td id="T_b7672_row1_col1" class="data row1 col1" >1.350812</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row2" class="row_heading level0 row2" >03/01/2023</th>
#       <td id="T_b7672_row2_col0" class="data row2 col0" >4.630022</td>
#       <td id="T_b7672_row2_col1" class="data row2 col1" >3.997702</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row3" class="row_heading level0 row3" >04/01/2023</th>
#       <td id="T_b7672_row3_col0" class="data row3 col0" >4.783664</td>
#       <td id="T_b7672_row3_col1" class="data row3 col1" >3.806793</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row4" class="row_heading level0 row4" >05/01/2023</th>
#       <td id="T_b7672_row4_col0" class="data row4 col0" >1.983351</td>
#       <td id="T_b7672_row4_col1" class="data row4 col1" >0.345924</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row5" class="row_heading level0 row5" >06/01/2023</th>
#       <td id="T_b7672_row5_col0" class="data row5 col0" >3.766149</td>
#       <td id="T_b7672_row5_col1" class="data row5 col1" >3.952022</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row6" class="row_heading level0 row6" >07/01/2023</th>
#       <td id="T_b7672_row6_col0" class="data row6 col0" >3.788730</td>
#       <td id="T_b7672_row6_col1" class="data row6 col1" >1.428688</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row7" class="row_heading level0 row7" >08/01/2023</th>
#       <td id="T_b7672_row7_col0" class="data row7 col0" >3.017750</td>
#       <td id="T_b7672_row7_col1" class="data row7 col1" >0.925546</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row8" class="row_heading level0 row8" >09/01/2023</th>
#       <td id="T_b7672_row8_col0" class="data row8 col0" >0.010001</td>
#       <td id="T_b7672_row8_col1" class="data row8 col1" >3.424726</td>
#     </tr>
#     <tr>
#       <th id="T_b7672_level0_row9" class="row_heading level0 row9" >10/01/2023</th>
#       <td id="T_b7672_row9_col0" class="data row9 col0" >1.584143</td>
#       <td id="T_b7672_row9_col1" class="data row9 col1" >2.874749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Adicionando título

# %%
df_tempo.style.set_caption('Condição do tempo')
# Out:
# <style type="text/css">
# </style>
# <table id="T_55610">
#   <caption>Condição do tempo</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55610_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_55610_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55610_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_55610_row0_col0" class="data row0 col0" >1.641186</td>
#       <td id="T_55610_row0_col1" class="data row0 col1" >1.015192</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_55610_row1_col0" class="data row1 col0" >0.177710</td>
#       <td id="T_55610_row1_col1" class="data row1 col1" >1.350812</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_55610_row2_col0" class="data row2 col0" >4.630022</td>
#       <td id="T_55610_row2_col1" class="data row2 col1" >3.997702</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_55610_row3_col0" class="data row3 col0" >4.783664</td>
#       <td id="T_55610_row3_col1" class="data row3 col1" >3.806793</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_55610_row4_col0" class="data row4 col0" >1.983351</td>
#       <td id="T_55610_row4_col1" class="data row4 col1" >0.345924</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_55610_row5_col0" class="data row5 col0" >3.766149</td>
#       <td id="T_55610_row5_col1" class="data row5 col1" >3.952022</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_55610_row6_col0" class="data row6 col0" >3.788730</td>
#       <td id="T_55610_row6_col1" class="data row6 col1" >1.428688</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_55610_row7_col0" class="data row7 col0" >3.017750</td>
#       <td id="T_55610_row7_col1" class="data row7 col1" >0.925546</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_55610_row8_col0" class="data row8 col0" >0.010001</td>
#       <td id="T_55610_row8_col1" class="data row8 col1" >3.424726</td>
#     </tr>
#     <tr>
#       <th id="T_55610_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_55610_row9_col0" class="data row9 col0" >1.584143</td>
#       <td id="T_55610_row9_col1" class="data row9 col1" >2.874749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Adicionando gradiente (formatação condicional)

# %%
df_tempo.style.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")# tema de cores
# Out:
# <style type="text/css">
# #T_70022_row0_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_70022_row0_col1, #T_70022_row1_col0, #T_70022_row4_col1, #T_70022_row7_col1, #T_70022_row8_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_70022_row1_col1 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_70022_row2_col0 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_70022_row2_col1 {
#   background-color: #225ea8;
#   color: #f1f1f1;
# }
# #T_70022_row3_col0 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_70022_row3_col1 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_70022_row4_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_70022_row5_col0 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_70022_row5_col1 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_70022_row6_col0 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_70022_row6_col1 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_70022_row7_col0 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_70022_row8_col1 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_70022_row9_col0 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_70022_row9_col1 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# </style>
# <table id="T_70022">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70022_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_70022_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70022_level0_row0" class="row_heading level0 row0" >2023-01-01 00:00:00</th>
#       <td id="T_70022_row0_col0" class="data row0 col0" >1.641186</td>
#       <td id="T_70022_row0_col1" class="data row0 col1" >1.015192</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row1" class="row_heading level0 row1" >2023-01-02 00:00:00</th>
#       <td id="T_70022_row1_col0" class="data row1 col0" >0.177710</td>
#       <td id="T_70022_row1_col1" class="data row1 col1" >1.350812</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row2" class="row_heading level0 row2" >2023-01-03 00:00:00</th>
#       <td id="T_70022_row2_col0" class="data row2 col0" >4.630022</td>
#       <td id="T_70022_row2_col1" class="data row2 col1" >3.997702</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row3" class="row_heading level0 row3" >2023-01-04 00:00:00</th>
#       <td id="T_70022_row3_col0" class="data row3 col0" >4.783664</td>
#       <td id="T_70022_row3_col1" class="data row3 col1" >3.806793</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row4" class="row_heading level0 row4" >2023-01-05 00:00:00</th>
#       <td id="T_70022_row4_col0" class="data row4 col0" >1.983351</td>
#       <td id="T_70022_row4_col1" class="data row4 col1" >0.345924</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row5" class="row_heading level0 row5" >2023-01-06 00:00:00</th>
#       <td id="T_70022_row5_col0" class="data row5 col0" >3.766149</td>
#       <td id="T_70022_row5_col1" class="data row5 col1" >3.952022</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row6" class="row_heading level0 row6" >2023-01-07 00:00:00</th>
#       <td id="T_70022_row6_col0" class="data row6 col0" >3.788730</td>
#       <td id="T_70022_row6_col1" class="data row6 col1" >1.428688</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row7" class="row_heading level0 row7" >2023-01-08 00:00:00</th>
#       <td id="T_70022_row7_col0" class="data row7 col0" >3.017750</td>
#       <td id="T_70022_row7_col1" class="data row7 col1" >0.925546</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row8" class="row_heading level0 row8" >2023-01-09 00:00:00</th>
#       <td id="T_70022_row8_col0" class="data row8 col0" >0.010001</td>
#       <td id="T_70022_row8_col1" class="data row8 col1" >3.424726</td>
#     </tr>
#     <tr>
#       <th id="T_70022_level0_row9" class="row_heading level0 row9" >2023-01-10 00:00:00</th>
#       <td id="T_70022_row9_col0" class="data row9 col0" >1.584143</td>
#       <td id="T_70022_row9_col1" class="data row9 col1" >2.874749</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Juntando tudo

# %%
def condição_chuva(v):
    if v < 1.75:
        return "Seco"
    elif v < 2.75:
        return "Chuva"
    return "Chuva Forte"

def embelezar(styler):
    styler.set_caption("Condição do tempo")
    styler.format(condição_chuva)
    styler.format_index(lambda v: v.strftime("%d/%m/%Y"))
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    return styler

df_tempo.style.pipe(embelezar)
# Out:
# <style type="text/css">
# #T_f917f_row0_col0 {
#   background-color: #e2f4b2;
#   color: #000000;
# }
# #T_f917f_row0_col1, #T_f917f_row1_col0, #T_f917f_row4_col1, #T_f917f_row7_col1, #T_f917f_row8_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_f917f_row1_col1 {
#   background-color: #f3fabd;
#   color: #000000;
# }
# #T_f917f_row2_col0 {
#   background-color: #1d2e83;
#   color: #f1f1f1;
# }
# #T_f917f_row2_col1 {
#   background-color: #225ea8;
#   color: #f1f1f1;
# }
# #T_f917f_row3_col0 {
#   background-color: #142670;
#   color: #f1f1f1;
# }
# #T_f917f_row3_col1 {
#   background-color: #2072b1;
#   color: #f1f1f1;
# }
# #T_f917f_row4_col0 {
#   background-color: #c9eab4;
#   color: #000000;
# }
# #T_f917f_row5_col0 {
#   background-color: #2075b3;
#   color: #f1f1f1;
# }
# #T_f917f_row5_col1 {
#   background-color: #2163aa;
#   color: #f1f1f1;
# }
# #T_f917f_row6_col0 {
#   background-color: #2073b2;
#   color: #f1f1f1;
# }
# #T_f917f_row6_col1 {
#   background-color: #f0f9b7;
#   color: #000000;
# }
# #T_f917f_row7_col0 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_f917f_row8_col1 {
#   background-color: #2296c1;
#   color: #f1f1f1;
# }
# #T_f917f_row9_col0 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_f917f_row9_col1 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# </style>
# <table id="T_f917f">
#   <caption>Condição do tempo</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f917f_level0_col0" class="col_heading level0 col0" >Porto Alegre</th>
#       <th id="T_f917f_level0_col1" class="col_heading level0 col1" >São Paulo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f917f_level0_row0" class="row_heading level0 row0" >01/01/2023</th>
#       <td id="T_f917f_row0_col0" class="data row0 col0" >Seco</td>
#       <td id="T_f917f_row0_col1" class="data row0 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row1" class="row_heading level0 row1" >02/01/2023</th>
#       <td id="T_f917f_row1_col0" class="data row1 col0" >Seco</td>
#       <td id="T_f917f_row1_col1" class="data row1 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row2" class="row_heading level0 row2" >03/01/2023</th>
#       <td id="T_f917f_row2_col0" class="data row2 col0" >Chuva Forte</td>
#       <td id="T_f917f_row2_col1" class="data row2 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row3" class="row_heading level0 row3" >04/01/2023</th>
#       <td id="T_f917f_row3_col0" class="data row3 col0" >Chuva Forte</td>
#       <td id="T_f917f_row3_col1" class="data row3 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row4" class="row_heading level0 row4" >05/01/2023</th>
#       <td id="T_f917f_row4_col0" class="data row4 col0" >Chuva</td>
#       <td id="T_f917f_row4_col1" class="data row4 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row5" class="row_heading level0 row5" >06/01/2023</th>
#       <td id="T_f917f_row5_col0" class="data row5 col0" >Chuva Forte</td>
#       <td id="T_f917f_row5_col1" class="data row5 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row6" class="row_heading level0 row6" >07/01/2023</th>
#       <td id="T_f917f_row6_col0" class="data row6 col0" >Chuva Forte</td>
#       <td id="T_f917f_row6_col1" class="data row6 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row7" class="row_heading level0 row7" >08/01/2023</th>
#       <td id="T_f917f_row7_col0" class="data row7 col0" >Chuva Forte</td>
#       <td id="T_f917f_row7_col1" class="data row7 col1" >Seco</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row8" class="row_heading level0 row8" >09/01/2023</th>
#       <td id="T_f917f_row8_col0" class="data row8 col0" >Seco</td>
#       <td id="T_f917f_row8_col1" class="data row8 col1" >Chuva Forte</td>
#     </tr>
#     <tr>
#       <th id="T_f917f_level0_row9" class="row_heading level0 row9" >10/01/2023</th>
#       <td id="T_f917f_row9_col0" class="data row9 col0" >Seco</td>
#       <td id="T_f917f_row9_col1" class="data row9 col1" >Chuva Forte</td>
#     </tr>
#   </tbody>
# </table>
