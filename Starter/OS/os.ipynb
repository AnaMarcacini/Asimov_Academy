# %%
import os

# %%
os.getcwd()
# Out:
# '/home/anahelena/Curso Python/Starter/OS'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'NOTAS.txt',
#  'os.py',
#  'teste.csv',
#  'Aula2.ipynb',
#  'teste.txt',
#  'teste.json']

# %%
os.listdir('/home/anahelena/Curso Python/')
# Out:
# ['.ipynb_checkpoints', 'Starter']

# %%
diretorioAtual = os.getcwd()

# %%
diretorioAtual
# Out:
# '/home/anahelena/Curso Python/Starter/OS'

# %%
os.chdir('/home/anahelena/Curso Python/')

# %%
print(os.getcwd())
# Out:
# /home/anahelena/Curso Python
