# %%
import os

# %%
os.getcwd()
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS/Parte 1'

# %%
os.path.join(os.getcwd(), 'pasta')
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS/Parte 1/pasta'

# %%
os.getcwd() + "/pasta"
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS/Parte 1/pasta'

# %%
os.path.basename(os.getcwd())
# Out:
# 'Parte 1'

# %%
os.getcwd()
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS/Parte 1'

# %%
os.getcwd().split("/")[-1]
# Out:
# 'Parte 1'

# %%
os.path.split(os.getcwd())
# Out:
# ('/home/anahelena/Git/Asimov_Academy/Starter/OS', 'Parte 1')

# %%
os.path.split(os.getcwd())[1]
# Out:
# 'Parte 1'

# %%
os.path.split(os.getcwd())[0]
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS'

# %%
os.path.dirname(os.getcwd())
# Out:
# '/home/anahelena/Git/Asimov_Academy/Starter/OS'

# %%
curr_dir = os.getcwd()

# %%
lt = os.path.getmtime(curr_dir)#data em segundos

# %%
os.path.getmtime(curr_dir)#data em segundos
# Out:
# 1671081538.0881276

# %%
from datetime import datetime

# %%
datetime.utcfromtimestamp(lt)
# Out:
# datetime.datetime(2022, 12, 15, 5, 18, 58, 88128)
